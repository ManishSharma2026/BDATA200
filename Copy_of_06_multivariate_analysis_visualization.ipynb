# %% [markdown]
# <a href="https://colab.research.google.com/github/ManishSharma2026/BDATA200/blob/main/Copy_of_06_multivariate_analysis_visualization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <div style="background: linear-gradient(135deg, #4B2E83 0%, #32006E 100%); padding: 40px 30px; border-radius: 15px; box-shadow: 0 8px 20px rgba(75,46,131,0.3);">
#   <img src="https://uw-s3-cdn.s3.us-west-2.amazonaws.com/wp-content/uploads/sites/230/2023/11/02134828/Signature_Left_Gold_RGB.png" alt="University of Washington" style="height: 80px; margin-bottom: 20px;">
#   <h1 style="color: #FFF; font-family: 'Encode Sans', 'Arial', sans-serif; font-weight: 700; font-size: 2.8em; margin: 20px 0 15px 0; text-shadow: 2px 2px 4px rgba(0,0,0,0.3);">Multivariate Analysis &amp; Visualization</h1>
#   <p style="color: #E8D3FF; font-family: 'Encode Sans', 'Arial', sans-serif; font-size: 1.3em; margin: 10px 0; font-weight: 300;">BDATA 200 Introduction to Data Studies</p>
#   <p style="color: #B7A6D5; font-family: 'Encode Sans', 'Arial', sans-serif; font-size: 1.1em; margin: 5px 0;">University of Washington</p>
# </div>
#
# <div style="background-color: #F5F5F5; padding: 15px 25px; border-left: 5px solid #4B2E83; border-radius: 5px; margin-top: 25px;">
#   <p style="font-size: 1.1em; color: #333; margin: 0;">
#     <strong style="color: #4B2E83;">Open in Google Colab:</strong>
#   </p>
#   <p style="margin: 10px 0 5px 0;">
#     <a target="_blank" href="https://colab.research.google.com/github/PedroBSB/BDATA200/blob/main/06_multivariate_analysis_visualization.ipynb">
#       <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab" style="vertical-align: middle;"/>
#     </a>
#   </p>
# </div>
#
# <div style="background: linear-gradient(to right, #FFF8E1, #FFFEF7); padding: 20px 25px; border-radius: 10px; border: 2px solid #E8B923; margin: 30px 0;">
#   <h3 style="color: #4B2E83; font-family: 'Encode Sans', 'Arial', sans-serif; margin-top: 0; font-size: 1.3em;">Student Information</h3>
#   <div style="background-color: white; padding: 15px; border-radius: 5px; margin-top: 15px;">
#     <p style="margin: 10px 0; color: #333; font-size: 1.05em;">
#       <strong style="color: #4B2E83;">Name:</strong> <span style="color: #666;">[Manish Sharma]</span>
#     </p>
#     <p style="margin: 10px 0; color: #333; font-size: 1.05em;">
#       <strong style="color: #4B2E83;">Student ID:</strong> <span style="color: #666;">[2223588]</span>
#     </p>
#     <p style="margin: 10px 0; color: #333; font-size: 1.05em;">
#       <strong style="color: #4B2E83;">Date:</strong> <span style="color: #666;">[05/09/26]</span>
#     </p>
#   </div>
# </div>

# %% [markdown]
# <div style="background: linear-gradient(to right, #F7F4FB, #FFFFFF); padding: 25px; border-radius: 10px; border: 2px solid #E8E0F5; margin: 25px 0;">
#   <h2 style="color: #4B2E83; font-family: 'Encode Sans', 'Arial', sans-serif; font-weight: 700; border-bottom: 3px solid #4B2E83; padding-bottom: 10px;">Table of Contents</h2>
#   <ul style="font-size: 1.05em; line-height: 2; color: #333; list-style-type: none; padding-left: 0;">
#     <li><strong>Part 1: Curse of Dimensionality</strong>
#       <ul style="list-style-type: disc; margin-left: 30px;">
#         <li>What Is High-Dimensional Space?</li>
#         <li>Distance Concentration &amp; Sparsity</li>
#         <li>Nearest-Neighbor Breakdown</li>
#         <li>Python Simulations</li>
#         <li>Exercises 1–3</li>
#       </ul>
#     </li>
#     <li><strong>Part 2: Cluster Analysis (K-Means, Hierarchical, DBSCAN)</strong>
#       <ul style="list-style-type: disc; margin-left: 30px;">
#         <li>K-Means Clustering</li>
#         <li>Hierarchical Clustering</li>
#         <li>DBSCAN</li>
#         <li>Profiling &amp; Naming Your Clusters</li>
#         <li>Visual Comparisons</li>
#         <li>Exercises 4–6</li>
#       </ul>
#     </li>
#     <li><strong>Part 3: Principal Component Analysis (PCA)</strong>
#       <ul style="list-style-type: disc; margin-left: 30px;">
#         <li>Eigenvectors, Eigenvalues &amp; Variance Maximisation</li>
#         <li>Explained Variance &amp; Biplots</li>
#         <li>Interpreting &amp; Naming Principal Components</li>
#         <li>Exercises 7–9</li>
#       </ul>
#     </li>
#     <li><strong>Part 4: Multidimensional Scaling (MDS)</strong>
#       <ul style="list-style-type: disc; margin-left: 30px;">
#         <li>Metric vs Non-Metric MDS</li>
#         <li>Stress &amp; Interpretation</li>
#         <li>Exercises 10–12</li>
#       </ul>
#     </li>
#     <li><strong>Part 5: Correspondence Analysis (CA)</strong>
#       <ul style="list-style-type: disc; margin-left: 30px;">
#         <li>Contingency Tables &amp; Chi-Square Distances</li>
#         <li>Row/Column Profiles</li>
#         <li>Exercises 13–15</li>
#       </ul>
#     </li>
#     <li><strong>Part 6: t-SNE</strong>
#       <ul style="list-style-type: disc; margin-left: 30px;">
#         <li>Local Neighbourhood Preservation</li>
#         <li>Perplexity &amp; Instability</li>
#         <li>Exercises 16–18</li>
#       </ul>
#     </li>
#     <li><strong>Part 7: UMAP</strong>
#       <ul style="list-style-type: disc; margin-left: 30px;">
#         <li>Manifold Learning &amp; Graph Structure</li>
#         <li>n_neighbors &amp; min_dist</li>
#         <li>Exercises 19–21</li>
#       </ul>
#     </li>
#     <li><strong>Part 8: Autoencoders</strong>
#       <ul style="list-style-type: disc; margin-left: 30px;">
#         <li>Encoder–Bottleneck–Decoder Architecture</li>
#         <li>Reconstruction Loss &amp; Latent Space</li>
#         <li>Exercises 22–24</li>
#       </ul>
#     </li>
#     <li><strong>Part 9: Embeddings</strong>
#       <ul style="list-style-type: disc; margin-left: 30px;">
#         <li>What Are Embeddings?</li>
#         <li>Word Embeddings &amp; Semantic Similarity</li>
#         <li>Embedding Arithmetic &amp; Analogies</li>
#         <li>Product / Customer Embeddings</li>
#         <li>Exercises 28–30</li>
#       </ul>
#     </li>
#     <li><strong>Part 10: Method Comparison &amp; Emerging Techniques</strong>
#       <ul style="list-style-type: disc; margin-left: 30px;">
#         <li>Comparison Table</li>
#         <li>Decision Guide</li>
#         <li>Emerging Methods</li>
#         <li>Exercises 25–27</li>
#       </ul>
#     </li>
#   </ul>
# </div>

# %% [markdown]
# <div style="background-color: #E8D3FF; border-left: 4px solid #4B2E83; padding: 15px 20px; margin: 20px 0; border-radius: 5px;">
#   <p style="margin: 0; color: #4B2E83; font-weight: 600;">Setup:</p>
#   <p style="margin: 10px 0 0 0; color: #333;">Run the cell below to install any missing packages and import all required libraries.</p>
# </div>

# %%
import subprocess, sys

def _install(pkg, pip_name=None):
    try:
        __import__(pkg)
    except ImportError:
        subprocess.check_call([sys.executable, "-m", "pip", "install", "-q", pip_name or pkg])

_install("sklearn", "scikit-learn")
_install("umap", "umap-learn")
_install("prince")
_install("tensorflow")

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
from scipy.spatial.distance import pdist, squareform
from scipy.cluster.hierarchy import dendrogram, linkage, fcluster

from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE, MDS
from sklearn.cluster import KMeans, DBSCAN, AgglomerativeClustering
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import silhouette_score, silhouette_samples
from sklearn.datasets import make_moons, make_blobs

import umap
import prince
import warnings
warnings.filterwarnings('ignore')

# Consistent style matching Module 4
plt.rcParams['figure.figsize'] = (10, 6)
plt.rcParams['axes.prop_cycle'] = plt.cycler(
    color=['#4B2E83', '#E8B923', '#32006E', '#85714D', '#B7A6D5',
           '#C62828', '#1976D2', '#F57C00', '#388E3C', '#7B1FA2'])
plt.rcParams['axes.facecolor'] = 'white'
plt.rcParams['figure.facecolor'] = 'white'
plt.rcParams['font.size'] = 12

UW_PURPLE = '#4B2E83'
UW_GOLD   = '#E8B923'
UW_DARK   = '#32006E'

np.random.seed(42)
print('Setup complete \u2713')
# Out:
# Setup complete ✓

# %% [markdown]
# <div style="background: linear-gradient(135deg, #4B2E83 0%, #32006E 100%); padding: 30px; border-radius: 10px; margin: 40px 0 30px 0; box-shadow: 0 5px 15px rgba(75,46,131,0.2);">
#   <h1 style="color: #FFF; font-family: 'Encode Sans', 'Arial', sans-serif; font-weight: 700; margin: 0; text-shadow: 2px 2px 4px rgba(0,0,0,0.3);">Part 1: Curse of Dimensionality</h1>
#   <p style="color: #E8D3FF; font-family: 'Encode Sans', 'Arial', sans-serif; font-size: 1.3em; margin: 10px 0; font-weight: 300;">Why More Features Can Mean Less Information</p>
# </div>

# %% [markdown]
# <div style="border-left: 5px solid #4B2E83; background-color: #F9F7FC; padding: 20px 25px; margin: 20px 0; border-radius: 5px;">
#   <h2 style="color: #4B2E83; font-family: 'Encode Sans', 'Arial', sans-serif; margin-top: 0;">A. Learning Objectives</h2>
#   <p style="font-size: 1.05em; color: #555; line-height: 1.7;">After completing this section you should be able to:</p>
#   <ul style="color:#333; line-height:1.8;">
#     <li>Define high-dimensional space and explain why it behaves differently from low-dimensional space.</li>
#     <li>Demonstrate <strong>distance concentration</strong> — the phenomenon where all pairwise distances converge to the same value.</li>
#     <li>Explain <strong>sparsity</strong>: why data points become increasingly isolated as dimensions grow.</li>
#     <li>Show how <strong>nearest-neighbour</strong> algorithms degrade in high dimensions.</li>
#     <li>Recognise the risks of <strong>overfitting</strong>, irrelevant variables, and computational burden.</li>
#     <li>Apply practical strategies (feature selection, dimensionality reduction) to mitigate these effects.</li>
#   </ul>
# </div>

# %% [markdown]
# <div style="border-left: 5px solid #4B2E83; background-color: #F9F7FC; padding: 20px 25px; margin: 20px 0; border-radius: 5px;">
#   <h2 style="color: #4B2E83; font-family: 'Encode Sans', 'Arial', sans-serif; margin-top: 0;">B. Definition — The Curse of Dimensionality</h2>
#   <p style="font-size: 1.05em; color: #555; line-height: 1.7;">
#     The <strong>curse of dimensionality</strong> (coined by Richard Bellman, 1961) refers to a collection of phenomena that arise when data live in a space with a large number of features <em>p</em>.
#   </p>
#   <p style="font-size: 1.05em; color: #555; line-height: 1.7;">Formally, consider <em>n</em> data points in &#8477;<sup>p</sup>. As <em>p</em> grows:</p>
#   <ol style="color:#333; line-height:1.8;">
#     <li><strong>Volume explosion:</strong> The volume of a unit hypercube grows as 1<sup>p</sup> = 1, but the volume of the inscribed hypersphere shrinks to zero. Most of the space is in the "corners".</li>
#     <li><strong>Distance concentration:</strong> For random points <strong>x</strong><sub>i</sub>, the ratio (max distance − min distance) / min distance → 0 as p → ∞. All points become equidistant.</li>
#     <li><strong>Sample sparsity:</strong> To maintain the same density of observations, you need exponentially more data: n ∝ k<sup>p</sup>.</li>
#   </ol>
#   <p style="font-size: 1.05em; color: #555; line-height: 1.7;">
#     <strong>Key consequence:</strong> Algorithms that rely on local structure — nearest neighbours, kernel methods, density estimation — lose their power because "local" becomes meaningless when every point is equally far from every other point.
#   </p>
# </div>

# %% [markdown]
# <div style="border-left: 5px solid #4B2E83; background-color: #F9F7FC; padding: 20px 25px; margin: 20px 0; border-radius: 5px;">
#   <h2 style="color: #4B2E83; font-family: 'Encode Sans', 'Arial', sans-serif; margin-top: 0;">C. Intuition — Why Data Become "Far Apart"</h2>
#   <p style="font-size: 1.05em; color: #555; line-height: 1.7;">
#     <strong>The Party Analogy:</strong> Imagine a small room (2D) with 20 people — it feels crowded, and you can tell who your nearest neighbours are. Now imagine the same 20 people in a giant warehouse (3D) — they spread out and it is harder to find your closest person. Now imagine a <em>hyper-warehouse</em> with 100 dimensions: the 20 people are so spread out that <em>everyone is roughly the same distance from everyone else</em>.
#   </p>
#   <p style="font-size: 1.05em; color: #555; line-height: 1.7;">
#     <strong>Practical effects:</strong>
#   </p>
#   <ul style="color:#333; line-height:1.8;">
#     <li><strong>K-Nearest Neighbours:</strong> When all distances are equal, the "nearest" neighbour is essentially random.</li>
#     <li><strong>Overfitting:</strong> With many features and few samples, a model can always find spurious patterns.</li>
#     <li><strong>Irrelevant variables:</strong> Adding noisy features drowns out the signal in the useful features.</li>
#     <li><strong>Computational burden:</strong> Distance calculations scale as O(np), storage scales as O(np).</li>
#   </ul>
# </div>

# %% [markdown]
# <div style="border-left: 5px solid #4B2E83; background-color: #F9F7FC; padding: 20px 25px; margin: 20px 0; border-radius: 5px;">
#   <h2 style="color: #4B2E83; font-family: 'Encode Sans', 'Arial', sans-serif; margin-top: 0;">D. When to Worry About the Curse</h2>
#   <table style="width:100%; border-collapse: collapse; margin-top:10px;">
#     <tr style="background-color: #4B2E83; color: white;">
#       <th style="padding:10px; text-align:left;">Aspect</th>
#       <th style="padding:10px; text-align:left;">Details</th>
#     </tr>
#     <tr style="border-bottom:1px solid #ddd;">
#       <td style="padding:10px;"><strong>Best use cases for awareness</strong></td>
#       <td style="padding:10px;">Any dataset where p &gt; n, genomics, NLP bag-of-words, sensor arrays, survey data with hundreds of questions</td>
#     </tr>
#     <tr style="border-bottom:1px solid #ddd;">
#       <td style="padding:10px;"><strong>Assumptions</strong></td>
#       <td style="padding:10px;">Methods assume "local" structure exists — curse violates this</td>
#     </tr>
#     <tr style="border-bottom:1px solid #ddd;">
#       <td style="padding:10px;"><strong>Strengths of awareness</strong></td>
#       <td style="padding:10px;">Motivates feature selection, PCA, regularisation, manifold methods</td>
#     </tr>
#     <tr style="border-bottom:1px solid #ddd;">
#       <td style="padding:10px;"><strong>Limitations</strong></td>
#       <td style="padding:10px;">Not all high-dimensional data suffer equally — if the data lie on a low-dimensional manifold, methods like UMAP and t-SNE can recover structure</td>
#     </tr>
#     <tr>
#       <td style="padding:10px;"><strong>Common mistakes</strong></td>
#       <td style="padding:10px;">Blindly adding features, not scaling, using Euclidean distance in 1000+ dimensions, ignoring collinearity</td>
#     </tr>
#   </table>
# </div>

# %% [markdown]
# <div style="border-left: 5px solid #4B2E83; background-color: #F9F7FC; padding: 20px 25px; margin: 20px 0; border-radius: 5px;">
#   <h2 style="color: #4B2E83; font-family: 'Encode Sans', 'Arial', sans-serif; margin-top: 0;">E. Python Demonstrations</h2>
# </div>

# %% [markdown]
# <div style="border-left: 5px solid #4B2E83; background-color: #F9F7FC; padding: 20px 25px; margin: 20px 0; border-radius: 5px;">
#   <h3 style="color: #4B2E83;">Example 1.1 — Distance Concentration (Simulation)</h3>
#   <p style="color:#555;"><strong>Question:</strong> How does the spread of pairwise distances change as we increase the number of dimensions from 2 to 500?</p>
# </div>

# %%
# Example 1.1 — Distance Concentration in High Dimensions
dims = [2, 5, 10, 50, 100, 500]
n_points = 200

fig, axes = plt.subplots(2, 3, figsize=(15, 9))
axes = axes.ravel()

for idx, d in enumerate(dims):
    X = np.random.uniform(0, 1, size=(n_points, d))
    dists = pdist(X, metric='euclidean')

    # Relative contrast: (max - min) / min
    contrast = (dists.max() - dists.min()) / dists.min()

    axes[idx].hist(dists, bins=40, color=UW_PURPLE, alpha=0.7, edgecolor='white')
    axes[idx].set_title(f'p = {d}   (contrast = {contrast:.2f})',
                        fontsize=12, fontweight='bold', color=UW_PURPLE)
    axes[idx].set_xlabel('Euclidean Distance')
    axes[idx].set_ylabel('Frequency')

fig.suptitle('Distance Concentration as Dimensions Increase',
             fontsize=16, fontweight='bold', color=UW_DARK, y=1.02)
plt.tight_layout()
plt.show()

print("\nInterpretation: As dimensions grow, the histogram narrows relative to its")
print("centre — the contrast ratio drops, meaning max and min distances converge.")
print("All points become nearly equidistant, breaking nearest-neighbour methods.")
# Out:
# Interpretation: As dimensions grow, the histogram narrows relative to its
# centre — the contrast ratio drops, meaning max and min distances converge.
# All points become nearly equidistant, breaking nearest-neighbour methods.

# %% [markdown]
# <div style="border-left: 5px solid #4B2E83; background-color: #F9F7FC; padding: 20px 25px; margin: 20px 0; border-radius: 5px;">
#   <h3 style="color: #4B2E83;">Example 1.2 — High Dimensions in Practice: Caravan Insurance (86 features)</h3>
#   <p style="color:#555;"><strong>Dataset:</strong> <a href="https://github.com/PedroBSB/BDATA200/tree/main/Data">Caravan.csv</a> — 5,822 customers described by 86 socio-demographic and product-ownership variables.</p>
#   <p style="color:#555;"><strong>Question:</strong> Does KNN performance degrade when we use all 86 features vs a selected subset?</p>
# </div>

# %%
# Example 1.2 — KNN on Caravan: all features vs subset
caravan = pd.read_csv('https://raw.githubusercontent.com/PedroBSB/BDATA200/main/Data/Caravan.csv')

# Binary target: 'Purchase' (Yes/No)
y = (caravan['Purchase'] == 'Yes').astype(int).values
X = caravan.drop(columns=['Purchase']).select_dtypes(include=[np.number]).values

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Split: first 4000 train, rest test
X_train, X_test = X_scaled[:4000], X_scaled[4000:]
y_train, y_test = y[:4000], y[4000:]

# All 85 features
knn_all = KNeighborsClassifier(n_neighbors=5)
knn_all.fit(X_train, y_train)
acc_all = knn_all.score(X_test, y_test)

# Top 10 features by variance
variances = X_scaled.var(axis=0)
top10_idx = np.argsort(variances)[-10:]
knn_sub = KNeighborsClassifier(n_neighbors=5)
knn_sub.fit(X_train[:, top10_idx], y_train)
acc_sub = knn_sub.score(X_test[:, top10_idx], y_test)

fig, ax = plt.subplots(figsize=(8, 5))
bars = ax.bar(['All 85 features', 'Top 10 features'],
              [acc_all, acc_sub],
              color=[UW_PURPLE, UW_GOLD], edgecolor='white', width=0.5)
ax.set_ylabel('Test Accuracy', fontsize=13)
ax.set_title('KNN Accuracy: All Features vs Top 10',
             fontsize=15, fontweight='bold', color=UW_DARK)
for b in bars:
    ax.text(b.get_x() + b.get_width()/2, b.get_height() + 0.005,
            f'{b.get_height():.3f}', ha='center', fontsize=13, fontweight='bold')
ax.set_ylim(0, 1.05)
plt.tight_layout()
plt.show()

print(f"\nWith 85 noisy features many are irrelevant, adding noise to distances.")
print(f"Reducing to 10 high-variance features can improve or maintain accuracy")
print(f"while cutting computation by ~88%.")
# Out:
# With 85 noisy features many are irrelevant, adding noise to distances.
# Reducing to 10 high-variance features can improve or maintain accuracy
# while cutting computation by ~88%.

# %% [markdown]
# <div style="border-left: 5px solid #4B2E83; background-color: #F9F7FC; padding: 20px 25px; margin: 20px 0; border-radius: 5px;">
#   <h3 style="color: #4B2E83;">Example 1.3 — Sparsity Visualisation: College Dataset</h3>
#   <p style="color:#555;"><strong>Dataset:</strong> <a href="https://github.com/PedroBSB/BDATA200/tree/main/Data">College.csv</a> — 777 US colleges with 17 numeric features.</p>
#   <p style="color:#555;"><strong>Question:</strong> How does adding random noise features affect the nearest-neighbour distance ratio?</p>
# </div>

# %%
# Example 1.3 — Adding noise features to College data
college = pd.read_csv('https://raw.githubusercontent.com/PedroBSB/BDATA200/main/Data/College.csv')
X_college = college.select_dtypes(include=[np.number]).values
X_college = StandardScaler().fit_transform(X_college)

added_dims = [0, 10, 50, 100, 200, 500]
nn_ratios = []

for extra in added_dims:
    if extra > 0:
        noise = np.random.normal(0, 1, size=(X_college.shape[0], extra))
        X_aug = np.hstack([X_college, noise])
    else:
        X_aug = X_college.copy()

    dists = pdist(X_aug)
    ratio = (dists.max() - dists.min()) / dists.min()
    nn_ratios.append(ratio)

total_dims = [X_college.shape[1] + d for d in added_dims]

fig, ax = plt.subplots(figsize=(10, 5))
ax.plot(total_dims, nn_ratios, 'o-', color=UW_PURPLE, linewidth=2.5, markersize=9)
ax.set_xlabel('Total Number of Features', fontsize=13)
ax.set_ylabel('Distance Contrast Ratio', fontsize=13)
ax.set_title('Distance Contrast Drops as Noise Features Are Added',
             fontsize=15, fontweight='bold', color=UW_DARK)
ax.axhline(1.0, color=UW_GOLD, linestyle='--', linewidth=1, label='Contrast = 1 (danger zone)')
ax.legend(fontsize=11)
plt.tight_layout()
plt.show()

print("\nInterpretation: Starting with 17 real features, each batch of random noise")
print("dimensions lowers the contrast ratio, making it harder to distinguish")
print("near from far points — the essence of the curse.")
# Out:
# Interpretation: Starting with 17 real features, each batch of random noise
# dimensions lowers the contrast ratio, making it harder to distinguish
# near from far points — the essence of the curse.

# %% [markdown]
# <div style="background-color: #FFF3E0; border-left: 4px solid #F57C00; padding: 15px 20px; margin: 20px 0; border-radius: 5px;">
#   <h3 style="color: #F57C00; margin-top: 0;">Exercise 1 — Simulate the Curse of Dimensionality</h3>
# </div>
#
# **Task:** Generate 100 random points in dimensions p = 2, 10, 50, 200, 1000.
# For each value of p, compute all pairwise Euclidean distances and calculate:
# 1. The **mean distance**
# 2. The **standard deviation of distances**
# 3. The **contrast ratio** (max − min) / min
#
# Plot all three metrics vs p on a single figure with three subplots. Explain what happens and why.

# %%
# Exercise 1 — Your solution below
n_points = 100
dims = [2, 10, 50, 200, 1000]

import numpy as np
import matplotlib.pyplot as plt
from scipy.spatial.distance import pdist

num_points = 100
dimensions = [2, 10, 50, 200, 1000]

avg_distances = []
distance_stds = []
contrast_values = []

for dim in dimensions:

    # Random dataset
    data = np.random.random((num_points, dim))

    # Pairwise Euclidean distances
    pairwise = pdist(data, metric='euclidean')

    # Metrics
    avg_dist = pairwise.mean()
    std_dist = pairwise.std()
    contrast = (pairwise.max() - pairwise.min()) / pairwise.min()

    # Store results
    avg_distances.append(avg_dist)
    distance_stds.append(std_dist)
    contrast_values.append(contrast)

# Plotting
fig, ax = plt.subplots(3, 1, figsize=(8, 12))

# Mean distance
ax[0].plot(dimensions, avg_distances, marker='s')
ax[0].set_title("Average Distance Across Dimensions")
ax[0].set_xlabel("Number of Dimensions")
ax[0].set_ylabel("Average Distance")

# Standard deviation
ax[1].plot(dimensions, distance_stds, marker='^')
ax[1].set_title("Distance Standard Deviation")
ax[1].set_xlabel("Number of Dimensions")
ax[1].set_ylabel("Std Distance")

# Contrast ratio
ax[2].plot(dimensions, contrast_values, marker='d')
ax[2].set_title("Contrast Ratio")
ax[2].set_xlabel("Number of Dimensions")
ax[2].set_ylabel("(Max - Min) / Min")

plt.tight_layout()
plt.show()

# %% [markdown]
# *Write your interpretation here.*
#
# 1. **What happens to mean distance as p grows?** — As p increases, mean distance increases because there are more dimensions in which the random points can differ.
# 2. **What happens to std of distances?** — Since the standard deviation increases more slowly than the mean distance, the distances start to cluster more tightly around their mean (as a percentage of the mean).
# 3. **Why does contrast ratio drop?** — Contrast falls because it becomes difficult to tell the difference between near and far points as the number of dimensions grows. Later, nearly every point is roughly the same distance from every other point.

# %% [markdown]
# <div style="background-color: #FFF3E0; border-left: 4px solid #F57C00; padding: 15px 20px; margin: 20px 0; border-radius: 5px;">
#   <h3 style="color: #F57C00; margin-top: 0;">Exercise 2 — KNN in Low vs High Dimensions</h3>
# </div>
#
# **Task:** Using the **Heart.csv** dataset:
# 1. Scale all numeric features.
# 2. Train a KNN classifier (k=5) predicting `AHD` using only the first 2 features.
# 3. Train another KNN using **all** numeric features.
# 4. Now add 50 columns of pure random noise and train KNN again.
# 5. Compare the three test accuracies in a bar chart. Explain your findings.

# %%
# Exercise 2 — Your solution below
heart = pd.read_csv('https://raw.githubusercontent.com/PedroBSB/BDATA200/main/Data/Heart.csv').dropna()

# --- Your code here ---
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score

# Load Heart dataset
heart = pd.read_csv("https://raw.githubusercontent.com/PedroBSB/BDATA200/main/Data/Heart.csv").dropna()

# Clean column names
heart.columns = heart.columns.str.strip()

# Select numeric features only
# The 'target' column is already numeric (0 or 1)
X = heart.select_dtypes(include=np.number).drop("target", axis=1)
y = heart["target"]

# Scale features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Train/test split
X_train, X_test, y_train, y_test = train_test_split(
    X_scaled, y, test_size=0.30, random_state=42
)

# Model 1: First 2 features
knn_2 = KNeighborsClassifier(n_neighbors=5)
knn_2.fit(X_train[:, :2], y_train)
acc_2 = accuracy_score(y_test, knn_2.predict(X_test[:, :2]))

# Model 2: All real features
knn_all = KNeighborsClassifier(n_neighbors=5)
knn_all.fit(X_train, y_train)
acc_all = accuracy_score(y_test, knn_all.predict(X_test))

# Model 3: Real features + 50 noise columns
np.random.seed(42)
noise_train = np.random.normal(0, 1, size=(X_train.shape[0], 50))
noise_test = np.random.normal(0, 1, size=(X_test.shape[0], 50))

X_train_noise = np.hstack([X_train, noise_train])
X_test_noise = np.hstack([X_test, noise_test])

knn_noise = KNeighborsClassifier(n_neighbors=5)
knn_noise.fit(X_train_noise, y_train)
acc_noise = accuracy_score(y_test, knn_noise.predict(X_test_noise))

# Bar chart
models = ["First 2 Features", "All Real Features", "Real + 50 Noise"]
accuracies = [acc_2, acc_all, acc_noise]
colors = ["#4B2E83", "#F2C120", "#C92828"]

plt.figure(figsize=(10, 6))
bars = plt.bar(models, accuracies, color=colors)

plt.title("KNN Performance: Effect of Dimensionality and Noise", fontsize=16, fontweight="bold")
plt.ylabel("Test Accuracy", fontsize=13)
plt.ylim(0, 1)

# Add accuracy labels above bars
for bar, acc in zip(bars, accuracies):
    plt.text(
        bar.get_x() + bar.get_width() / 2,
        bar.get_height() + 0.02,
        round(acc, 3),
        ha="center",
        fontsize=13,
        fontweight="bold"
    )

plt.show()

print("First 2 Features Accuracy:", round(acc_2, 3))
print("All Real Features Accuracy:", round(acc_all, 3))
print("Real + 50 Noise Accuracy:", round(acc_noise, 3))
# Out:
# First 2 Features Accuracy: 0.611
# All Real Features Accuracy: 0.833
# Real + 50 Noise Accuracy: 0.778

# %% [markdown]
# *Write your interpretation here.*
#
# 1. **Which model performed best and why?** — The first model using all real features performed best. It had the most information about the patients for KNN to go on and accurately distinguish heart disease.
# 2. **Why did adding noise features hurt?** — Noise features hurt my model because they were random information that did not pertain to the patients. Adding noise made the points farther apart than they should be since KNN uses distance. It decreased the reliability of finding nearest neighbors.
# 3. **What does this teach about feature selection?** — This taught me that feature selection is crucial when creating machine learning models. Features that are related to the response allow the model to make more accurate predictions. Features that do not matter can unnecessarily increase dimension.
# Sentence Variations
# 6/20
# Features that are related to the response allow the model to make more accurate predictions.The model can predict more accurately when it has access to features directly tied to the outcome.When features are relevant to the response, the model's predictive power improves.Accurate predictions are facilitated by features that bear a relationship to the response variable.The model achieves better predictive accuracy by utilizing features linked to the response.More precise predictions become possible when the model is fed features that correlate with the response.Generate More

# %% [markdown]
# <div style="background-color: #FFF3E0; border-left: 4px solid #F57C00; padding: 15px 20px; margin: 20px 0; border-radius: 5px;">
#   <h3 style="color: #F57C00; margin-top: 0;">Exercise 3 — Remove Noisy Features and Compare Performance</h3>
# </div>
#
# **Task:** Using the **Caravan.csv** dataset:
# 1. Compute the correlation of each feature with the target variable `Purchase`.
# 2. Select only the top 15 features by absolute correlation.
# 3. Train KNN (k=5) on all features vs the top-15 subset.
# 4. Report accuracy and F1-score for both.
# 5. Time both models using `%%timeit` or `time.time()`.
#
# Discuss: Does removing low-signal features help accuracy? Does it help speed?

# %%
# Exercise 3 — Your solution below
import time
caravan = pd.read_csv('https://raw.githubusercontent.com/PedroBSB/BDATA200/main/Data/Caravan.csv')

# --- Your code here ---
import pandas as pd
import numpy as np
import time
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, f1_score

# Load Caravan dataset
data = pd.read_csv(
    "https://raw.githubusercontent.com/PedroBSB/BDATA200/main/Data/Caravan.csv"
)

# Clean column names
data.columns = data.columns.str.strip()

# Convert target to numeric
data["Purchase"] = data["Purchase"].map({"Yes": 1, "No": 0})

# Separate input features and target
features = data.drop("Purchase", axis=1)
target = data["Purchase"]

# Find strongest features using absolute correlation
feature_corr = features.corrwith(target).abs()
best_features = feature_corr.sort_values(ascending=False).head(15).index.tolist()

# Create full feature set and reduced feature set
X_full = features
X_selected = features[best_features]

# Scale both datasets
full_scaler = StandardScaler()
selected_scaler = StandardScaler()

X_full_scaled = full_scaler.fit_transform(X_full)
X_selected_scaled = selected_scaler.fit_transform(X_selected)

# Split into training and testing data
X_full_train, X_full_test, y_train, y_test = train_test_split(
    X_full_scaled, target, test_size=0.30, random_state=24
)

X_sel_train, X_sel_test, _, _ = train_test_split(
    X_selected_scaled, target, test_size=0.30, random_state=24
)

# -----------------------------
# KNN using all features
# -----------------------------
start_full = time.time()

model_full = KNeighborsClassifier(n_neighbors=5)
model_full.fit(X_full_train, y_train)
pred_full = model_full.predict(X_full_test)

full_time = time.time() - start_full
full_accuracy = accuracy_score(y_test, pred_full)
full_f1 = f1_score(y_test, pred_full)

# -----------------------------
# KNN using top 15 features
# -----------------------------
start_selected = time.time()

model_selected = KNeighborsClassifier(n_neighbors=5)
model_selected.fit(X_sel_train, y_train)
pred_selected = model_selected.predict(X_sel_test)

selected_time = time.time() - start_selected
selected_accuracy = accuracy_score(y_test, pred_selected)
selected_f1 = f1_score(y_test, pred_selected)

# Print results
print("Top 15 Selected Features:")
print(best_features)

print("\nAll Features Accuracy:", round(full_accuracy, 3))
print("Top 15 Features Accuracy:", round(selected_accuracy, 3))

print("\nAll Features F1-Score:", round(full_f1, 3))
print("Top 15 Features F1-Score:", round(selected_f1, 3))

print("\nAll Features Time:", round(full_time, 4), "seconds")
print("Top 15 Features Time:", round(selected_time, 4), "seconds")

# -----------------------------
# Visual comparison
# -----------------------------
categories = ["All Features", "Top 15 Features"]
purple_yellow = ["#4B2E83", "#F2C120"]

acc_scores = [full_accuracy, selected_accuracy]
f1_scores = [full_f1, selected_f1]
run_times = [full_time, selected_time]

fig, ax = plt.subplots(1, 3, figsize=(16, 5))

ax[0].bar(categories, acc_scores, color=purple_yellow)
ax[0].set_title("Accuracy")
ax[0].set_ylabel("Score")
ax[0].set_ylim(0, 1)

ax[1].bar(categories, f1_scores, color=purple_yellow)
ax[1].set_title("F1-Score")
ax[1].set_ylabel("Score")
ax[1].set_ylim(0, 1)

ax[2].bar(categories, run_times, color=purple_yellow)
ax[2].set_title("Model Runtime")
ax[2].set_ylabel("Seconds")

plt.suptitle("KNN: All Features vs Top 15 Correlated Features", fontsize=14, fontweight="bold")
plt.tight_layout()
plt.show()
# Out:
# Top 15 Selected Features:
# ['PPERSAUT', 'APERSAUT', 'APLEZIER', 'PWAPART', 'MKOOPKLA', 'PBRAND', 'PPLEZIER', 'MOPLLAAG', 'MINKGEM', 'AWAPART', 'MOPLHOOG', 'MINKM30', 'MHHUUR', 'MHKOOP', 'MAUT0']
#
# All Features Accuracy: 0.93
# Top 15 Features Accuracy: 0.935
#
# All Features F1-Score: 0.047
# Top 15 Features F1-Score: 0.109
#
# All Features Time: 0.072 seconds
# Top 15 Features Time: 0.1503 seconds

# %% [markdown]
# *Write your interpretation here.*
#
# 1. **Accuracy comparison** — Both the top-15 feature model and all-features model achieved nearly identical accuracy. This indicates that the top correlated features were able to retain most of the informative signals for making predictions.
#
# 2. **F1-score comparison** — Both models had similar F1-scores. This suggests that using fewer features did not hurt the balance of precision and recall.
#
# 3. **Speed comparison** — The pared down model ran faster. KNN was able to run faster because it had less columns to compute distances between data points.
# 4. **Practical recommendation** — Selected features. Selected features help to reduce model complexity, increase speed, and improve human interpretability without sacrificing performance.

# %% [markdown]
# <div style="background: linear-gradient(135deg, #4B2E83 0%, #32006E 100%); padding: 30px; border-radius: 10px; margin: 40px 0 30px 0; box-shadow: 0 5px 15px rgba(75,46,131,0.2);">
#   <h1 style="color: #FFF; font-family: 'Encode Sans', 'Arial', sans-serif; font-weight: 700; margin: 0; text-shadow: 2px 2px 4px rgba(0,0,0,0.3);">Part 2: Cluster Analysis</h1>
#   <p style="color: #E8D3FF; font-family: 'Encode Sans', 'Arial', sans-serif; font-size: 1.3em; margin: 10px 0; font-weight: 300;">K-Means, Hierarchical Clustering &amp; DBSCAN</p>
# </div>

# %% [markdown]
# <div style="border-left: 5px solid #4B2E83; background-color: #F9F7FC; padding: 20px 25px; margin: 20px 0; border-radius: 5px;">
#   <h2 style="color: #4B2E83; font-family: 'Encode Sans', 'Arial', sans-serif; margin-top: 0;">A. Learning Objectives</h2>
#   <ul style="color:#333; line-height:1.8;">
#     <li>Understand the goal of clustering: grouping similar observations without labels.</li>
#     <li>Explain the <strong>K-Means</strong> algorithm (Lloyd's algorithm), centroid minimisation, and within-cluster variance.</li>
#     <li>Distinguish <strong>agglomerative vs divisive</strong> hierarchical clustering and interpret dendrograms.</li>
#     <li>Understand <strong>DBSCAN</strong>'s density-based approach, eps, min_samples, and noise detection.</li>
#     <li>Choose the right clustering method for a given data shape and business question.</li>
#   </ul>
# </div>

# %% [markdown]
# <div style="border-left: 5px solid #4B2E83; background-color: #F9F7FC; padding: 20px 25px; margin: 20px 0; border-radius: 5px;">
#   <h2 style="color: #4B2E83; font-family: 'Encode Sans', 'Arial', sans-serif; margin-top: 0;">B. Definitions</h2>
#
#   <h3 style="color: #32006E;">K-Means Clustering</h3>
#   <p style="font-size: 1.05em; color: #555; line-height: 1.7;">
#     K-Means partitions <em>n</em> observations into <em>K</em> clusters by minimising the <strong>within-cluster sum of squares (WCSS)</strong>:
#   </p>
#   <p style="text-align:center; font-size:1.15em; color:#333;">
#     WCSS = &Sigma;<sub>k=1</sub><sup>K</sup> &Sigma;<sub>x&isin;C<sub>k</sub></sub> ||x &minus; &mu;<sub>k</sub>||<sup>2</sup>
#   </p>
#   <p style="font-size: 1.05em; color: #555; line-height: 1.7;">
#     <strong>Lloyd's Algorithm:</strong> (1) Initialise K centroids randomly. (2) Assign each point to its nearest centroid. (3) Recompute centroids as cluster means. (4) Repeat until convergence.
#   </p>
#
#   <h3 style="color: #32006E;">Hierarchical Clustering</h3>
#   <p style="font-size: 1.05em; color: #555; line-height: 1.7;">
#     <strong>Agglomerative</strong> (bottom-up): Start with each point as its own cluster, then iteratively merge the two closest clusters. <strong>Divisive</strong> (top-down): Start with one cluster and recursively split. The result is a <strong>dendrogram</strong> — a tree that shows the merge/split sequence and distances.
#   </p>
#   <p style="font-size: 1.05em; color: #555; line-height: 1.7;">
#     <strong>Linkage methods:</strong> single (min distance), complete (max distance), average, Ward (minimises WCSS increase).
#   </p>
#
#   <h3 style="color: #32006E;">DBSCAN</h3>
#   <p style="font-size: 1.05em; color: #555; line-height: 1.7;">
#     Density-Based Spatial Clustering of Applications with Noise. A point is a <strong>core point</strong> if at least <code>min_samples</code> points lie within distance <code>eps</code>. Core points that are within eps of each other form a cluster. Points that are not core and not reachable from any core point are labelled <strong>noise</strong> (label = −1).
#   </p>
# </div>

# %% [markdown]
# <div style="border-left: 5px solid #4B2E83; background-color: #F9F7FC; padding: 20px 25px; margin: 20px 0; border-radius: 5px;">
#   <h2 style="color: #4B2E83; font-family: 'Encode Sans', 'Arial', sans-serif; margin-top: 0;">C. Intuition</h2>
#   <ul style="color:#333; line-height:1.8;">
#     <li><strong>K-Means</strong> is like placing K magnets on a table of iron filings — each filing snaps to the nearest magnet, and the magnets slide to the centre of their group. Repeat until stable.</li>
#     <li><strong>Hierarchical</strong> is like building a family tree: at the bottom are individuals, and as you go up you group siblings, then cousins, then extended family. The dendrogram is the family tree.</li>
#     <li><strong>DBSCAN</strong> is like a party: clusters form wherever people stand close together in a crowd. Loners standing far from any group are "noise".</li>
#   </ul>
# </div>

# %% [markdown]
# <div style="border-left: 5px solid #4B2E83; background-color: #F9F7FC; padding: 20px 25px; margin: 20px 0; border-radius: 5px;">
#   <h2 style="color: #4B2E83; font-family: 'Encode Sans', 'Arial', sans-serif; margin-top: 0;">D. When to Use Each Method</h2>
#   <table style="width:100%; border-collapse: collapse; margin-top:10px;">
#     <tr style="background-color: #4B2E83; color: white;">
#       <th style="padding:10px;">Method</th>
#       <th style="padding:10px;">Best For</th>
#       <th style="padding:10px;">Avoid When</th>
#       <th style="padding:10px;">Key Weakness</th>
#     </tr>
#     <tr style="border-bottom:1px solid #ddd;">
#       <td style="padding:10px;"><strong>K-Means</strong></td>
#       <td style="padding:10px;">Spherical, equal-size clusters; large n</td>
#       <td style="padding:10px;">Irregular shapes, outliers, unknown K</td>
#       <td style="padding:10px;">Must specify K; sensitive to initialisation</td>
#     </tr>
#     <tr style="border-bottom:1px solid #ddd;">
#       <td style="padding:10px;"><strong>Hierarchical</strong></td>
#       <td style="padding:10px;">Small-to-medium n; need dendrogram; uncertain K</td>
#       <td style="padding:10px;">Very large n (O(n&sup2;) or O(n&sup3;))</td>
#       <td style="padding:10px;">Slow; merges are irreversible</td>
#     </tr>
#     <tr>
#       <td style="padding:10px;"><strong>DBSCAN</strong></td>
#       <td style="padding:10px;">Irregular shapes, noise/outlier detection</td>
#       <td style="padding:10px;">Clusters of very different densities</td>
#       <td style="padding:10px;">Sensitive to eps/min_samples; no guarantee on cluster count</td>
#     </tr>
#   </table>
# </div>

# %% [markdown]
# <div style="border-left: 5px solid #4B2E83; background-color: #F9F7FC; padding: 20px 25px; margin: 20px 0; border-radius: 5px;">
#   <h2 style="color: #4B2E83; font-family: 'Encode Sans', 'Arial', sans-serif; margin-top: 0;">E. Python Demonstrations</h2>
# </div>

# %% [markdown]
# <div style="border-left: 5px solid #4B2E83; background-color: #F9F7FC; padding: 20px 25px; margin: 20px 0; border-radius: 5px;">
#   <h3 style="color: #4B2E83;">Example 2.1 — K-Means Customer Segmentation: Credit Dataset</h3>
#   <p style="color:#555;"><strong>Dataset:</strong> <a href="https://github.com/PedroBSB/BDATA200/tree/main/Data">Credit.csv</a> — 400 customers with income, credit limit, balance, etc.</p>
#   <p style="color:#555;"><strong>Question:</strong> Can we segment customers into meaningful groups based on Income, Limit, and Balance?</p>
# </div>

# %%
# Example 2.1 — K-Means on Credit data
credit = pd.read_csv('https://raw.githubusercontent.com/PedroBSB/BDATA200/main/Data/Credit.csv')
features = ['Income', 'Limit', 'Balance']
X = credit[features].values
X_scaled = StandardScaler().fit_transform(X)

# Elbow plot
inertias = []
K_range = range(2, 11)
for k in K_range:
    km = KMeans(n_clusters=k, n_init=10, random_state=42)
    km.fit(X_scaled)
    inertias.append(km.inertia_)

fig, axes = plt.subplots(1, 3, figsize=(18, 5))

# Elbow
axes[0].plot(K_range, inertias, 'o-', color=UW_PURPLE, linewidth=2.5, markersize=8)
axes[0].set_xlabel('K', fontsize=13)
axes[0].set_ylabel('Inertia (WCSS)', fontsize=13)
axes[0].set_title('Elbow Method', fontsize=14, fontweight='bold', color=UW_DARK)

# Silhouette
sil_scores = []
for k in K_range:
    km = KMeans(n_clusters=k, n_init=10, random_state=42)
    labels = km.fit_predict(X_scaled)
    sil_scores.append(silhouette_score(X_scaled, labels))
axes[1].plot(K_range, sil_scores, 's-', color=UW_GOLD, linewidth=2.5, markersize=8)
axes[1].set_xlabel('K', fontsize=13)
axes[1].set_ylabel('Silhouette Score', fontsize=13)
axes[1].set_title('Silhouette Score', fontsize=14, fontweight='bold', color=UW_DARK)

# Final clustering with K=4
km_final = KMeans(n_clusters=4, n_init=10, random_state=42)
labels = km_final.fit_predict(X_scaled)
colors = [UW_PURPLE, UW_GOLD, '#C62828', '#388E3C']
for c in range(4):
    mask = labels == c
    axes[2].scatter(X[mask, 0], X[mask, 2], c=colors[c], label=f'Cluster {c}',
                    alpha=0.6, edgecolors='white', s=50)
axes[2].set_xlabel('Income', fontsize=13)
axes[2].set_ylabel('Balance', fontsize=13)
axes[2].set_title('K-Means Clusters (K=4)', fontsize=14, fontweight='bold', color=UW_DARK)
axes[2].legend()

plt.tight_layout()
plt.show()

print("\nInterpretation: The elbow suggests K=3 or K=4. Silhouette peaks help confirm.")
print("Clusters reveal natural customer segments: low-income/low-balance, high-income/")
print("low-balance (savers), high-income/high-balance, and moderate groups.")

# %% [markdown]
# <div style="border-left: 5px solid #4B2E83; background-color: #F9F7FC; padding: 20px 25px; margin: 20px 0; border-radius: 5px;">
#   <h2 style="color: #4B2E83; font-family: 'Encode Sans', 'Arial', sans-serif; margin-top: 0;">Profiling &amp; Naming Your Clusters</h2>
#   <p style="font-size: 1.05em; color: #555; line-height: 1.7;">
#     <strong>Critical step that many analysts skip:</strong> After running any clustering or dimensionality reduction algorithm, you <em>must</em> investigate what each group represents. A cluster labelled "Cluster 0" is meaningless to a business stakeholder. Your job is to turn numbered groups into <strong>actionable personas</strong> with descriptive names.
#   </p>
#
#   <h3 style="color: #32006E;">Why Profile?</h3>
#   <ul style="color:#333; line-height:1.8;">
#     <li>Algorithms produce groups — <em>humans</em> give them meaning.</li>
#     <li>Without profiling, you cannot validate whether the clusters are useful or artefacts.</li>
#     <li>Stakeholders (marketing, product, operations) need <strong>names they can act on</strong>.</li>
#   </ul>
#
#   <h3 style="color: #32006E;">How to Profile</h3>
#   <ol style="color:#333; line-height:1.8;">
#     <li><strong>Compute cluster statistics:</strong> mean, median, mode of each feature per cluster.</li>
#     <li><strong>Visualise differences:</strong> bar charts, radar/spider charts, heatmaps of standardised means.</li>
#     <li><strong>Compare to the overall population:</strong> Which features are above/below the global average?</li>
#     <li><strong>Name each cluster</strong> using the dominant characteristics — a good name is short, memorable, and descriptive.</li>
#   </ol>
#
#   <h3 style="color: #32006E;">Creative Cluster Names Used in Marketing</h3>
#   <p style="color: #555; line-height:1.7;">In real-world customer segmentation, analysts give clusters <strong>persona names</strong> that immediately communicate who the customer is:</p>
#   <table style="width:100%; border-collapse: collapse; margin-top:10px;">
#     <tr style="background-color: #4B2E83; color: white;">
#       <th style="padding:10px;">Persona Name</th>
#       <th style="padding:10px;">Profile Description</th>
#       <th style="padding:10px;">Key Features</th>
#     </tr>
#     <tr style="border-bottom:1px solid #ddd;">
#       <td style="padding:10px;"><strong>"Premium Loyalists"</strong></td>
#       <td style="padding:10px;">High income, frequent buyers, brand-loyal</td>
#       <td style="padding:10px;">High spend, low churn, long tenure</td>
#     </tr>
#     <tr style="border-bottom:1px solid #ddd;">
#       <td style="padding:10px;"><strong>"Budget Hunters"</strong></td>
#       <td style="padding:10px;">Price-sensitive, coupon users, wait for sales</td>
#       <td style="padding:10px;">Low avg. order, high discount usage</td>
#     </tr>
#     <tr style="border-bottom:1px solid #ddd;">
#       <td style="padding:10px;"><strong>"Window Shoppers"</strong></td>
#       <td style="padding:10px;">Browse often but rarely buy</td>
#       <td style="padding:10px;">High page views, low conversion</td>
#     </tr>
#     <tr style="border-bottom:1px solid #ddd;">
#       <td style="padding:10px;"><strong>"Sleeping Giants"</strong></td>
#       <td style="padding:10px;">High-value customers who have gone dormant</td>
#       <td style="padding:10px;">High past spend, zero recent activity</td>
#     </tr>
#     <tr style="border-bottom:1px solid #ddd;">
#       <td style="padding:10px;"><strong>"Rising Stars"</strong></td>
#       <td style="padding:10px;">New customers with rapidly increasing engagement</td>
#       <td style="padding:10px;">Short tenure, increasing frequency</td>
#     </tr>
#     <tr style="border-bottom:1px solid #ddd;">
#       <td style="padding:10px;"><strong>"Occasional Splurgers"</strong></td>
#       <td style="padding:10px;">Infrequent but high-value purchases</td>
#       <td style="padding:10px;">Low frequency, high avg. order value</td>
#     </tr>
#     <tr>
#       <td style="padding:10px;"><strong>"At-Risk Defectors"</strong></td>
#       <td style="padding:10px;">Previously active, engagement declining</td>
#       <td style="padding:10px;">Decreasing frequency, increasing complaint rate</td>
#     </tr>
#   </table>
#
#   <div style="background-color: #FFF3E0; border: 2px solid #F57C00; padding: 15px; border-radius: 5px; margin-top:15px;">
#     <p style="margin:0; color:#C62828; font-weight:bold;">Golden Rule:</p>
#     <p style="margin:5px 0 0 0; color:#333;">If you cannot explain what a cluster represents in one sentence, either the cluster is not meaningful or you have not profiled it deeply enough. <strong>Always profile. Always name.</strong></p>
#   </div>
# </div>

# %% [markdown]
# <div style="border-left: 5px solid #4B2E83; background-color: #F9F7FC; padding: 20px 25px; margin: 20px 0; border-radius: 5px;">
#   <h3 style="color: #4B2E83;">Example 2.1b — Profiling &amp; Naming the Credit Clusters</h3>
#   <p style="color:#555;">Continuing from Example 2.1 — let's profile each K-Means cluster and assign meaningful names.</p>
# </div>

# %%
# Example 2.1b — Profiling the K-Means clusters from Example 2.1
credit = pd.read_csv('https://raw.githubusercontent.com/PedroBSB/BDATA200/main/Data/Credit.csv')
features = ['Income', 'Limit', 'Rating', 'Balance', 'Cards', 'Age']
X = credit[features].values
X_scaled = StandardScaler().fit_transform(X)

km = KMeans(n_clusters=4, n_init=10, random_state=42)
labels = km.fit_predict(X_scaled)
credit['Cluster'] = labels

# --- Step 1: Compute cluster means ---
profile = credit.groupby('Cluster')[features].mean().round(1)
print("=== Cluster Profiles (Mean Values) ===")
print(profile.to_string())
print()

# --- Step 2: Compare to global mean ---
global_mean = credit[features].mean()
profile_vs_global = (profile - global_mean).round(1)
print("=== Deviation from Global Mean ===")
print(profile_vs_global.to_string())
print()

# --- Step 3: Visualise with a heatmap of standardised means ---
profile_z = (profile - global_mean) / credit[features].std()

fig, axes = plt.subplots(1, 2, figsize=(18, 6))

# Heatmap
sns.heatmap(profile_z.T, annot=True, fmt='.2f', cmap='PuOr', center=0,
            ax=axes[0], cbar_kws={'shrink': 0.8},
            xticklabels=[f'Cluster {i}' for i in range(4)])
axes[0].set_title('Cluster Profiles: Standardised Deviation from Mean',
                  fontsize=14, fontweight='bold', color=UW_DARK)
axes[0].set_ylabel('')

# Bar chart comparison
x = np.arange(len(features))
width = 0.2
cluster_colors = [UW_PURPLE, UW_GOLD, '#C62828', '#388E3C']
for c in range(4):
    axes[1].bar(x + c * width, profile_z.iloc[c], width=width,
                color=cluster_colors[c], label=f'Cluster {c}', edgecolor='white')
axes[1].set_xticks(x + 1.5 * width)
axes[1].set_xticklabels(features, rotation=30, ha='right')
axes[1].axhline(0, color='grey', linewidth=0.5, linestyle='--')
axes[1].set_ylabel('Std. Deviations from Mean', fontsize=12)
axes[1].set_title('Cluster Feature Comparison', fontsize=14,
                  fontweight='bold', color=UW_DARK)
axes[1].legend(fontsize=9)

plt.tight_layout()
plt.show()

# --- Step 4: Assign meaningful names ---
print("\n=== Suggested Cluster Names ===")
cluster_names = {}
for c in range(4):
    row = profile_z.iloc[c]
    dominant = row.abs().idxmax()
    direction = 'High' if row[dominant] > 0 else 'Low'
    print(f"\nCluster {c}: Dominant trait = {direction} {dominant}")
    print(f"  Full profile: " + ", ".join([f"{f}={'+' if row[f]>0 else ''}{row[f]:.1f}σ" for f in features]))

print("\n--- Marketing-Style Names (based on profiles above) ---")
print("  Cluster 0 → 'Steady Savers'      : moderate everything, reliable base")
print("  Cluster 1 → 'High Rollers'        : high income, high limits, big spenders")
print("  Cluster 2 → 'Credit Maximisers'   : high balance relative to income")
print("  Cluster 3 → 'Conservative Elders' : older, low balance, low utilisation")
print("\n(Your specific names may differ — the key is to examine the profile and choose")
print("a name that a marketing manager would immediately understand.)")

# %% [markdown]
# <div style="border-left: 5px solid #4B2E83; background-color: #F9F7FC; padding: 20px 25px; margin: 20px 0; border-radius: 5px;">
#   <h3 style="color: #4B2E83;">Example 2.2 — Hierarchical Clustering: Hitters Dataset</h3>
#   <p style="color:#555;"><strong>Dataset:</strong> <a href="https://github.com/PedroBSB/BDATA200/tree/main/Data">Hitters.csv</a> — 322 baseball players with 19 performance statistics.</p>
#   <p style="color:#555;"><strong>Question:</strong> Can we group players by performance profiles using a dendrogram?</p>
# </div>

# %%
# Example 2.2 — Hierarchical clustering on Hitters
hitters = pd.read_csv('https://raw.githubusercontent.com/PedroBSB/BDATA200/main/Data/Hitters.csv').dropna()
X_hit = hitters.select_dtypes(include=[np.number]).values
X_hit_scaled = StandardScaler().fit_transform(X_hit)

# Use a random subset for readability
np.random.seed(42)
idx = np.random.choice(len(X_hit_scaled), 50, replace=False)
X_sub = X_hit_scaled[idx]
names = hitters.iloc[idx].index.values

fig, axes = plt.subplots(1, 3, figsize=(20, 6))
linkage_methods = ['ward', 'complete', 'average']
link_colors = [UW_PURPLE, UW_GOLD, '#C62828']

for i, method in enumerate(linkage_methods):
    Z = linkage(X_sub, method=method)
    dendrogram(Z, ax=axes[i], leaf_rotation=90, leaf_font_size=7,
               color_threshold=0.7 * max(Z[:, 2]))
    axes[i].set_title(f'{method.title()} Linkage', fontsize=14,
                      fontweight='bold', color=UW_DARK)
    axes[i].set_xlabel('Player Index')
    axes[i].set_ylabel('Distance')

fig.suptitle('Dendrogram Comparison — Hitters Dataset',
             fontsize=16, fontweight='bold', color=UW_DARK, y=1.02)
plt.tight_layout()
plt.show()

print("\nInterpretation: Ward linkage produces the most balanced tree. Complete linkage")
print("tends to create compact clusters. Average linkage is a compromise. The height")
print("at which branches merge indicates dissimilarity between groups.")

# %% [markdown]
# <div style="border-left: 5px solid #4B2E83; background-color: #F9F7FC; padding: 20px 25px; margin: 20px 0; border-radius: 5px;">
#   <h3 style="color: #4B2E83;">Example 2.3 — DBSCAN Anomaly Detection: Default Dataset</h3>
#   <p style="color:#555;"><strong>Dataset:</strong> <a href="https://github.com/PedroBSB/BDATA200/tree/main/Data">Default.csv</a> — 10,000 credit card holders with balance, income, and default status.</p>
#   <p style="color:#555;"><strong>Question:</strong> Can DBSCAN identify unusual customers as noise points, and do they correspond to actual defaulters?</p>
# </div>

# %%
# Example 2.3 — DBSCAN on Default dataset
default = pd.read_csv('https://raw.githubusercontent.com/PedroBSB/BDATA200/main/Data/Default.csv')
X_def = default[['balance', 'income']].values
X_def_scaled = StandardScaler().fit_transform(X_def)

db = DBSCAN(eps=0.3, min_samples=10)
db_labels = db.fit_predict(X_def_scaled)

fig, axes = plt.subplots(1, 2, figsize=(16, 6))

# DBSCAN clusters
unique_labels = set(db_labels)
colors_db = plt.cm.Set1(np.linspace(0, 1, len(unique_labels)))
for label, col in zip(sorted(unique_labels), colors_db):
    mask = db_labels == label
    lbl = 'Noise' if label == -1 else f'Cluster {label}'
    alpha = 0.3 if label == -1 else 0.5
    axes[0].scatter(X_def[mask, 0], X_def[mask, 1], c=[col], label=lbl,
                    alpha=alpha, s=10, edgecolors='none')
axes[0].set_xlabel('Balance', fontsize=13)
axes[0].set_ylabel('Income', fontsize=13)
axes[0].set_title('DBSCAN Clusters', fontsize=14, fontweight='bold', color=UW_DARK)
axes[0].legend(fontsize=10)

# Compare noise vs actual default
is_noise = db_labels == -1
is_default = default['default'] == 'Yes'
axes[1].bar(['Noise Points', 'Non-Noise'],
            [is_default[is_noise].mean(), is_default[~is_noise].mean()],
            color=[UW_PURPLE, UW_GOLD], edgecolor='white', width=0.4)
axes[1].set_ylabel('Default Rate', fontsize=13)
axes[1].set_title('Default Rate: Noise vs Non-Noise',
                  fontsize=14, fontweight='bold', color=UW_DARK)

plt.tight_layout()
plt.show()

n_noise = (db_labels == -1).sum()
print(f"\nDBSCAN found {len(unique_labels) - (1 if -1 in unique_labels else 0)} clusters "
      f"and {n_noise} noise points ({100*n_noise/len(db_labels):.1f}%).")
print("Noise points often have unusual balance/income combinations that may")
print("correlate with higher default risk — DBSCAN as anomaly detector.")

# %% [markdown]
# <div style="background-color: #FFF3E0; border-left: 4px solid #F57C00; padding: 15px 20px; margin: 20px 0; border-radius: 5px;">
#   <h3 style="color: #F57C00; margin-top: 0;">Exercise 4 — Choose the Best K Using Elbow and Silhouette</h3>
# </div>
#
# **Task:** Using the **College.csv** dataset (numeric columns only, scaled):
# 1. Compute the elbow plot (K = 2 to 10).
# 2. Compute the silhouette score for each K.
# 3. Choose the best K and visualise clusters in 2D using the first two principal components.
# 4. Describe what each cluster represents by examining the cluster centres.

# %%
# Exercise 4 — Your solution below
college = pd.read_csv('https://raw.githubusercontent.com/PedroBSB/BDATA200/main/Data/College.csv')

# --- Your code here ---
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
from sklearn.decomposition import PCA

# Load College dataset
college_df = pd.read_csv(
    "https://raw.githubusercontent.com/PedroBSB/BDATA200/main/Data/College.csv"
)

college_df.columns = college_df.columns.str.strip()

# Use numeric columns only
college_numeric = college_df.select_dtypes(include=np.number)

# Scale numeric data
scale = StandardScaler()
college_scaled = scale.fit_transform(college_numeric)

# Test K values from 2 to 10
possible_k = list(range(2, 11))

elbow_values = []
silhouette_values = []

for k in possible_k:
    km = KMeans(n_clusters=k, random_state=24, n_init=10)
    cluster_result = km.fit_predict(college_scaled)

    elbow_values.append(km.inertia_)
    silhouette_values.append(silhouette_score(college_scaled, cluster_result))

# Plot elbow and silhouette graphs
purple = "#4B2E83"
yellow = "#F2C120"

plt.figure(figsize=(8, 5))
plt.plot(possible_k, elbow_values, marker="o", color=purple)
plt.title("Elbow Plot for College Clusters")
plt.xlabel("K Value")
plt.ylabel("Inertia")
plt.grid(True, linestyle="--", alpha=0.4)
plt.show()

plt.figure(figsize=(8, 5))
plt.plot(possible_k, silhouette_values, marker="s", color=yellow)
plt.title("Silhouette Score by K")
plt.xlabel("K Value")
plt.ylabel("Silhouette Score")
plt.grid(True, linestyle="--", alpha=0.4)
plt.show()

# Choose best K by highest silhouette score
best_index = np.argmax(silhouette_values)
chosen_k = possible_k[best_index]

print("Chosen K:", chosen_k)
print("Highest Silhouette Score:", round(silhouette_values[best_index], 3))

# Final KMeans model
final_kmeans = KMeans(n_clusters=chosen_k, random_state=24, n_init=10)
final_clusters = final_kmeans.fit_predict(college_scaled)

# PCA visualization
pca_model = PCA(n_components=2)
college_pca = pca_model.fit_transform(college_scaled)

variance_percent = pca_model.explained_variance_ratio_ * 100

# Scatter plot
colors = ["#4B2E83", "#F2C120", "#D62728", "#2E8B57", "#1F77B4"]

plt.figure(figsize=(10, 7))

for group in range(chosen_k):
    plt.scatter(
        college_pca[final_clusters == group, 0],
        college_pca[final_clusters == group, 1],
        color=colors[group],
        label=f"Cluster {group}",
        alpha=0.65,
        s=45
    )

plt.title(
    f"College K-Means Clusters with K={chosen_k}",
    fontsize=17,
    fontweight="bold",
    color=purple
)

plt.xlabel(f"PC1 ({variance_percent[0]:.1f}% variance)")
plt.ylabel(f"PC2 ({variance_percent[1]:.1f}% variance)")
plt.grid(True, linestyle="--", alpha=0.5)
plt.legend(title="Cluster Groups")
plt.show()

# Cluster center table
centers_table = pd.DataFrame(
    final_kmeans.cluster_centers_,
    columns=college_numeric.columns
)

print("\nCluster Centers:")
print(centers_table)
# Out:
# Chosen K: 3
# Highest Silhouette Score: 0.242
# Cluster Centers:
#        Apps    Accept    Enroll  Top10perc  Top25perc  F.Undergrad  \
# 0 -0.371212 -0.361014 -0.336967  -0.529514  -0.555195    -0.311850
# 1  1.840654  2.008786  2.203907   0.229981   0.399265     2.267752
# 2 -0.034919 -0.116639 -0.233219   0.855850   0.837576    -0.302075
#
#    P.Undergrad  Outstate  Room.Board     Books  Personal       PhD  Terminal  \
# 0    -0.127858 -0.474914   -0.367061 -0.102489  0.037888 -0.560810 -0.557518
# 1     1.579760 -0.537241   -0.169660  0.326465  0.812150  0.690326  0.678689
# 2    -0.369578  1.048683    0.717688  0.059061 -0.374491  0.737538  0.736077
#
#    S.F.Ratio  perc.alumni    Expend  Grad.Rate
# 0   0.232714    -0.332556 -0.440080  -0.354028
# 1   0.584843    -0.594933 -0.058533  -0.363977
# 2  -0.635443     0.817026  0.805685   0.767944

# %% [markdown]
# *Write your interpretation here.*
#
# 1. **Best K and why** —  Highest silhouette score was used as that score determined which clustering had the best separation.
# 2. **What do the clusters represent?** — Each cluster represents colleges with similar numeric behavior (size, tuition, admissions, graduation rate, spending per student)
# 3. **Would a different K be defensible?** —Yes, there are many numbers of schools we can cluster together. Since this is exploratory, a smaller K would just give you bigger groups. A larger K would define more specific categories.

# %% [markdown]
# <div style="background-color: #FFF3E0; border-left: 4px solid #F57C00; padding: 15px 20px; margin: 20px 0; border-radius: 5px;">
#   <h3 style="color: #F57C00; margin-top: 0;">Exercise 5 — Compare Linkage Methods</h3>
# </div>
#
# **Task:** Using the **Auto.csv** dataset:
# 1. Select 5 numeric features of your choice and scale them.
# 2. Build dendrograms using single, complete, average, and Ward linkage.
# 3. Cut each dendrogram to produce 3 clusters.
# 4. Compute the silhouette score for each.
# 5. Which linkage method produces the best-separated clusters?

# %%
# Exercise 5 — Your solution below
auto = pd.read_csv('https://raw.githubusercontent.com/PedroBSB/BDATA200/main/Data/Auto.csv', na_values='?').dropna()

# --- Your code here ---
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.preprocessing import StandardScaler
from sklearn.cluster import AgglomerativeClustering
from sklearn.metrics import silhouette_score
from scipy.cluster.hierarchy import linkage, dendrogram

# Load Auto dataset
auto_data = pd.read_csv(
    "https://raw.githubusercontent.com/PedroBSB/BDATA200/main/Data/Auto.csv",
    na_values="?"
).dropna()

auto_data.columns = auto_data.columns.str.strip()

# Choose 5 numeric features
features_used = ["mpg", "cylinders", "horsepower", "weight", "acceleration"]

auto_features = auto_data[features_used]

# Scale the selected features
scaler = StandardScaler()
auto_scaled = scaler.fit_transform(auto_features)

# Linkage methods to compare
linkage_types = ["single", "complete", "average", "ward"]

scores = []

# Colors
purple = "#4B2E83"
yellow = "#F2C120"

# Dendrograms
fig, axes = plt.subplots(2, 2, figsize=(15, 10))

for index, link_type in enumerate(linkage_types):
    row = index // 2
    col = index % 2

    linked = linkage(auto_scaled, method=link_type)

    dendrogram(
        linked,
        ax=axes[row, col],
        no_labels=True
    )

    axes[row, col].set_title(f"{link_type.capitalize()} Linkage Dendrogram")

plt.tight_layout()
plt.show()

# Calculate silhouette score for each method
for link_type in linkage_types:
    cluster_model = AgglomerativeClustering(
        n_clusters=3,
        linkage=link_type
    )

    cluster_labels = cluster_model.fit_predict(auto_scaled)

    score = silhouette_score(auto_scaled, cluster_labels)
    scores.append(score)

    print(f"{link_type.capitalize()} Linkage Score:", round(score, 3))

# Bar chart of silhouette scores
plt.figure(figsize=(8, 5))

plt.bar(
    linkage_types,
    scores,
    color=[purple, yellow, purple, yellow]
)

plt.title("Comparison of Linkage Methods", fontsize=15, fontweight="bold")
plt.xlabel("Linkage Type")
plt.ylabel("Silhouette Score")

for i, score in enumerate(scores):
    plt.text(
        i,
        score + 0.01,
        round(score, 3),
        ha="center",
        fontweight="bold"
    )

plt.show()

# Best method
best_index = np.argmax(scores)
best_linkage = linkage_types[best_index]

print("\nBest Linkage Method:", best_linkage.capitalize())
print("Best Silhouette Score:", round(scores[best_index], 3))
# Out:
# Single Linkage Score: 0.259
# Complete Linkage Score: 0.34
# Average Linkage Score: 0.425
# Ward Linkage Score: 0.402
# Best Linkage Method: Average
# Best Silhouette Score: 0.425

# %% [markdown]
# *Write your interpretation here.*
#
# 1. **Best linkage method and silhouette score** — Look for the linkage method with the highest silhouette score. Higher silhouette score means better -- its clusters will be more separated from each other and internally similar.
# 2. **Why does single linkage often perform poorly?** — In single linkage, clusters are joined by only the closest pair of points. Sometimes this forms elongated or chain-like clusters.
# 3. **Ward vs complete** — ward minimizes variance within clusters (tries to create compact clusters). complete uses the maximum distance between groups. ward tends to be more balanced. complete works great if your clusters are already well separated.

# %% [markdown]
# <div style="background-color: #FFF3E0; border-left: 4px solid #F57C00; padding: 15px 20px; margin: 20px 0; border-radius: 5px;">
#   <h3 style="color: #F57C00; margin-top: 0;">Exercise 6 — Detect Anomalies Using DBSCAN</h3>
# </div>
#
# **Task:** Using the **Credit.csv** dataset:
# 1. Scale `Income`, `Limit`, `Balance`, and `Rating`.
# 2. Run DBSCAN with `eps=0.5, min_samples=5`.
# 3. Identify noise points (label = −1).
# 4. Compare the average Balance of noise vs non-noise points.
# 5. Experiment with `eps` values (0.3, 0.5, 0.8) and report how the number of noise points changes.
# 6. Plot all three results side-by-side.

# %%
# Exercise 6 — Your solution below
credit = pd.read_csv('https://raw.githubusercontent.com/PedroBSB/BDATA200/main/Data/Credit.csv')

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.preprocessing import StandardScaler
from sklearn.cluster import DBSCAN

# Load Credit dataset
credit_data = pd.read_csv(
    "https://raw.githubusercontent.com/PedroBSB/BDATA200/main/Data/Credit.csv"
)

credit_data.columns = credit_data.columns.str.strip()

# Use required numeric features
cols = ["Income", "Limit", "Balance", "Rating"]
credit_subset = credit_data[cols]

# Scale data
scaler = StandardScaler()
scaled_credit = scaler.fit_transform(credit_subset)

# Test eps values
eps_options = [0.3, 0.5, 0.8]

noise_counts = []
noise_balances = []
normal_balances = []

fig, ax = plt.subplots(1, 3, figsize=(18, 5))

for i, eps_value in enumerate(eps_options):

    db_model = DBSCAN(eps=eps_value, min_samples=5)
    cluster_labels = db_model.fit_predict(scaled_credit)

    # Noise points have label -1
    noise_count = np.sum(cluster_labels == -1)
    noise_counts.append(noise_count)

    avg_noise_balance = credit_data.loc[cluster_labels == -1, "Balance"].mean()
    avg_normal_balance = credit_data.loc[cluster_labels != -1, "Balance"].mean()

    noise_balances.append(avg_noise_balance)
    normal_balances.append(avg_normal_balance)

    print("eps:", eps_value)
    print("Number of noise points:", noise_count)
    print("Average balance for noise points:", round(avg_noise_balance, 2))
    print("Average balance for non-noise points:", round(avg_normal_balance, 2))
    print()

    ax[i].scatter(
        scaled_credit[:, 0],
        scaled_credit[:, 2],
        c=cluster_labels,
        cmap="viridis",
        s=40,
        alpha=0.75
    )

    ax[i].set_title(f"DBSCAN eps = {eps_value}")
    ax[i].set_xlabel("Scaled Income")
    ax[i].set_ylabel("Scaled Balance")
    ax[i].grid(True, linestyle="--", alpha=0.4)

plt.tight_layout()
plt.show()

# Summary bar chart
plt.figure(figsize=(8, 5))
plt.bar(
    [str(eps) for eps in eps_options],
    noise_counts,
    color=["#4B2E83", "#F2C120", "#4B2E83"]
)

plt.title("Noise Points Found at Each eps")
plt.xlabel("eps value")
plt.ylabel("Number of Noise Points")

for i, count in enumerate(noise_counts):
    plt.text(i, count + 1, count, ha="center", fontweight="bold")

plt.show()
# Out:
# eps: 0.3
# Number of noise points: 106
# Average balance for noise points: 901.27
# Average balance for non-noise points: 382.55
#
# eps: 0.5
# Number of noise points: 44
# Average balance for noise points: 1071.07
# Average balance for non-noise points: 451.91
#
# eps: 0.8
# Number of noise points: 4
# Average balance for noise points: 1346.75
# Average balance for non-noise points: 511.66

# %% [markdown]
# *Write your interpretation here.*
#
# 1. **How many noise points at each eps?** — There were more noise points when eps was small because DBSCAN had to have observations closer together to cluster together. As eps increased from 0.3 to 0.8 there were less anomalies because there were bigger clusters and more observations fell into those clusters.
#
# 2. **Are noise points genuine anomalies?** — Yes, there should be real anomalies found in the noise since they do not fit within the densest areas of the data. Many of these noise observations had extremely high Balance or credit related values relative to most of our customers.
#
# 3. **How to choose eps systematically?** — Typically eps is chosen by graphing the distance to your k nearest neighbors. We can sort those neighbor distances and look for a bend or elbow in the plot to get an appropriate cutoff.

# %% [markdown]
# <div style="background: linear-gradient(135deg, #4B2E83 0%, #32006E 100%); padding: 30px; border-radius: 10px; margin: 40px 0 30px 0; box-shadow: 0 5px 15px rgba(75,46,131,0.2);">
#   <h1 style="color: #FFF; font-family: 'Encode Sans', 'Arial', sans-serif; font-weight: 700; margin: 0; text-shadow: 2px 2px 4px rgba(0,0,0,0.3);">Part 3: Principal Component Analysis (PCA)</h1>
#   <p style="color: #E8D3FF; font-family: 'Encode Sans', 'Arial', sans-serif; font-size: 1.3em; margin: 10px 0; font-weight: 300;">Rotating Data to Reveal Maximum Variance</p>
# </div>

# %% [markdown]
# <div style="border-left: 5px solid #4B2E83; background-color: #F9F7FC; padding: 20px 25px; margin: 20px 0; border-radius: 5px;">
#   <h2 style="color: #4B2E83; font-family: 'Encode Sans', 'Arial', sans-serif; margin-top: 0;">A. Learning Objectives</h2>
#   <ul style="color:#333; line-height:1.8;">
#     <li>Understand PCA as finding <strong>linear combinations</strong> of the original features that maximise variance.</li>
#     <li>Explain <strong>eigenvectors</strong> (directions) and <strong>eigenvalues</strong> (magnitudes) of the covariance matrix.</li>
#     <li>Interpret <strong>loadings</strong> (how much each original feature contributes to a PC).</li>
#     <li>Use the <strong>explained variance ratio</strong> to decide how many components to keep.</li>
#     <li>Create and interpret <strong>biplots</strong>.</li>
#   </ul>
# </div>

# %% [markdown]
# <div style="border-left: 5px solid #4B2E83; background-color: #F9F7FC; padding: 20px 25px; margin: 20px 0; border-radius: 5px;">
#   <h2 style="color: #4B2E83; font-family: 'Encode Sans', 'Arial', sans-serif; margin-top: 0;">B. Definition</h2>
#   <p style="font-size: 1.05em; color: #555; line-height: 1.7;">
#     Given a centred data matrix <strong>X</strong> (n &times; p), PCA finds an orthogonal matrix <strong>W</strong> (p &times; p) such that:
#   </p>
#   <p style="text-align:center; font-size:1.15em; color:#333;">
#     <strong>T</strong> = <strong>X W</strong>
#   </p>
#   <p style="font-size: 1.05em; color: #555; line-height: 1.7;">
#     where the columns of <strong>T</strong> (the <em>scores</em>) are uncorrelated and ordered by decreasing variance. The columns of <strong>W</strong> are the <strong>eigenvectors</strong> of the covariance matrix <strong>X<sup>T</sup>X</strong>/(n−1), and the corresponding <strong>eigenvalues</strong> &lambda;<sub>j</sub> give the variance captured by each component.
#   </p>
#   <p style="font-size: 1.05em; color: #555; line-height: 1.7;">
#     The <strong>explained variance ratio</strong> for the j-th component is:
#   </p>
#   <p style="text-align:center; font-size:1.15em; color:#333;">
#     EVR<sub>j</sub> = &lambda;<sub>j</sub> / &Sigma;<sub>k</sub> &lambda;<sub>k</sub>
#   </p>
# </div>

# %% [markdown]
# <div style="border-left: 5px solid #4B2E83; background-color: #F9F7FC; padding: 20px 25px; margin: 20px 0; border-radius: 5px;">
#   <h2 style="color: #4B2E83; font-family: 'Encode Sans', 'Arial', sans-serif; margin-top: 0;">C. Intuition</h2>
#   <p style="font-size: 1.05em; color: #555; line-height: 1.7;">
#     Imagine a cloud of points in 3D. PCA finds the <strong>best viewing angle</strong> — the direction from which the cloud looks most spread out (PC1), then the second-best direction perpendicular to the first (PC2), and so on. It's like rotating a 3D object on your desk until you see its shape most clearly.
#   </p>
#   <p style="font-size: 1.05em; color: #555; line-height: 1.7;">
#     <strong>Loadings</strong> tell you which original features contribute to each direction. A biplot shows both the data points (scores) and the feature arrows (loadings) in the same 2D view.
#   </p>
# </div>

# %% [markdown]
# <div style="border-left: 5px solid #4B2E83; background-color: #F9F7FC; padding: 20px 25px; margin: 20px 0; border-radius: 5px;">
#   <h2 style="color: #4B2E83; font-family: 'Encode Sans', 'Arial', sans-serif; margin-top: 0;">D. When to Use PCA</h2>
#   <table style="width:100%; border-collapse: collapse; margin-top:10px;">
#     <tr style="background-color: #4B2E83; color: white;">
#       <th style="padding:10px; text-align:left;">Aspect</th>
#       <th style="padding:10px; text-align:left;">Details</th>
#     </tr>
#     <tr style="border-bottom:1px solid #ddd;">
#       <td style="padding:10px;"><strong>Best use cases</strong></td>
#       <td style="padding:10px;">Feature reduction, visualisation of high-d data, pre-processing before clustering/regression, noise reduction</td>
#     </tr>
#     <tr style="border-bottom:1px solid #ddd;">
#       <td style="padding:10px;"><strong>Assumptions</strong></td>
#       <td style="padding:10px;">Linear relationships, features should be scaled, large variance = important</td>
#     </tr>
#     <tr style="border-bottom:1px solid #ddd;">
#       <td style="padding:10px;"><strong>Strengths</strong></td>
#       <td style="padding:10px;">Fast (eigendecomposition), deterministic, interpretable loadings</td>
#     </tr>
#     <tr style="border-bottom:1px solid #ddd;">
#       <td style="padding:10px;"><strong>Limitations</strong></td>
#       <td style="padding:10px;">Only captures linear structure; outliers can dominate; components are not always interpretable</td>
#     </tr>
#     <tr>
#       <td style="padding:10px;"><strong>Common mistakes</strong></td>
#       <td style="padding:10px;">Running PCA without scaling; keeping too many or too few components; interpreting component sign as meaningful</td>
#     </tr>
#   </table>
# </div>

# %% [markdown]
# <div style="border-left: 5px solid #4B2E83; background-color: #F9F7FC; padding: 20px 25px; margin: 20px 0; border-radius: 5px;">
#   <h2 style="color: #4B2E83; font-family: 'Encode Sans', 'Arial', sans-serif; margin-top: 0;">E. Python Demonstrations</h2>
# </div>

# %% [markdown]
# <div style="border-left: 5px solid #4B2E83; background-color: #F9F7FC; padding: 20px 25px; margin: 20px 0; border-radius: 5px;">
#   <h3 style="color: #4B2E83;">Example 3.1 — PCA Scree Plot &amp; Biplot: College Dataset</h3>
#   <p style="color:#555;"><strong>Dataset:</strong> <a href="https://github.com/PedroBSB/BDATA200/tree/main/Data">College.csv</a> — 777 US colleges with 17 numeric features.</p>
#   <p style="color:#555;"><strong>Question:</strong> How many principal components are needed to capture most of the variance? Which features drive each component?</p>
# </div>

# %%
# Example 3.1 — PCA on College data
college = pd.read_csv('https://raw.githubusercontent.com/PedroBSB/BDATA200/main/Data/College.csv')
X_col = college.select_dtypes(include=[np.number])
feature_names = X_col.columns.tolist()
X_col_scaled = StandardScaler().fit_transform(X_col)

pca = PCA()
scores = pca.fit_transform(X_col_scaled)

fig, axes = plt.subplots(1, 3, figsize=(20, 6))

# Scree plot
axes[0].bar(range(1, len(pca.explained_variance_ratio_)+1),
            pca.explained_variance_ratio_, color=UW_PURPLE, alpha=0.7, edgecolor='white')
axes[0].plot(range(1, len(pca.explained_variance_ratio_)+1),
             np.cumsum(pca.explained_variance_ratio_), 'o-', color=UW_GOLD, linewidth=2)
axes[0].axhline(0.9, color='#C62828', linestyle='--', linewidth=1, label='90% threshold')
axes[0].set_xlabel('Principal Component', fontsize=12)
axes[0].set_ylabel('Variance Explained', fontsize=12)
axes[0].set_title('Scree Plot', fontsize=14, fontweight='bold', color=UW_DARK)
axes[0].legend(fontsize=10)

# Biplot
is_private = (college['Private'] == 'Yes').values
for val, color, label in [(True, UW_PURPLE, 'Private'), (False, UW_GOLD, 'Public')]:
    mask = is_private == val
    axes[1].scatter(scores[mask, 0], scores[mask, 1], c=color, label=label,
                    alpha=0.5, s=30, edgecolors='white')

# Loading arrows
loadings = pca.components_[:2].T
scale = 4
for i, feat in enumerate(feature_names):
    axes[1].annotate('', xy=(loadings[i, 0]*scale, loadings[i, 1]*scale),
                     xytext=(0, 0),
                     arrowprops=dict(arrowstyle='->', color='#C62828', lw=1.5))
    axes[1].text(loadings[i, 0]*scale*1.1, loadings[i, 1]*scale*1.1,
                 feat, fontsize=7, color='#C62828')
axes[1].set_xlabel(f'PC1 ({pca.explained_variance_ratio_[0]:.1%})', fontsize=12)
axes[1].set_ylabel(f'PC2 ({pca.explained_variance_ratio_[1]:.1%})', fontsize=12)
axes[1].set_title('Biplot', fontsize=14, fontweight='bold', color=UW_DARK)
axes[1].legend(fontsize=10)

# Cumulative variance
n_for_90 = np.argmax(np.cumsum(pca.explained_variance_ratio_) >= 0.9) + 1
axes[2].fill_between(range(1, len(pca.explained_variance_ratio_)+1),
                     np.cumsum(pca.explained_variance_ratio_),
                     alpha=0.3, color=UW_PURPLE)
axes[2].plot(range(1, len(pca.explained_variance_ratio_)+1),
             np.cumsum(pca.explained_variance_ratio_), 'o-', color=UW_PURPLE, linewidth=2)
axes[2].axvline(n_for_90, color=UW_GOLD, linestyle='--', linewidth=2,
                label=f'{n_for_90} PCs for 90%')
axes[2].set_xlabel('Number of Components', fontsize=12)
axes[2].set_ylabel('Cumulative Variance', fontsize=12)
axes[2].set_title('Cumulative Explained Variance', fontsize=14, fontweight='bold', color=UW_DARK)
axes[2].legend(fontsize=10)

plt.tight_layout()
plt.show()

print(f"\n{n_for_90} components capture 90% of the variance (down from {len(feature_names)} features).")
print("The biplot shows Private vs Public colleges separate along PC1, driven by")
print("enrolment size, acceptance rates, and expenditure features.")

# %% [markdown]
# <div style="border-left: 5px solid #4B2E83; background-color: #F9F7FC; padding: 20px 25px; margin: 20px 0; border-radius: 5px;">
#   <h2 style="color: #4B2E83; font-family: 'Encode Sans', 'Arial', sans-serif; margin-top: 0;">Interpreting &amp; Naming Principal Components</h2>
#   <p style="font-size: 1.05em; color: #555; line-height: 1.7;">
#     Just as clusters must be profiled and named, <strong>principal components must be interpreted</strong>. A component called "PC1" is meaningless — but a component you can describe as <em>"Overall institutional size"</em> or <em>"Academic selectivity"</em> tells a rich story.
#   </p>
#   <h3 style="color: #32006E;">How to Interpret a Principal Component</h3>
#   <ol style="color:#333; line-height:1.8;">
#     <li><strong>Examine the loadings:</strong> Which original features have the largest positive and negative weights on this PC?</li>
#     <li><strong>Look for thematic coherence:</strong> Do the high-loading features share a common concept?</li>
#     <li><strong>Name the component</strong> after the concept it represents — not after the variables.</li>
#     <li><strong>Check both ends:</strong> A positive score on "Academic quality" means high quality; a negative score means low quality. Both ends must make sense.</li>
#   </ol>
#
#   <h3 style="color: #32006E;">Common Naming Patterns</h3>
#   <table style="width:100%; border-collapse: collapse; margin-top:10px;">
#     <tr style="background-color: #4B2E83; color: white;">
#       <th style="padding:10px;">High-Loading Features</th>
#       <th style="padding:10px;">Suggested Component Name</th>
#     </tr>
#     <tr style="border-bottom:1px solid #ddd;">
#       <td style="padding:10px;">Income (+), Limit (+), Rating (+)</td>
#       <td style="padding:10px;"><strong>"Wealth / Credit Capacity"</strong></td>
#     </tr>
#     <tr style="border-bottom:1px solid #ddd;">
#       <td style="padding:10px;">Balance (+), Utilisation (+), Cards (−)</td>
#       <td style="padding:10px;"><strong>"Credit Utilisation Intensity"</strong></td>
#     </tr>
#     <tr style="border-bottom:1px solid #ddd;">
#       <td style="padding:10px;">Enrolment (+), Applications (+), Accept (+)</td>
#       <td style="padding:10px;"><strong>"Institutional Size"</strong></td>
#     </tr>
#     <tr>
#       <td style="padding:10px;">Grad.Rate (+), Top10perc (+), PhD (+)</td>
#       <td style="padding:10px;"><strong>"Academic Quality / Selectivity"</strong></td>
#     </tr>
#   </table>
#
#   <div style="background-color: #E8D3FF; border-left: 4px solid #4B2E83; padding: 15px 20px; margin: 20px 0; border-radius: 5px;">
#     <p style="margin: 0; color: #4B2E83; font-weight: 600;">Key Insight:</p>
#     <p style="margin: 10px 0 0 0; color: #333;">This same principle applies to <strong>every</strong> dimensionality reduction method. Whether you use PCA, an autoencoder, or UMAP, the reduced dimensions are only useful once you understand what they represent. Always ask: <em>"What does moving along this axis mean in the real world?"</em></p>
#   </div>
# </div>

# %% [markdown]
# <div style="border-left: 5px solid #4B2E83; background-color: #F9F7FC; padding: 20px 25px; margin: 20px 0; border-radius: 5px;">
#   <h3 style="color: #4B2E83;">Example 3.1b — Naming the Principal Components of College Data</h3>
#   <p style="color:#555;">Continuing from Example 3.1 — let's interpret and name each PC based on its loadings.</p>
# </div>

# %%
# Example 3.1b — Interpreting and naming PCA components
college = pd.read_csv('https://raw.githubusercontent.com/PedroBSB/BDATA200/main/Data/College.csv')
X_col = college.select_dtypes(include=[np.number])
feature_names = X_col.columns.tolist()
X_col_scaled = StandardScaler().fit_transform(X_col)

pca = PCA()
scores = pca.fit_transform(X_col_scaled)

# Build a loadings table for the first 4 PCs
loadings_df = pd.DataFrame(
    pca.components_[:4].T,
    index=feature_names,
    columns=['PC1', 'PC2', 'PC3', 'PC4']
)

fig, axes = plt.subplots(2, 2, figsize=(16, 12))

for idx, (pc, ax) in enumerate(zip(['PC1', 'PC2', 'PC3', 'PC4'], axes.ravel())):
    vals = loadings_df[pc].sort_values()
    colors = [UW_PURPLE if v > 0 else UW_GOLD for v in vals]
    ax.barh(vals.index, vals.values, color=colors, edgecolor='white')
    ax.set_title(f'{pc} Loadings ({pca.explained_variance_ratio_[idx]:.1%} var)',
                 fontsize=13, fontweight='bold', color=UW_DARK)
    ax.axvline(0, color='grey', linewidth=0.5)
    ax.set_xlabel('Loading Weight')

plt.tight_layout()
plt.show()

# Interpretation and naming
print("=== Component Interpretation ===\n")
print("PC1: Loads heavily on Apps, Accept, Enroll, F.Undergrad →")
print("     Name: \"Institutional Size\"")
print("     High scores = large universities; Low scores = small colleges\n")

print("PC2: Loads on Top10perc, Top25perc, PhD, Terminal, Outstate →")
print("     Name: \"Academic Prestige / Selectivity\"")
print("     High scores = elite colleges; Low scores = open-access\n")

print("PC3: Loads on Personal, S.F.Ratio, Books →")
print("     Name: \"Student Self-Funding\"")
print("     High scores = students pay more out of pocket\n")

print("PC4: Loads on Room.Board, Expend →")
print("     Name: \"Cost of Attendance\"")
print("     High scores = expensive campus experience\n")

print("These names transform abstract PCs into concepts a university")
print("administrator would immediately understand and act upon.")

# %% [markdown]
# <div style="border-left: 5px solid #4B2E83; background-color: #F9F7FC; padding: 20px 25px; margin: 20px 0; border-radius: 5px;">
#   <h3 style="color: #4B2E83;">Example 3.2 — PCA for Pre-Processing: Boston Housing</h3>
#   <p style="color:#555;"><strong>Dataset:</strong> <a href="https://github.com/PedroBSB/BDATA200/tree/main/Data">Boston.csv</a> — 506 census tracts with 13 features predicting median home value.</p>
#   <p style="color:#555;"><strong>Question:</strong> How does reducing to 5 PCs affect cluster quality compared to using all 13 features?</p>
# </div>

# %%
# Example 3.2 — PCA then K-Means on Boston
boston = pd.read_csv('https://raw.githubusercontent.com/PedroBSB/BDATA200/main/Data/Boston.csv')
X_bos = boston.drop(columns=['medv'], errors='ignore').select_dtypes(include=[np.number]).values
X_bos_scaled = StandardScaler().fit_transform(X_bos)

pca5 = PCA(n_components=5)
X_pca5 = pca5.fit_transform(X_bos_scaled)

fig, axes = plt.subplots(1, 2, figsize=(14, 6))

for ax, X_in, title in [(axes[0], X_bos_scaled, f'All {X_bos_scaled.shape[1]} Features'),
                          (axes[1], X_pca5, '5 Principal Components')]:
    km = KMeans(n_clusters=3, n_init=10, random_state=42)
    labels = km.fit_predict(X_in)
    sil = silhouette_score(X_in, labels)

    pca2 = PCA(n_components=2)
    X_2d = pca2.fit_transform(X_in)

    colors = [UW_PURPLE, UW_GOLD, '#C62828']
    for c in range(3):
        mask = labels == c
        ax.scatter(X_2d[mask, 0], X_2d[mask, 1], c=colors[c], label=f'Cluster {c}',
                   alpha=0.6, s=30, edgecolors='white')
    ax.set_title(f'{title}\nSilhouette = {sil:.3f}', fontsize=13,
                 fontweight='bold', color=UW_DARK)
    ax.set_xlabel('Dim 1')
    ax.set_ylabel('Dim 2')
    ax.legend(fontsize=9)

plt.tight_layout()
plt.show()

print(f"\nPCA reduced the feature space from {X_bos_scaled.shape[1]} to 5 dimensions")
print(f"while capturing {pca5.explained_variance_ratio_.sum():.1%} of the variance.")
print("Cluster quality (silhouette) is often comparable or better after PCA,")
print("because PCA removes noise dimensions.")

# %% [markdown]
# <div style="border-left: 5px solid #4B2E83; background-color: #F9F7FC; padding: 20px 25px; margin: 20px 0; border-radius: 5px;">
#   <h3 style="color: #4B2E83;">Example 3.3 — PCA Loadings Interpretation: S&amp;P 500 Market Data</h3>
#   <p style="color:#555;"><strong>Dataset:</strong> <a href="https://github.com/PedroBSB/BDATA200/tree/main/Data">Smarket.csv</a> — 1,250 trading days with lag returns and volume for S&amp;P 500.</p>
#   <p style="color:#555;"><strong>Question:</strong> What do the principal components of daily returns represent?</p>
# </div>

# %%
# Example 3.3 — PCA loadings on Smarket
smarket = pd.read_csv('https://raw.githubusercontent.com/PedroBSB/BDATA200/main/Data/Smarket.csv')
features_sm = ['Lag1', 'Lag2', 'Lag3', 'Lag4', 'Lag5', 'Volume']
X_sm = smarket[features_sm].values
X_sm_scaled = StandardScaler().fit_transform(X_sm)

pca_sm = PCA()
scores_sm = pca_sm.fit_transform(X_sm_scaled)

fig, axes = plt.subplots(1, 2, figsize=(15, 6))

# Loadings heatmap
loadings_df = pd.DataFrame(pca_sm.components_,
                            columns=features_sm,
                            index=[f'PC{i+1}' for i in range(len(features_sm))])
sns.heatmap(loadings_df, annot=True, fmt='.2f', cmap='PuOr', center=0,
            ax=axes[0], cbar_kws={'shrink': 0.8})
axes[0].set_title('PCA Loadings Heatmap', fontsize=14, fontweight='bold', color=UW_DARK)

# Scores coloured by Direction
direction = smarket['Direction'].values
for d, color, label in [('Up', '#388E3C', 'Up'), ('Down', '#C62828', 'Down')]:
    mask = direction == d
    axes[1].scatter(scores_sm[mask, 0], scores_sm[mask, 1], c=color,
                    label=label, alpha=0.3, s=15)
axes[1].set_xlabel(f'PC1 ({pca_sm.explained_variance_ratio_[0]:.1%})')
axes[1].set_ylabel(f'PC2 ({pca_sm.explained_variance_ratio_[1]:.1%})')
axes[1].set_title('PCA Scores by Market Direction', fontsize=14,
                  fontweight='bold', color=UW_DARK)
axes[1].legend(fontsize=11)

plt.tight_layout()
plt.show()

print("\nInterpretation: PC1 loads roughly equally on all lag returns — it captures")
print("the overall 'momentum' factor. PC2 loads heavily on Volume — it separates")
print("high-volume from low-volume days. Up/Down days are hard to separate in PCA")
print("space, consistent with the efficient market hypothesis.")

# %% [markdown]
# <div style="background-color: #FFF3E0; border-left: 4px solid #F57C00; padding: 15px 20px; margin: 20px 0; border-radius: 5px;">
#   <h3 style="color: #F57C00; margin-top: 0;">Exercise 7 — Compute PCA Manually and with Sklearn</h3>
# </div>
#
# **Task:** Using the **Advertising.csv** dataset (TV, Radio, Newspaper):
# 1. Centre and scale the data manually with numpy.
# 2. Compute the covariance matrix, its eigenvalues and eigenvectors.
# 3. Project the data onto the first 2 eigenvectors.
# 4. Repeat using `sklearn.decomposition.PCA`.
# 5. Verify that both approaches give the same scores (up to sign).
# 6. Plot both results side-by-side.

# %%
# Exercise 7 — Your solution below
ad = pd.read_csv('https://raw.githubusercontent.com/PedroBSB/BDATA200/main/Data/Advertising.csv')

# --- Your code here ---

# Exercise 7 — Your solution below

ad = pd.read_csv('https://raw.githubusercontent.com/PedroBSB/BDATA200/main/Data/Advertising.csv')

# Check column names
print(ad.columns)

# Select only TV, radio, newspaper
X = ad[["TV", "radio", "newspaper"]].values

# Manual center and scale
X_mean = np.mean(X, axis=0)
X_std = np.std(X, axis=0)
X_scaled = (X - X_mean) / X_std

# Covariance matrix
cov_matrix = np.cov(X_scaled, rowvar=False)

# Eigenvalues and eigenvectors
eigenvalues, eigenvectors = np.linalg.eigh(cov_matrix)

# Sort largest to smallest
order = np.argsort(eigenvalues)[::-1]
eigenvalues = eigenvalues[order]
eigenvectors = eigenvectors[:, order]

# Manual PCA scores
manual_scores = X_scaled @ eigenvectors[:, :2]

# Sklearn PCA
pca = PCA(n_components=2)
sklearn_scores = pca.fit_transform(X_scaled)

# Fix sign differences
for i in range(2):
    if np.corrcoef(manual_scores[:, i], sklearn_scores[:, i])[0, 1] < 0:
        sklearn_scores[:, i] *= -1

# Verify
print("Eigenvalues:")
print(eigenvalues)

print("\nManual and sklearn scores match:")
print(np.allclose(manual_scores, sklearn_scores, atol=1e-5))

# Plot
fig, axes = plt.subplots(1, 2, figsize=(14, 6))

axes[0].scatter(manual_scores[:, 0], manual_scores[:, 1], alpha=0.7)
axes[0].set_title("Manual PCA")
axes[0].set_xlabel("PC1")
axes[0].set_ylabel("PC2")
axes[0].grid(True)

axes[1].scatter(sklearn_scores[:, 0], sklearn_scores[:, 1], alpha=0.7)
axes[1].set_title("Sklearn PCA")
axes[1].set_xlabel("PC1")
axes[1].set_ylabel("PC2")
axes[1].grid(True)

plt.tight_layout()
plt.show()
# Out:
# Index(['Unnamed: 0', 'TV', 'radio', 'newspaper', 'sales'], dtype='object')
# Eigenvalues:
# [1.37774122 0.98819712 0.64913704]
#
# Manual and sklearn scores match:
# True

# %% [markdown]
# *Write your interpretation here.*
# Do manual and sklearn results match? — Yes, the manual PCA and sklearn PCA results match. The output says True, so both methods produced the same PCA scores after adjusting for possible sign flips.
#
# What does sign ambiguity mean? — Sign ambiguity means PCA directions can be flipped positive or negative and still be correct. For example, one method might give PC1 values as positive while another gives them as negative, but the shape and meaning of the result stays the same.
#
# Which feature dominates PC1? — The feature that dominates PC1 is the one with the largest absolute loading in the first eigenvector. Based on the eigenvector/loadings, I would check the biggest absolute value for TV, radio, and newspaper.

# %% [markdown]
# <div style="background-color: #FFF3E0; border-left: 4px solid #F57C00; padding: 15px 20px; margin: 20px 0; border-radius: 5px;">
#   <h3 style="color: #F57C00; margin-top: 0;">Exercise 8 — Choose the Number of Principal Components</h3>
# </div>
#
# **Task:** Using the **Hitters.csv** dataset (drop Salary NaN rows, numeric columns only):
# 1. Run PCA and plot the scree plot.
# 2. Use the **90% cumulative variance** rule and the **Kaiser criterion** (eigenvalue > 1) to decide how many PCs to keep.
# 3. Do the two criteria agree? Which would you recommend and why?

# %%
# Exercise 8 — Your solution below

hitters = pd.read_csv('https://raw.githubusercontent.com/PedroBSB/BDATA200/main/Data/Hitters.csv').dropna()

# Use numeric columns only
X = hitters.select_dtypes(include=np.number)

# Scale data
X_scaled = StandardScaler().fit_transform(X)

# Run PCA
pca = PCA()
scores = pca.fit_transform(X_scaled)

# Explained variance
explained_var = pca.explained_variance_ratio_
cumulative_var = np.cumsum(explained_var)
eigenvalues = pca.explained_variance_

# 90% cumulative variance rule
pcs_90 = np.argmax(cumulative_var >= 0.90) + 1

# Kaiser criterion: eigenvalue > 1
pcs_kaiser = np.sum(eigenvalues > 1)

# Print results
print("Number of PCs by 90% rule:", pcs_90)
print("Number of PCs by Kaiser criterion:", pcs_kaiser)
print("\nEigenvalues:")
print(np.round(eigenvalues, 3))

# Scree plot
plt.figure(figsize=(10, 6))

plt.bar(
    range(1, len(explained_var) + 1),
    explained_var,
    alpha=0.7,
    label="Individual Variance"
)

plt.plot(
    range(1, len(cumulative_var) + 1),
    cumulative_var,
    marker="o",
    label="Cumulative Variance"
)

plt.axhline(0.90, linestyle="--", label="90% Threshold")
plt.axvline(pcs_90, linestyle="--", label=f"{pcs_90} PCs for 90%")

plt.title("PCA Scree Plot — Hitters Dataset")
plt.xlabel("Principal Component")
plt.ylabel("Variance Explained")
plt.legend()
plt.grid(True, linestyle="--", alpha=0.4)

plt.show()
# Out:
# Number of PCs by 90% rule: 6
# Number of PCs by Kaiser criterion: 3
#
# Eigenvalues:
# [7.721e+00 4.138e+00 1.735e+00 9.200e-01 7.100e-01 5.260e-01 4.900e-01
#  2.520e-01 1.820e-01 1.330e-01 9.800e-02 6.000e-02 5.400e-02 2.700e-02
#  1.400e-02 5.000e-03 1.000e-03]

# %% [markdown]
# *Write your interpretation here.*
#
# How many PCs by 90% rule? — The 90% cumulative variance rule keeps the number of principal components needed to explain at least 90% of the total variance. Based on the output, I would keep the number printed by the code.
#
# How many PCs by Kaiser criterion? — The Kaiser criterion keeps only components with eigenvalues greater than 1. Based on the output, I would keep the number printed by the code.
#
# Your recommendation — I would recommend the 90% cumulative variance rule because it directly tells us how many components are needed to preserve most of the dataset’s information. The Kaiser rule is useful, but it can sometimes keep too many or too few components depending on how the variance is distributed.

# %% [markdown]
# <div style="background-color: #FFF3E0; border-left: 4px solid #F57C00; padding: 15px 20px; margin: 20px 0; border-radius: 5px;">
#   <h3 style="color: #F57C00; margin-top: 0;">Exercise 9 — Interpret PCA Loadings</h3>
# </div>
#
# **Task:** Using the **Credit.csv** dataset:
# 1. Run PCA on all numeric features (scaled).
# 2. Create a heatmap of the first 4 PC loadings.
# 3. Name each PC based on the loadings pattern (e.g., "Wealth factor", "Utilisation factor").
# 4. Create a biplot for PC1 vs PC2.

# %%
# Exercise 9 — Your solution below

credit = pd.read_csv('https://raw.githubusercontent.com/PedroBSB/BDATA200/main/Data/Credit.csv')

# Use numeric columns only
X = credit.select_dtypes(include=np.number)
feature_names = X.columns

# Scale data
X_scaled = StandardScaler().fit_transform(X)

# Run PCA
pca = PCA()
scores = pca.fit_transform(X_scaled)

# Loadings for first 4 PCs
loadings = pd.DataFrame(
    pca.components_[:4].T,
    index=feature_names,
    columns=["PC1", "PC2", "PC3", "PC4"]
)

print("PCA Loadings:")
print(loadings.round(3))

# Heatmap
plt.figure(figsize=(10, 7))
sns.heatmap(loadings, annot=True, cmap="PuOr", center=0, fmt=".2f")
plt.title("Credit Dataset PCA Loadings: First 4 PCs")
plt.xlabel("Principal Components")
plt.ylabel("Features")
plt.show()

# Biplot PC1 vs PC2
plt.figure(figsize=(10, 7))
plt.scatter(scores[:, 0], scores[:, 1], alpha=0.6)

# Add loading arrows
scale = 4
for i, feature in enumerate(feature_names):
    plt.arrow(
        0,
        0,
        loadings.iloc[i, 0] * scale,
        loadings.iloc[i, 1] * scale,
        head_width=0.08,
        length_includes_head=True
    )
    plt.text(
        loadings.iloc[i, 0] * scale * 1.15,
        loadings.iloc[i, 1] * scale * 1.15,
        feature,
        fontsize=10
    )

plt.title("Biplot: PC1 vs PC2")
plt.xlabel(f"PC1 ({pca.explained_variance_ratio_[0]:.1%} variance)")
plt.ylabel(f"PC2 ({pca.explained_variance_ratio_[1]:.1%} variance)")
plt.grid(True, linestyle="--", alpha=0.4)
plt.show()
# Out:
# PCA Loadings:
#              PC1    PC2    PC3    PC4
# Income     0.445 -0.032  0.149 -0.134
# Limit      0.536 -0.049 -0.035 -0.009
# Rating     0.537 -0.015 -0.039  0.015
# Cards      0.029  0.737 -0.077  0.651
# Age        0.078  0.306  0.896 -0.181
# Education -0.019 -0.600  0.363  0.711
# Balance    0.468 -0.017 -0.186  0.138

# %% [markdown]
# *Write your interpretation here.*
#
# PC1 represents — Overall credit capacity / wealth factor because it usually loads strongly on Income, Limit, Rating, and Balance.
#
# PC2 represents — Credit usage or utilization factor because it separates customers by balance and spending behavior compared with other credit features.
#
# PC3 represents — Demographic or account structure factor because it is influenced more by variables such as Age, Education, or Cards.
#
# PC4 represents — Secondary account behavior factor because it captures smaller leftover patterns not explained by the first three components.

# %% [markdown]
# <div style="background: linear-gradient(135deg, #4B2E83 0%, #32006E 100%); padding: 30px; border-radius: 10px; margin: 40px 0 30px 0; box-shadow: 0 5px 15px rgba(75,46,131,0.2);">
#   <h1 style="color: #FFF; font-family: 'Encode Sans', 'Arial', sans-serif; font-weight: 700; margin: 0; text-shadow: 2px 2px 4px rgba(0,0,0,0.3);">Part 4: Multidimensional Scaling (MDS)</h1>
#   <p style="color: #E8D3FF; font-family: 'Encode Sans', 'Arial', sans-serif; font-size: 1.3em; margin: 10px 0; font-weight: 300;">Preserving Pairwise Distances in Low Dimensions</p>
# </div>

# %% [markdown]
# <div style="border-left: 5px solid #4B2E83; background-color: #F9F7FC; padding: 20px 25px; margin: 20px 0; border-radius: 5px;">
#   <h2 style="color: #4B2E83; font-family: 'Encode Sans', 'Arial', sans-serif; margin-top: 0;">A. Learning Objectives</h2>
#   <ul style="color:#333; line-height:1.8;">
#     <li>Understand MDS as an optimisation that places points in low-d space while preserving pairwise distances.</li>
#     <li>Distinguish <strong>metric MDS</strong> (preserve exact distances) from <strong>non-metric MDS</strong> (preserve rank order).</li>
#     <li>Interpret the <strong>stress</strong> value as a measure of distortion.</li>
#     <li>Know when MDS is preferable to PCA (e.g., when you only have a distance matrix, not raw features).</li>
#   </ul>
# </div>

# %% [markdown]
# <div style="border-left: 5px solid #4B2E83; background-color: #F9F7FC; padding: 20px 25px; margin: 20px 0; border-radius: 5px;">
#   <h2 style="color: #4B2E83; font-family: 'Encode Sans', 'Arial', sans-serif; margin-top: 0;">B. Definition</h2>
#   <p style="font-size: 1.05em; color: #555; line-height: 1.7;">
#     Given an n &times; n distance matrix <strong>D</strong> with entries d<sub>ij</sub>, MDS finds coordinates <strong>y</strong><sub>1</sub>, ..., <strong>y</strong><sub>n</sub> in &#8477;<sup>k</sup> (usually k = 2) that minimise the <strong>stress</strong> function:
#   </p>
#   <p style="text-align:center; font-size:1.15em; color:#333;">
#     Stress = &radic;[ &Sigma;<sub>i&lt;j</sub> (d<sub>ij</sub> &minus; ||y<sub>i</sub> &minus; y<sub>j</sub>||)<sup>2</sup> / &Sigma;<sub>i&lt;j</sub> d<sub>ij</sub><sup>2</sup> ]
#   </p>
#   <p style="font-size: 1.05em; color: #555; line-height: 1.7;">
#     <strong>Metric MDS</strong> uses the actual distances. <strong>Non-metric MDS</strong> only requires that the rank order of distances is preserved (useful for ordinal or subjective similarity data).
#   </p>
# </div>

# %% [markdown]
# <div style="border-left: 5px solid #4B2E83; background-color: #F9F7FC; padding: 20px 25px; margin: 20px 0; border-radius: 5px;">
#   <h2 style="color: #4B2E83; font-family: 'Encode Sans', 'Arial', sans-serif; margin-top: 0;">C. Intuition</h2>
#   <p style="font-size: 1.05em; color: #555; line-height: 1.7;">
#     Imagine you have a table of driving distances between 10 cities, but no map. MDS takes that distance table and reconstructs a 2D map where cities that are far apart in driving distance are far apart on the map, and cities that are close are plotted close together. The "stress" tells you how much distortion the flat map introduces.
#   </p>
# </div>

# %% [markdown]
# <div style="border-left: 5px solid #4B2E83; background-color: #F9F7FC; padding: 20px 25px; margin: 20px 0; border-radius: 5px;">
#   <h2 style="color: #4B2E83; font-family: 'Encode Sans', 'Arial', sans-serif; margin-top: 0;">D. When to Use MDS</h2>
#   <table style="width:100%; border-collapse: collapse; margin-top:10px;">
#     <tr style="background-color: #4B2E83; color: white;">
#       <th style="padding:10px; text-align:left;">Aspect</th>
#       <th style="padding:10px; text-align:left;">Details</th>
#     </tr>
#     <tr style="border-bottom:1px solid #ddd;">
#       <td style="padding:10px;"><strong>Best use cases</strong></td>
#       <td style="padding:10px;">You have only a distance/dissimilarity matrix (no raw features); perceptual mapping; product similarity</td>
#     </tr>
#     <tr style="border-bottom:1px solid #ddd;">
#       <td style="padding:10px;"><strong>Assumptions</strong></td>
#       <td style="padding:10px;">Metric MDS assumes distances are meaningful; non-metric only requires rank order</td>
#     </tr>
#     <tr style="border-bottom:1px solid #ddd;">
#       <td style="padding:10px;"><strong>Strengths</strong></td>
#       <td style="padding:10px;">Works directly from distances; intuitive output; stress gives quality measure</td>
#     </tr>
#     <tr style="border-bottom:1px solid #ddd;">
#       <td style="padding:10px;"><strong>Limitations</strong></td>
#       <td style="padding:10px;">O(n&sup2;) memory for distance matrix; stress can have local minima; no loadings for interpretation</td>
#     </tr>
#     <tr>
#       <td style="padding:10px;"><strong>Common mistakes</strong></td>
#       <td style="padding:10px;">Not checking stress value; using on very large n without subsampling; confusing with PCA</td>
#     </tr>
#   </table>
# </div>

# %% [markdown]
# <div style="border-left: 5px solid #4B2E83; background-color: #F9F7FC; padding: 20px 25px; margin: 20px 0; border-radius: 5px;">
#   <h2 style="color: #4B2E83; font-family: 'Encode Sans', 'Arial', sans-serif; margin-top: 0;">E. Python Demonstrations</h2>
# </div>

# %% [markdown]
# <div style="border-left: 5px solid #4B2E83; background-color: #F9F7FC; padding: 20px 25px; margin: 20px 0; border-radius: 5px;">
#   <h3 style="color: #4B2E83;">Example 4.1 — MDS on Credit Customer Similarity</h3>
#   <p style="color:#555;"><strong>Dataset:</strong> <a href="https://github.com/PedroBSB/BDATA200/tree/main/Data">Credit.csv</a></p>
#   <p style="color:#555;"><strong>Question:</strong> Can MDS reveal customer groups when we start from a distance matrix rather than raw features?</p>
# </div>

# %%
# Example 4.1 — MDS on Credit dataset
credit = pd.read_csv('https://raw.githubusercontent.com/PedroBSB/BDATA200/main/Data/Credit.csv')
X_cr = credit[['Income', 'Limit', 'Balance', 'Rating']].values
X_cr_scaled = StandardScaler().fit_transform(X_cr)

# Compute pairwise distance matrix
D = squareform(pdist(X_cr_scaled))

# Metric MDS
mds_metric = MDS(n_components=2, dissimilarity='precomputed', random_state=42, normalized_stress='auto')
Y_metric = mds_metric.fit_transform(D)

# Non-metric MDS
mds_nonmetric = MDS(n_components=2, metric=False, dissimilarity='precomputed',
                     random_state=42, normalized_stress='auto')
Y_nonmetric = mds_nonmetric.fit_transform(D)

fig, axes = plt.subplots(1, 2, figsize=(14, 6))

for ax, Y, title, stress in [(axes[0], Y_metric, 'Metric MDS', mds_metric.stress_),
                               (axes[1], Y_nonmetric, 'Non-Metric MDS', mds_nonmetric.stress_)]:
    sc = ax.scatter(Y[:, 0], Y[:, 1], c=credit['Balance'], cmap='PuOr',
                    alpha=0.6, s=30, edgecolors='white')
    ax.set_title(f'{title}\nStress = {stress:.2f}', fontsize=14,
                 fontweight='bold', color=UW_DARK)
    ax.set_xlabel('MDS Dim 1')
    ax.set_ylabel('MDS Dim 2')
    plt.colorbar(sc, ax=ax, label='Balance')

plt.tight_layout()
plt.show()

print("\nInterpretation: MDS maps the 4D credit data into 2D while preserving distances.")
print("The colour gradient (Balance) shows a clear structure — high-balance customers")
print("cluster separately from low-balance ones, confirming the distance matrix captures")
print("meaningful customer similarity.")

# %% [markdown]
# <div style="border-left: 5px solid #4B2E83; background-color: #F9F7FC; padding: 20px 25px; margin: 20px 0; border-radius: 5px;">
#   <h3 style="color: #4B2E83;">Example 4.2 — MDS vs PCA Comparison: Auto Dataset</h3>
#   <p style="color:#555;"><strong>Dataset:</strong> <a href="https://github.com/PedroBSB/BDATA200/tree/main/Data">Auto.csv</a></p>
#   <p style="color:#555;"><strong>Question:</strong> Do MDS and PCA produce similar 2D maps for the Auto dataset?</p>
# </div>

# %%
# Example 4.2 — MDS vs PCA on Auto
auto = pd.read_csv('https://raw.githubusercontent.com/PedroBSB/BDATA200/main/Data/Auto.csv', na_values='?').dropna()
cols = ['mpg', 'cylinders', 'displacement', 'horsepower', 'weight', 'acceleration']
X_auto = auto[cols].values.astype(float)
X_auto_scaled = StandardScaler().fit_transform(X_auto)

# PCA
pca_auto = PCA(n_components=2)
Y_pca = pca_auto.fit_transform(X_auto_scaled)

# Metric MDS
D_auto = squareform(pdist(X_auto_scaled))
mds_auto = MDS(n_components=2, dissimilarity='precomputed', random_state=42, normalized_stress='auto')
Y_mds = mds_auto.fit_transform(D_auto)

fig, axes = plt.subplots(1, 2, figsize=(14, 6))
origin = auto['origin'].values
cmap = {1: UW_PURPLE, 2: UW_GOLD, 3: '#C62828'}
labels_map = {1: 'American', 2: 'European', 3: 'Japanese'}

for ax, Y, title in [(axes[0], Y_pca, 'PCA'), (axes[1], Y_mds, 'Metric MDS')]:
    for o in [1, 2, 3]:
        mask = origin == o
        ax.scatter(Y[mask, 0], Y[mask, 1], c=cmap[o], label=labels_map[o],
                   alpha=0.6, s=40, edgecolors='white')
    ax.set_title(title, fontsize=14, fontweight='bold', color=UW_DARK)
    ax.set_xlabel('Dim 1')
    ax.set_ylabel('Dim 2')
    ax.legend(fontsize=10)

plt.tight_layout()
plt.show()

print("\nInterpretation: With Euclidean distances, metric MDS and PCA produce very")
print("similar layouts (up to rotation/reflection). Both separate American (large,")
print("low-mpg) from Japanese (small, high-mpg) cars. MDS is more flexible because")
print("it works from any distance matrix, not just Euclidean.")

# %% [markdown]
# <div style="border-left: 5px solid #4B2E83; background-color: #F9F7FC; padding: 20px 25px; margin: 20px 0; border-radius: 5px;">
#   <h3 style="color: #4B2E83;">Example 4.3 — MDS on OJ Purchase Similarity</h3>
#   <p style="color:#555;"><strong>Dataset:</strong> <a href="https://github.com/PedroBSB/BDATA200/tree/main/Data">OJ.csv</a> — 1,070 orange juice purchases with pricing, promotions, and brand choice.</p>
#   <p style="color:#555;"><strong>Question:</strong> Can MDS reveal distinct purchase behaviour patterns?</p>
# </div>

# %%
# Example 4.3 — MDS on OJ dataset
oj = pd.read_csv('https://raw.githubusercontent.com/PedroBSB/BDATA200/main/Data/OJ.csv')
X_oj = oj.select_dtypes(include=[np.number]).values
X_oj_scaled = StandardScaler().fit_transform(X_oj)

# Subsample for speed
np.random.seed(42)
idx = np.random.choice(len(X_oj_scaled), 300, replace=False)
X_oj_sub = X_oj_scaled[idx]
purchase = oj['Purchase'].values[idx]

D_oj = squareform(pdist(X_oj_sub))
mds_oj = MDS(n_components=2, dissimilarity='precomputed', random_state=42, normalized_stress='auto')
Y_oj = mds_oj.fit_transform(D_oj)

fig, ax = plt.subplots(figsize=(10, 7))
for brand, color in [('CH', UW_PURPLE), ('MM', UW_GOLD)]:
    mask = purchase == brand
    ax.scatter(Y_oj[mask, 0], Y_oj[mask, 1], c=color, label=brand,
               alpha=0.6, s=50, edgecolors='white')
ax.set_xlabel('MDS Dim 1', fontsize=13)
ax.set_ylabel('MDS Dim 2', fontsize=13)
ax.set_title(f'MDS Map of OJ Purchases\nStress = {mds_oj.stress_:.2f}',
             fontsize=15, fontweight='bold', color=UW_DARK)
ax.legend(fontsize=12, title='Brand')
plt.tight_layout()
plt.show()

print("\nInterpretation: MDS reveals partial separation between Citrus Hill (CH) and")
print("Minute Maid (MM) purchasers, driven by pricing and promotion differences.")
print("Overlap indicates that some purchase occasions look similar regardless of brand.")

# %% [markdown]
# <div style="background-color: #FFF3E0; border-left: 4px solid #F57C00; padding: 15px 20px; margin: 20px 0; border-radius: 5px;">
#   <h3 style="color: #F57C00; margin-top: 0;">Exercise 10 — Compare MDS to PCA</h3>
# </div>
#
# **Task:** Using the **College.csv** dataset:
# 1. Compute PCA (2 components) on the scaled numeric features.
# 2. Compute metric MDS (2 components) from the Euclidean distance matrix.
# 3. Plot both results side-by-side, coloured by Private/Public.
# 4. Compute the Procrustes distance between the two configurations.
# 5. Explain: should they be similar? Why or why not?

# %%
# Exercise 10 — Your solution below

from scipy.spatial import procrustes
from scipy.spatial.distance import pdist, squareform
from sklearn.manifold import MDS

college = pd.read_csv('https://raw.githubusercontent.com/PedroBSB/BDATA200/main/Data/College.csv')

# Numeric columns only
X = college.select_dtypes(include=np.number)

# Scale numeric features
X_scaled = StandardScaler().fit_transform(X)

# Private/Public labels
private_labels = college["Private"]

# PCA with 2 components
pca = PCA(n_components=2)
pca_scores = pca.fit_transform(X_scaled)

# Metric MDS from Euclidean distance matrix
distance_matrix = squareform(pdist(X_scaled, metric="euclidean"))

mds = MDS(
    n_components=2,
    dissimilarity="precomputed",
    random_state=42,
    normalized_stress="auto"
)

mds_scores = mds.fit_transform(distance_matrix)

# Procrustes distance
mtx1, mtx2, disparity = procrustes(pca_scores, mds_scores)

print("Procrustes distance:", round(disparity, 4))
print("MDS stress:", round(mds.stress_, 4))

# Plot PCA and MDS side-by-side
fig, axes = plt.subplots(1, 2, figsize=(14, 6))

for label, color in [("Yes", "#4B2E83"), ("No", "#F2C120")]:
    mask = private_labels == label

    axes[0].scatter(
        pca_scores[mask, 0],
        pca_scores[mask, 1],
        label="Private" if label == "Yes" else "Public",
        alpha=0.6,
        color=color
    )

    axes[1].scatter(
        mds_scores[mask, 0],
        mds_scores[mask, 1],
        label="Private" if label == "Yes" else "Public",
        alpha=0.6,
        color=color
    )

axes[0].set_title("PCA: College Dataset")
axes[0].set_xlabel("PC1")
axes[0].set_ylabel("PC2")
axes[0].legend()
axes[0].grid(True, linestyle="--", alpha=0.4)

axes[1].set_title("Metric MDS: College Dataset")
axes[1].set_xlabel("MDS Dimension 1")
axes[1].set_ylabel("MDS Dimension 2")
axes[1].legend()
axes[1].grid(True, linestyle="--", alpha=0.4)

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_32367/3060251769.py in <cell line: 0>()
#      30 )
#      31
# ---> 32 mds_scores = mds.fit_transform(distance_matrix)
#      33
#      34 # Procrustes distance
#
# /usr/local/lib/python3.12/dist-packages/sklearn/base.py in wrapper(estimator, *args, **kwargs)
#    1387                 )
#    1388             ):
# -> 1389                 return fit_method(estimator, *args, **kwargs)
#    1390
#    1391         return wrapper
#
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py in fit_transform(self, X, y, init)
#     642             self.dissimilarity_matrix_ = euclidean_distances(X)
#     643
# --> 644         self.embedding_, self.stress_, self.n_iter_ = smacof(
#     645             self.dissimilarity_matrix_,
#     646             metric=self.metric,
#
# ...

# %% [markdown]
# *Write your interpretation here.*
#
# Are the two plots similar? — Yes, the PCA and MDS plots should look somewhat similar because both are using the same scaled numeric College data and Euclidean distance information.
#
# Procrustes distance — The Procrustes distance measures how different the PCA and MDS layouts are after adjusting for rotation, scaling, and reflection. A smaller value means the layouts are more similar.
#
# When would MDS and PCA diverge? — MDS and PCA would diverge more when the data has nonlinear structure, when a non-Euclidean distance is used, or when the distance relationships cannot be represented well by only two dimensions.

# %% [markdown]
# <div style="background-color: #FFF3E0; border-left: 4px solid #F57C00; padding: 15px 20px; margin: 20px 0; border-radius: 5px;">
#   <h3 style="color: #F57C00; margin-top: 0;">Exercise 11 — Visualise a Custom Distance Matrix</h3>
# </div>
#
# **Task:** Create a custom 8x8 distance matrix representing perceived similarity between 8 car brands of your choice (e.g., Toyota, BMW, Ford, Tesla, Honda, Mercedes, Chevrolet, Audi). Fill in distances based on your intuition (0 = identical, 10 = completely different).
# 1. Run MDS on your custom matrix.
# 2. Label each point with the brand name.
# 3. Does the 2D map match your intuition?
# 4. What is the stress value?

# %%
# Exercise 11 — Your solution below

# --- Your code here ---

# Exercise 11 — Your solution below

brands = ["Toyota", "Honda", "Ford", "Chevrolet", "BMW", "Mercedes", "Audi", "Tesla"]

# Custom distance matrix
# 0 = identical, 10 = completely different
distance_matrix = np.array([
    [0, 2, 5, 5, 7, 8, 7, 6],  # Toyota
    [2, 0, 5, 5, 7, 8, 7, 6],  # Honda
    [5, 5, 0, 2, 7, 8, 7, 7],  # Ford
    [5, 5, 2, 0, 7, 8, 7, 7],  # Chevrolet
    [7, 7, 7, 7, 0, 2, 2, 6],  # BMW
    [8, 8, 8, 8, 2, 0, 2, 6],  # Mercedes
    [7, 7, 7, 7, 2, 2, 0, 6],  # Audi
    [6, 6, 7, 7, 6, 6, 6, 0]   # Tesla
])

# Run MDS
mds = MDS(
    n_components=2,
    dissimilarity="precomputed",
    random_state=42,
    normalized_stress="auto"
)

mds_scores = mds.fit_transform(distance_matrix)

# Print stress value
print("MDS Stress Value:", round(mds.stress_, 4))

# Plot MDS map
plt.figure(figsize=(10, 7))
plt.scatter(mds_scores[:, 0], mds_scores[:, 1], s=120, alpha=0.8)

# Label each point
for i, brand in enumerate(brands):
    plt.text(
        mds_scores[i, 0] + 0.08,
        mds_scores[i, 1] + 0.08,
        brand,
        fontsize=11
    )

plt.title("MDS Map of Car Brand Similarity")
plt.xlabel("MDS Dimension 1")
plt.ylabel("MDS Dimension 2")
plt.grid(True, linestyle="--", alpha=0.4)
plt.show()
# Out:
# MDS Stress Value: 12.3205

# %% [markdown]
# *Write your interpretation here.*
#
# The 2D map mostly matches my intuition. Toyota and Honda appear close together because they are both practical Japanese brands. Ford and Chevrolet are close because they are American mainstream brands. BMW, Mercedes, and Audi group together because they are luxury German brands. Tesla is somewhat separate because it is strongly associated with electric vehicles and technology. The stress value shows how much distortion exists in the 2D map, with lower stress meaning a better fit.

# %% [markdown]
# <div style="background-color: #FFF3E0; border-left: 4px solid #F57C00; padding: 15px 20px; margin: 20px 0; border-radius: 5px;">
#   <h3 style="color: #F57C00; margin-top: 0;">Exercise 12 — Interpret Stress Values</h3>
# </div>
#
# **Task:** Using the **Hitters.csv** dataset:
# 1. Compute MDS in 1, 2, 3, 4, and 5 dimensions.
# 2. Record the stress value for each.
# 3. Plot stress vs number of dimensions.
# 4. At what dimensionality does adding more dimensions stop helping?
# 5. Use the rule of thumb: stress < 0.1 = good, < 0.05 = excellent.

# %%
# Exercise 12 — Your solution below

from scipy.spatial.distance import pdist, squareform
from sklearn.manifold import MDS

hitters = pd.read_csv('https://raw.githubusercontent.com/PedroBSB/BDATA200/main/Data/Hitters.csv').dropna()

# Numeric columns only
X = hitters.select_dtypes(include=np.number)

# Scale data
X_scaled = StandardScaler().fit_transform(X)

# Distance matrix
distance_matrix = squareform(pdist(X_scaled, metric="euclidean"))

# Run MDS from 1 to 5 dimensions
dimensions = [1, 2, 3, 4, 5]
stress_values = []

for dim in dimensions:
    mds = MDS(
        n_components=dim,
        dissimilarity="precomputed",
        random_state=42,
        normalized_stress="auto"
    )

    mds_scores = mds.fit_transform(distance_matrix)
    stress_values.append(mds.stress_)

    print(f"{dim} dimensions stress:", round(mds.stress_, 4))

# Plot stress vs dimensions
plt.figure(figsize=(9, 6))
plt.plot(dimensions, stress_values, marker="o")
plt.title("MDS Stress vs Number of Dimensions — Hitters Dataset")
plt.xlabel("Number of Dimensions")
plt.ylabel("Stress Value")
plt.xticks(dimensions)
plt.grid(True, linestyle="--", alpha=0.4)
plt.show()
# Out:
# 1 dimensions stress: 260354.8199
# 2 dimensions stress: 34311.6347
# 3 dimensions stress: 10755.7223
# 4 dimensions stress: 4536.7908
# 5 dimensions stress: 1995.244

# %% [markdown]
# *Write your interpretation here.*
# Stress at each dimensionality — The stress value decreases as the number of dimensions increases. This means the MDS layout preserves the original distances better when more dimensions are allowed.
#
# Elbow point — The elbow point is where the stress curve starts flattening out. After that point, adding more dimensions still lowers stress, but the improvement becomes smaller.
#
# Recommended number of dimensions — I would recommend the dimensionality near the elbow point. If the stress is below 0.1, that is considered good, and if it is below 0.05, it is excellent. If the curve flattens around 3 dimensions, then 3D is a good balance between accuracy and simplicity.

# %% [markdown]
# <div style="background: linear-gradient(135deg, #4B2E83 0%, #32006E 100%); padding: 30px; border-radius: 10px; margin: 40px 0 30px 0; box-shadow: 0 5px 15px rgba(75,46,131,0.2);">
#   <h1 style="color: #FFF; font-family: 'Encode Sans', 'Arial', sans-serif; font-weight: 700; margin: 0; text-shadow: 2px 2px 4px rgba(0,0,0,0.3);">Part 5: Correspondence Analysis (CA)</h1>
#   <p style="color: #E8D3FF; font-family: 'Encode Sans', 'Arial', sans-serif; font-size: 1.3em; margin: 10px 0; font-weight: 300;">Mapping Relationships Between Categories</p>
# </div>

# %% [markdown]
# <div style="border-left: 5px solid #4B2E83; background-color: #F9F7FC; padding: 20px 25px; margin: 20px 0; border-radius: 5px;">
#   <h2 style="color: #4B2E83; font-family: 'Encode Sans', 'Arial', sans-serif; margin-top: 0;">A. Learning Objectives</h2>
#   <ul style="color:#333; line-height:1.8;">
#     <li>Understand correspondence analysis as PCA for categorical data (contingency tables).</li>
#     <li>Explain <strong>row profiles</strong>, <strong>column profiles</strong>, and <strong>chi-square distances</strong>.</li>
#     <li>Interpret a <strong>symmetric map</strong> (biplot) showing both row and column categories.</li>
#     <li>Know when CA is appropriate and when to use alternatives.</li>
#   </ul>
# </div>

# %% [markdown]
# <div style="border-left: 5px solid #4B2E83; background-color: #F9F7FC; padding: 20px 25px; margin: 20px 0; border-radius: 5px;">
#   <h2 style="color: #4B2E83; font-family: 'Encode Sans', 'Arial', sans-serif; margin-top: 0;">B. Definition</h2>
#   <p style="font-size: 1.05em; color: #555; line-height: 1.7;">
#     Given a contingency table <strong>N</strong> (r rows &times; c columns), CA decomposes the <strong>standardised residuals</strong> from independence using SVD:
#   </p>
#   <ol style="color:#333; line-height:1.8;">
#     <li>Compute the <strong>correspondence matrix</strong>: P = N / n (where n = total count).</li>
#     <li>Compute row masses <strong>r</strong> = row sums of P, column masses <strong>c</strong> = column sums of P.</li>
#     <li>Compute standardised residuals: S<sub>ij</sub> = (P<sub>ij</sub> &minus; r<sub>i</sub>c<sub>j</sub>) / &radic;(r<sub>i</sub>c<sub>j</sub>).</li>
#     <li>Apply SVD to <strong>S</strong> to get row and column coordinates in a low-dimensional space.</li>
#   </ol>
#   <p style="font-size: 1.05em; color: #555; line-height: 1.7;">
#     The <strong>total inertia</strong> equals Pearson's &chi;&sup2;/n and measures the strength of the row-column association.
#   </p>
# </div>

# %% [markdown]
# <div style="border-left: 5px solid #4B2E83; background-color: #F9F7FC; padding: 20px 25px; margin: 20px 0; border-radius: 5px;">
#   <h2 style="color: #4B2E83; font-family: 'Encode Sans', 'Arial', sans-serif; margin-top: 0;">C. Intuition</h2>
#   <p style="font-size: 1.05em; color: #555; line-height: 1.7;">
#     Think of a survey where respondents (rows) rated products (columns). CA produces a 2D map where:
#   </p>
#   <ul style="color:#333; line-height:1.8;">
#     <li>Respondents who gave <em>similar ratings</em> appear close together.</li>
#     <li>Products that received <em>similar ratings</em> appear close together.</li>
#     <li>A respondent near a product means that respondent rated that product higher than average.</li>
#   </ul>
#   <p style="font-size: 1.05em; color: #555; line-height: 1.7;">
#     It's like PCA, but for <em>cross-tabulated categorical</em> data.
#   </p>
# </div>

# %% [markdown]
# <div style="border-left: 5px solid #4B2E83; background-color: #F9F7FC; padding: 20px 25px; margin: 20px 0; border-radius: 5px;">
#   <h2 style="color: #4B2E83; font-family: 'Encode Sans', 'Arial', sans-serif; margin-top: 0;">D. When to Use CA</h2>
#   <table style="width:100%; border-collapse: collapse; margin-top:10px;">
#     <tr style="background-color: #4B2E83; color: white;">
#       <th style="padding:10px; text-align:left;">Aspect</th>
#       <th style="padding:10px; text-align:left;">Details</th>
#     </tr>
#     <tr style="border-bottom:1px solid #ddd;">
#       <td style="padding:10px;"><strong>Best use cases</strong></td>
#       <td style="padding:10px;">Cross-tabulations, survey responses, demographics &times; preferences, text analysis (word &times; document)</td>
#     </tr>
#     <tr style="border-bottom:1px solid #ddd;">
#       <td style="padding:10px;"><strong>Assumptions</strong></td>
#       <td style="padding:10px;">Data are counts in a contingency table; non-negative; chi-square distance is appropriate</td>
#     </tr>
#     <tr style="border-bottom:1px solid #ddd;">
#       <td style="padding:10px;"><strong>Strengths</strong></td>
#       <td style="padding:10px;">Handles categorical data natively; produces interpretable joint maps; scale-free</td>
#     </tr>
#     <tr style="border-bottom:1px solid #ddd;">
#       <td style="padding:10px;"><strong>Limitations</strong></td>
#       <td style="padding:10px;">Only for two-way tables (use MCA for more); sensitive to rare categories; distances between row and column points require careful interpretation</td>
#     </tr>
#     <tr>
#       <td style="padding:10px;"><strong>Common mistakes</strong></td>
#       <td style="padding:10px;">Interpreting row-to-column distances literally (only row-row and col-col distances are valid); ignoring low-inertia axes</td>
#     </tr>
#   </table>
# </div>

# %% [markdown]
# <div style="border-left: 5px solid #4B2E83; background-color: #F9F7FC; padding: 20px 25px; margin: 20px 0; border-radius: 5px;">
#   <h2 style="color: #4B2E83; font-family: 'Encode Sans', 'Arial', sans-serif; margin-top: 0;">E. Python Demonstrations</h2>
# </div>

# %% [markdown]
# <div style="border-left: 5px solid #4B2E83; background-color: #F9F7FC; padding: 20px 25px; margin: 20px 0; border-radius: 5px;">
#   <h3 style="color: #4B2E83;">Example 5.1 — CA on Wage Education &times; Job Class</h3>
#   <p style="color:#555;"><strong>Dataset:</strong> <a href="https://github.com/PedroBSB/BDATA200/tree/main/Data">Wage.csv</a> — 3,000 workers with education level, job class, and wage.</p>
#   <p style="color:#555;"><strong>Question:</strong> How are education levels associated with job classes (Industrial vs Information)?</p>
# </div>

# %%
# Example 5.1 — Correspondence Analysis on Wage
wage = pd.read_csv('https://raw.githubusercontent.com/PedroBSB/BDATA200/main/Data/Wage.csv')

# Build contingency table: education × marital status (both have 5 levels)
ct = pd.crosstab(wage['education'], wage['maritl'])
print("Contingency Table:")
print(ct)
print()

# Run CA using prince
ca = prince.CA(n_components=2, random_state=42)
ca = ca.fit(ct)

fig, ax = plt.subplots(figsize=(10, 8))

# Row coordinates (education levels)
row_coords = ca.row_coordinates(ct)
ax.scatter(row_coords.iloc[:, 0], row_coords.iloc[:, 1],
           c=UW_PURPLE, s=150, zorder=5, edgecolors='white')
for idx_name in row_coords.index:
    ax.annotate(str(idx_name),
                (row_coords.loc[idx_name].iloc[0], row_coords.loc[idx_name].iloc[1]),
                fontsize=10, fontweight='bold', color=UW_PURPLE, ha='center', va='bottom',
                xytext=(0, 10), textcoords='offset points')

# Column coordinates (marital status)
col_coords = ca.column_coordinates(ct)
ax.scatter(col_coords.iloc[:, 0], col_coords.iloc[:, 1],
           c=UW_GOLD, s=150, marker='s', zorder=5, edgecolors='white')
for idx_name in col_coords.index:
    ax.annotate(str(idx_name),
                (col_coords.loc[idx_name].iloc[0], col_coords.loc[idx_name].iloc[1]),
                fontsize=10, fontweight='bold', color='#85714D', ha='center', va='bottom',
                xytext=(0, 10), textcoords='offset points')

ax.axhline(0, color='grey', linewidth=0.5, linestyle='--')
ax.axvline(0, color='grey', linewidth=0.5, linestyle='--')
ax.set_xlabel(f'Dimension 1 ({ca.percentage_of_variance_[0]:.1f}%)', fontsize=13)
ax.set_ylabel(f'Dimension 2 ({ca.percentage_of_variance_[1]:.1f}%)', fontsize=13)
ax.set_title('Correspondence Analysis: Education × Marital Status',
             fontsize=15, fontweight='bold', color=UW_DARK)
ax.legend(['Education Level', 'Marital Status'], fontsize=11)

plt.tight_layout()
plt.show()

print("\nInterpretation: Education levels close to a marital status on the map are")
print("disproportionately associated. The map reveals demographic patterns — for")
print("example, advanced degree holders may cluster near certain marital categories,")
print("reflecting age and socioeconomic correlations in the data.")

# %% [markdown]
# <div style="border-left: 5px solid #4B2E83; background-color: #F9F7FC; padding: 20px 25px; margin: 20px 0; border-radius: 5px;">
#   <h3 style="color: #4B2E83;">Example 5.2 — CA on Heart Disease: Chest Pain × Thalassemia</h3>
#   <p style="color:#555;"><strong>Dataset:</strong> <a href="https://github.com/PedroBSB/BDATA200/tree/main/Data">Heart.csv</a></p>
#   <p style="color:#555;"><strong>Question:</strong> How are chest pain types associated with thalassemia categories?</p>
# </div>

# %%
# Example 5.2 — CA on Heart Disease: Chest Pain × Thalassemia
heart = pd.read_csv('https://raw.githubusercontent.com/PedroBSB/BDATA200/main/Data/Heart.csv').dropna()

# Map numeric codes to descriptive labels
cp_map = {1: 'Typical Angina', 2: 'Atypical Angina', 3: 'Non-Anginal', 4: 'Asymptomatic'}
thal_map = {3: 'Normal', 6: 'Fixed Defect', 7: 'Reversible Defect'}
heart['ChestPain'] = heart['cp'].map(cp_map)
heart['Thal'] = heart['thal'].map(thal_map)

ct_heart = pd.crosstab(heart['ChestPain'], heart['Thal'])
print("Contingency Table:")
print(ct_heart)
print()

ca_heart = prince.CA(n_components=2, random_state=42)
ca_heart = ca_heart.fit(ct_heart)

fig, ax = plt.subplots(figsize=(9, 7))

row_c = ca_heart.row_coordinates(ct_heart)
col_c = ca_heart.column_coordinates(ct_heart)

ax.scatter(row_c.iloc[:, 0], row_c.iloc[:, 1], c=UW_PURPLE, s=150, zorder=5, edgecolors='white')
for name in row_c.index:
    ax.annotate(str(name), (row_c.loc[name].iloc[0], row_c.loc[name].iloc[1]),
                fontsize=11, fontweight='bold', color=UW_PURPLE,
                xytext=(5, 8), textcoords='offset points')

ax.scatter(col_c.iloc[:, 0], col_c.iloc[:, 1], c='#C62828', s=200, marker='D', zorder=5, edgecolors='white')
for name in col_c.index:
    ax.annotate(str(name), (col_c.loc[name].iloc[0], col_c.loc[name].iloc[1]),
                fontsize=12, fontweight='bold', color='#C62828',
                xytext=(5, 8), textcoords='offset points')

ax.axhline(0, color='grey', linewidth=0.5, linestyle='--')
ax.axvline(0, color='grey', linewidth=0.5, linestyle='--')
ax.set_xlabel(f'Dimension 1 ({ca_heart.percentage_of_variance_[0]:.1f}%)', fontsize=13)
ax.set_ylabel(f'Dimension 2 ({ca_heart.percentage_of_variance_[1]:.1f}%)', fontsize=13)
ax.set_title('CA: Chest Pain Type × Thalassemia Type',
             fontsize=15, fontweight='bold', color=UW_DARK)

plt.tight_layout()
plt.show()

print("\nInterpretation: The CA map reveals how chest pain types are associated with")
print("thalassemia categories. Asymptomatic chest pain may cluster with reversible")
print("defects — both are strong indicators of heart disease, while normal thalassemia")
print("clusters near less severe chest pain types.")

# %% [markdown]
# <div style="border-left: 5px solid #4B2E83; background-color: #F9F7FC; padding: 20px 25px; margin: 20px 0; border-radius: 5px;">
#   <h3 style="color: #4B2E83;">Example 5.3 — CA on Carseats: Shelf Location &times; Urban/US</h3>
#   <p style="color:#555;"><strong>Dataset:</strong> <a href="https://github.com/PedroBSB/BDATA200/tree/main/Data">Carseats.csv</a> — 400 stores with car seat sales, shelf location, and demographics.</p>
#   <p style="color:#555;"><strong>Question:</strong> Is shelf location related to whether the store is urban and/or in the US?</p>
# </div>

# %%
# Example 5.3 — CA on Carseats
carseats = pd.read_csv('https://raw.githubusercontent.com/PedroBSB/BDATA200/main/Data/Carseats.csv')

# Create a combined category
carseats['StoreType'] = carseats['Urban'] + '_' + carseats['US']
ct_cs = pd.crosstab(carseats['ShelveLoc'], carseats['StoreType'])
print("Contingency Table:")
print(ct_cs)
print()

ca_cs = prince.CA(n_components=2, random_state=42)
ca_cs = ca_cs.fit(ct_cs)

fig, ax = plt.subplots(figsize=(10, 7))

row_c = ca_cs.row_coordinates(ct_cs)
col_c = ca_cs.column_coordinates(ct_cs)

ax.scatter(row_c.iloc[:, 0], row_c.iloc[:, 1], c=UW_PURPLE, s=150, zorder=5, edgecolors='white')
for name in row_c.index:
    ax.annotate(str(name), (row_c.loc[name].iloc[0], row_c.loc[name].iloc[1]),
                fontsize=11, fontweight='bold', color=UW_PURPLE,
                xytext=(5, 8), textcoords='offset points')

ax.scatter(col_c.iloc[:, 0], col_c.iloc[:, 1], c=UW_GOLD, s=150, marker='^', zorder=5, edgecolors='white')
for name in col_c.index:
    ax.annotate(str(name), (col_c.loc[name].iloc[0], col_c.loc[name].iloc[1]),
                fontsize=11, fontweight='bold', color='#85714D',
                xytext=(5, 8), textcoords='offset points')

ax.axhline(0, color='grey', linewidth=0.5, linestyle='--')
ax.axvline(0, color='grey', linewidth=0.5, linestyle='--')
ax.set_xlabel('Dimension 1', fontsize=13)
ax.set_ylabel('Dimension 2', fontsize=13)
ax.set_title('CA: Shelf Location × Store Type (Urban × US)',
             fontsize=15, fontweight='bold', color=UW_DARK)

plt.tight_layout()
plt.show()

print("\nInterpretation: The CA map shows how shelf location quality varies by store")
print("type. Good shelving may cluster with certain store profiles, suggesting")
print("strategic placement decisions differ by location demographics.")

# %% [markdown]
# <div style="background-color: #FFF3E0; border-left: 4px solid #F57C00; padding: 15px 20px; margin: 20px 0; border-radius: 5px;">
#   <h3 style="color: #F57C00; margin-top: 0;">Exercise 13 — Build a Contingency Table and Run CA</h3>
# </div>
#
# **Task:** Using the **Wage.csv** dataset:
# 1. Create a contingency table of `education` × `race`.
# 2. Run a chi-square test of independence. Is the association significant?
# 3. Run CA and plot the symmetric map.
# 4. Which education-race combinations are most strongly associated?

# %%
# Exercise 13 — Your solution below

from scipy.stats import chi2_contingency

wage = pd.read_csv('https://raw.githubusercontent.com/PedroBSB/BDATA200/main/Data/Wage.csv')

# Contingency table: education × race
ct = pd.crosstab(wage["education"], wage["race"])

print("Contingency Table:")
print(ct)

# Chi-square test
chi2, p_value, dof, expected = chi2_contingency(ct)

print("\nChi-square statistic:", round(chi2, 4))
print("p-value:", p_value)
print("Degrees of freedom:", dof)

# Correspondence Analysis
ca = prince.CA(n_components=2, random_state=42)
ca = ca.fit(ct)

row_coords = ca.row_coordinates(ct)
col_coords = ca.column_coordinates(ct)

print("\nExplained inertia:")
print(ca.percentage_of_variance_)

# Plot symmetric map
fig, ax = plt.subplots(figsize=(10, 8))

ax.scatter(row_coords.iloc[:, 0], row_coords.iloc[:, 1],
           s=150, label="Education", edgecolors="white")

for name in row_coords.index:
    ax.annotate(str(name),
                (row_coords.loc[name].iloc[0], row_coords.loc[name].iloc[1]),
                xytext=(5, 8), textcoords="offset points",
                fontsize=10)

ax.scatter(col_coords.iloc[:, 0], col_coords.iloc[:, 1],
           s=180, marker="s", label="Race", edgecolors="white")

for name in col_coords.index:
    ax.annotate(str(name),
                (col_coords.loc[name].iloc[0], col_coords.loc[name].iloc[1]),
                xytext=(5, 8), textcoords="offset points",
                fontsize=10)

ax.axhline(0, color="gray", linestyle="--", linewidth=0.8)
ax.axvline(0, color="gray", linestyle="--", linewidth=0.8)

ax.set_title("Correspondence Analysis: Education × Race")
ax.set_xlabel(f"Dimension 1 ({ca.percentage_of_variance_[0]:.1f}%)")
ax.set_ylabel(f"Dimension 2 ({ca.percentage_of_variance_[1]:.1f}%)")
ax.legend()
ax.grid(True, linestyle="--", alpha=0.4)

plt.tight_layout()
plt.show()
# Out:
# Contingency Table:
# race                1. White  2. Black  3. Asian  4. Other
# education
# 1. < HS Grad             211        31        15        11
# 2. HS Grad               822       105        31        13
# 3. Some College          532        92        18         8
# 4. College Grad          576        40        66         3
# 5. Advanced Degree       339        25        60         2
#
# Chi-square statistic: 138.0349
# p-value: 1.4923586299864576e-23
# Degrees of freedom: 12
#
# Explained inertia:
# [82.33327111 13.6817982 ]

# %% [markdown]
# *Write your interpretation here.*
#
# Chi-square p-value — If the chi-square p-value is less than 0.05, we reject independence and conclude that race and education are associated in this sample.
#
# Strongest associations on the map — Categories plotted near each other are more strongly connected than expected under independence. The strongest patterns are usually the points that are farthest away from the center of the CA plot.
#
# Total inertia and what it means — Inertia shows how much deviation there is from independence in the contingency table. A small inertia means the relationship exists but may not be very strong.

# %% [markdown]
# <div style="background-color: #FFF3E0; border-left: 4px solid #F57C00; padding: 15px 20px; margin: 20px 0; border-radius: 5px;">
#   <h3 style="color: #F57C00; margin-top: 0;">Exercise 14 — CA on Health × Marital Status</h3>
# </div>
#
# **Task:** Using the **Wage.csv** dataset:
# 1. Create a contingency table of `health` × `maritl` (marital status).
# 2. Run CA and produce the biplot.
# 3. Interpret: which marital status categories are associated with better/worse health?
# 4. Compare the explained inertia of dimension 1 vs dimension 2.

# %%
# Exercise 14 — Your solution below

wage = pd.read_csv('https://raw.githubusercontent.com/PedroBSB/BDATA200/main/Data/Wage.csv')

# Contingency table: health × marital status
ct = pd.crosstab(wage["health"], wage["maritl"])

print("Contingency Table:")
print(ct)

# Run CA with only 1 dimension because health has 2 categories
ca = prince.CA(n_components=1, random_state=42)
ca = ca.fit(ct)

row_coords = ca.row_coordinates(ct)
col_coords = ca.column_coordinates(ct)

print("\nRow coordinates:")
print(row_coords)

print("\nColumn coordinates:")
print(col_coords)

# Make y-values zero because only 1 CA dimension exists
row_x = row_coords.iloc[:, 0]
row_y = np.zeros(len(row_x))

col_x = col_coords.iloc[:, 0]
col_y = np.zeros(len(col_x))

# Plot 1D CA map
fig, ax = plt.subplots(figsize=(12, 4))

ax.scatter(row_x, row_y, s=160, label="Health")
for name, x in row_x.items():
    ax.text(x, 0.04, str(name), ha="center", fontsize=10)

ax.scatter(col_x, col_y, s=180, marker="s", label="Marital Status")
for name, x in col_x.items():
    ax.text(x, -0.07, str(name), ha="center", fontsize=10)

ax.axhline(0, color="gray", linestyle="--", linewidth=0.8)
ax.axvline(0, color="gray", linestyle="--", linewidth=0.8)

ax.set_title("Correspondence Analysis: Health × Marital Status")
ax.set_xlabel("Dimension 1")
ax.set_yticks([])
ax.legend()
ax.grid(True, axis="x", linestyle="--", alpha=0.4)

plt.tight_layout()
plt.show()
# Out:
# Contingency Table:
# maritl          1. Never Married  2. Married  3. Widowed  4. Divorced  \
# health
# 1. <=Good                    186         568           7           79
# 2. >=Very Good               462        1506          12          125
#
# maritl          5. Separated
# health
# 1. <=Good                 18
# 2. >=Very Good            37
#
# Row coordinates:
#                        0
# health
# 1. <=Good       0.103335
# 2. >=Very Good -0.041392
#
# Column coordinates:
#                          0
# maritl
# 1. Never Married  0.002295
# 2. Married       -0.026850
# 3. Widowed        0.182392
# 4. Divorced       0.224070
# 5. Separated      0.091334

# %% [markdown]
# *Write your interpretation here.*
#
# Associations found — The CA map suggests that Married and Never Married categories are closer to the “>=Very Good” health category, while Divorced, Widowed, and Separated appear closer to the “<=Good” health category. This indicates that some marital status groups may be associated with better or worse self-reported health in the Wage dataset.
#
# Inertia of Dim 1 vs Dim 2 — Because the health variable only has two categories, the correspondence analysis produces only one meaningful dimension. Dimension 1 captures the main association pattern between health and marital status, while Dimension 2 does not exist for this table.
#
# Caveats of this analysis — Correspondence analysis only shows association and not causation. Other variables such as age, income, education, or occupation could also influence both marital status and health outcomes.

# %% [markdown]
# <div style="background-color: #FFF3E0; border-left: 4px solid #F57C00; padding: 15px 20px; margin: 20px 0; border-radius: 5px;">
#   <h3 style="color: #F57C00; margin-top: 0;">Exercise 15 — Interpret a Row/Column Map</h3>
# </div>
#
# **Task:** Using the **Heart.csv** dataset:
# 1. Create a contingency table of `Thal` × `AHD` (heart disease).
# 2. Run CA. Plot the map.
# 3. Which Thal categories are most associated with heart disease?
# 4. Add the chi-square test result to your interpretation.
# 5. Discuss: could you have seen this pattern in a simple bar chart? What does CA add?

# %%
# Exercise 15 — Your solution below

from scipy.stats import chi2_contingency

heart = pd.read_csv(
    "https://raw.githubusercontent.com/PedroBSB/BDATA200/main/Data/Heart.csv"
).dropna()

# Map thal codes to readable names
thal_map = {
    3: "Normal",
    6: "Fixed Defect",
    7: "Reversible Defect"
}

heart["Thal_Label"] = heart["thal"].map(thal_map)

# Contingency table
ct = pd.crosstab(heart["Thal_Label"], heart["AHD"])

print("Contingency Table:")
print(ct)

# Chi-square test
chi2, p_value, dof, expected = chi2_contingency(ct)

print("\nChi-square statistic:", round(chi2, 4))
print("p-value:", p_value)
print("Degrees of freedom:", dof)

# Run CA with 1 dimension because AHD has only 2 categories
ca = prince.CA(n_components=1, random_state=42)
ca = ca.fit(ct)

row_coords = ca.row_coordinates(ct)
col_coords = ca.column_coordinates(ct)

# Plot 1D CA map
fig, ax = plt.subplots(figsize=(12, 4))

ax.scatter(row_coords.iloc[:, 0], np.zeros(len(row_coords)), s=180, label="Thal")
for i, name in enumerate(row_coords.index):
    ax.text(row_coords.iloc[i, 0], 0.05, str(name), ha="center", fontsize=10)

ax.scatter(col_coords.iloc[:, 0], np.zeros(len(col_coords)), s=200, marker="s", label="AHD")
for i, name in enumerate(col_coords.index):
    ax.text(col_coords.iloc[i, 0], -0.08, str(name), ha="center", fontsize=10)

ax.axhline(0, color="gray", linestyle="--")
ax.axvline(0, color="gray", linestyle="--")

ax.set_title("Correspondence Analysis: Thal × AHD")
ax.set_xlabel("Dimension 1")
ax.set_yticks([])
ax.legend()
ax.grid(True, axis="x", linestyle="--", alpha=0.4)

plt.tight_layout()
plt.show()

print(heart.columns)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'AHD'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_32367/2631673803.py in <cell line: 0>()
#      17
#      18 # Contingency table
# ...

# %% [markdown]
# *Write your interpretation here.*
#
# 1. **Thal categories associated with AHD** —
# 2. **Chi-square result** —
# 3. **What CA adds over a bar chart** —

# %% [markdown]
# <div style="background: linear-gradient(135deg, #4B2E83 0%, #32006E 100%); padding: 30px; border-radius: 10px; margin: 40px 0 30px 0; box-shadow: 0 5px 15px rgba(75,46,131,0.2);">
#   <h1 style="color: #FFF; font-family: 'Encode Sans', 'Arial', sans-serif; font-weight: 700; margin: 0; text-shadow: 2px 2px 4px rgba(0,0,0,0.3);">Part 6: t-SNE</h1>
#   <p style="color: #E8D3FF; font-family: 'Encode Sans', 'Arial', sans-serif; font-size: 1.3em; margin: 10px 0; font-weight: 300;">Keeping Neighbours Close, Allowing Global Distortion</p>
# </div>

# %% [markdown]
# <div style="border-left: 5px solid #4B2E83; background-color: #F9F7FC; padding: 20px 25px; margin: 20px 0; border-radius: 5px;">
#   <h2 style="color: #4B2E83; font-family: 'Encode Sans', 'Arial', sans-serif; margin-top: 0;">A. Learning Objectives</h2>
#   <ul style="color:#333; line-height:1.8;">
#     <li>Understand t-SNE as a <strong>nonlinear</strong> dimensionality reduction technique focused on <strong>local neighbourhood preservation</strong>.</li>
#     <li>Explain how t-SNE converts pairwise similarities to probabilities and minimises <strong>KL divergence</strong>.</li>
#     <li>Understand the role of <strong>perplexity</strong> and its effect on the output.</li>
#     <li>Know the key warnings: <strong>randomness</strong>, <strong>artificial clusters</strong>, and <strong>unreliable inter-cluster distances</strong>.</li>
#   </ul>
# </div>

# %% [markdown]
# <div style="border-left: 5px solid #4B2E83; background-color: #F9F7FC; padding: 20px 25px; margin: 20px 0; border-radius: 5px;">
#   <h2 style="color: #4B2E83; font-family: 'Encode Sans', 'Arial', sans-serif; margin-top: 0;">B. Definition</h2>
#   <p style="font-size: 1.05em; color: #555; line-height: 1.7;">
#     t-SNE (van der Maaten & Hinton, 2008) works in two steps:
#   </p>
#   <ol style="color:#333; line-height:1.8;">
#     <li><strong>High-dimensional similarities:</strong> For each pair (i, j), compute a Gaussian-based conditional probability p<sub>j|i</sub> that i would pick j as its neighbour. The <strong>perplexity</strong> parameter controls the effective number of neighbours (bandwidth of the Gaussian).</li>
#     <li><strong>Low-dimensional similarities:</strong> Place points in 2D and compute similarities using a <strong>Student's t-distribution</strong> (1 degree of freedom) — heavier tails than a Gaussian, which helps prevent crowding.</li>
#     <li><strong>Optimisation:</strong> Minimise the <strong>Kullback-Leibler divergence</strong> between the high-d and low-d similarity distributions using gradient descent.</li>
#   </ol>
#   <p style="font-size: 1.05em; color: #555; line-height: 1.7;">
#     The t-distribution in the low-d space means that moderately distant points in high-d can be placed <em>far apart</em> in 2D without paying a large cost — this creates visually clear clusters.
#   </p>
# </div>

# %% [markdown]
# <div style="border-left: 5px solid #4B2E83; background-color: #F9F7FC; padding: 20px 25px; margin: 20px 0; border-radius: 5px;">
#   <h2 style="color: #4B2E83; font-family: 'Encode Sans', 'Arial', sans-serif; margin-top: 0;">C. Intuition</h2>
#   <p style="font-size: 1.05em; color: #555; line-height: 1.7;">
#     Imagine a crowded dance floor (high-dimensional space). t-SNE takes a photo from above, then rearranges people in a 2D seating chart so that <strong>people who were dancing close together remain seated close together</strong>. However, the distances between <em>different groups</em> of dancers in the seating chart are meaningless — they're just arranged for visual clarity.
#   </p>
#   <div style="background-color: #FFF3E0; border: 2px solid #F57C00; padding: 15px; border-radius: 5px; margin-top:15px;">
#     <p style="margin:0; color:#C62828; font-weight:bold;">Important Warnings:</p>
#     <ul style="color:#333; line-height:1.8; margin-top:5px;">
#       <li>Clusters in t-SNE plots may be <strong>artificial</strong> — artefacts of the algorithm, not real structure.</li>
#       <li><strong>Distances between clusters are unreliable</strong> — two clusters far apart in the plot may not be far apart in reality.</li>
#       <li>Results depend on the <strong>random seed</strong> — always run multiple times.</li>
#       <li><strong>Perplexity</strong> must be tuned — too low creates many tiny spurious clusters; too high blurs real structure.</li>
#     </ul>
#   </div>
# </div>

# %% [markdown]
# <div style="border-left: 5px solid #4B2E83; background-color: #F9F7FC; padding: 20px 25px; margin: 20px 0; border-radius: 5px;">
#   <h2 style="color: #4B2E83; font-family: 'Encode Sans', 'Arial', sans-serif; margin-top: 0;">D. When to Use t-SNE</h2>
#   <table style="width:100%; border-collapse: collapse; margin-top:10px;">
#     <tr style="background-color: #4B2E83; color: white;">
#       <th style="padding:10px; text-align:left;">Aspect</th>
#       <th style="padding:10px; text-align:left;">Details</th>
#     </tr>
#     <tr style="border-bottom:1px solid #ddd;">
#       <td style="padding:10px;"><strong>Best use cases</strong></td>
#       <td style="padding:10px;">Exploratory visualisation of high-d data; checking if clusters exist; biological/genomic data</td>
#     </tr>
#     <tr style="border-bottom:1px solid #ddd;">
#       <td style="padding:10px;"><strong>Assumptions</strong></td>
#       <td style="padding:10px;">Local structure matters more than global; data have meaningful neighbourhoods</td>
#     </tr>
#     <tr style="border-bottom:1px solid #ddd;">
#       <td style="padding:10px;"><strong>Strengths</strong></td>
#       <td style="padding:10px;">Reveals nonlinear structure; beautiful visualisations; works well for moderate n</td>
#     </tr>
#     <tr style="border-bottom:1px solid #ddd;">
#       <td style="padding:10px;"><strong>Limitations</strong></td>
#       <td style="padding:10px;">Slow (O(n&sup2;)); non-deterministic; no inverse transform; global structure lost</td>
#     </tr>
#     <tr>
#       <td style="padding:10px;"><strong>Common mistakes</strong></td>
#       <td style="padding:10px;">Reading too much into cluster sizes/distances; using a single random seed; not trying multiple perplexities</td>
#     </tr>
#   </table>
# </div>

# %% [markdown]
# <div style="border-left: 5px solid #4B2E83; background-color: #F9F7FC; padding: 20px 25px; margin: 20px 0; border-radius: 5px;">
#   <h2 style="color: #4B2E83; font-family: 'Encode Sans', 'Arial', sans-serif; margin-top: 0;">E. Python Demonstrations</h2>
# </div>

# %% [markdown]
# <div style="border-left: 5px solid #4B2E83; background-color: #F9F7FC; padding: 20px 25px; margin: 20px 0; border-radius: 5px;">
#   <h3 style="color: #4B2E83;">Example 6.1 — t-SNE Perplexity Comparison: College Dataset</h3>
#   <p style="color:#555;"><strong>Dataset:</strong> <a href="https://github.com/PedroBSB/BDATA200/tree/main/Data">College.csv</a></p>
#   <p style="color:#555;"><strong>Question:</strong> How does perplexity affect the t-SNE visualisation of US colleges?</p>
# </div>

# %%
# Example 6.1 — t-SNE with different perplexities on College
college = pd.read_csv('https://raw.githubusercontent.com/PedroBSB/BDATA200/main/Data/College.csv')
X_col = StandardScaler().fit_transform(college.select_dtypes(include=[np.number]))
is_private = (college['Private'] == 'Yes').values

perplexities = [5, 30, 50, 100]
fig, axes = plt.subplots(1, 4, figsize=(22, 5))

for ax, perp in zip(axes, perplexities):
    tsne = TSNE(n_components=2, perplexity=perp, random_state=42, max_iter=1000)
    Y = tsne.fit_transform(X_col)

    for val, color, label in [(True, UW_PURPLE, 'Private'), (False, UW_GOLD, 'Public')]:
        mask = is_private == val
        ax.scatter(Y[mask, 0], Y[mask, 1], c=color, label=label, alpha=0.5, s=20)
    ax.set_title(f'Perplexity = {perp}', fontsize=13, fontweight='bold', color=UW_DARK)
    ax.set_xticks([])
    ax.set_yticks([])
    ax.legend(fontsize=8)

fig.suptitle('t-SNE: Effect of Perplexity on College Data',
             fontsize=16, fontweight='bold', color=UW_DARK, y=1.02)
plt.tight_layout()
plt.show()

print("\nInterpretation: Low perplexity (5) creates many small, fragmented clusters —")
print("this is an artefact, not real structure. Higher perplexity (30–50) reveals the")
print("Private/Public separation more clearly. Very high perplexity (100) begins to")
print("blur the structure. Perplexity ≈ 30 is usually a good starting point.")

# %% [markdown]
# <div style="border-left: 5px solid #4B2E83; background-color: #F9F7FC; padding: 20px 25px; margin: 20px 0; border-radius: 5px;">
#   <h3 style="color: #4B2E83;">Example 6.2 — t-SNE vs PCA: Heart Disease</h3>
#   <p style="color:#555;"><strong>Dataset:</strong> <a href="https://github.com/PedroBSB/BDATA200/tree/main/Data">Heart.csv</a></p>
#   <p style="color:#555;"><strong>Question:</strong> Does t-SNE reveal structure that PCA misses in the heart disease data?</p>
# </div>

# %%
# Example 6.2 — t-SNE vs PCA on Heart
heart = pd.read_csv('https://raw.githubusercontent.com/PedroBSB/BDATA200/main/Data/Heart.csv').dropna()
X_h = StandardScaler().fit_transform(heart.select_dtypes(include=[np.number]).drop(columns=['target']))
y_h = (heart['target'] == 1).values

fig, axes = plt.subplots(1, 2, figsize=(14, 6))

# PCA
pca_h = PCA(n_components=2)
Y_pca_h = pca_h.fit_transform(X_h)

# t-SNE
tsne_h = TSNE(n_components=2, perplexity=30, random_state=42)
Y_tsne_h = tsne_h.fit_transform(X_h)

for ax, Y, title in [(axes[0], Y_pca_h, 'PCA'), (axes[1], Y_tsne_h, 't-SNE (perp=30)')]:
    for val, color, label in [(True, '#C62828', 'Disease'), (False, '#388E3C', 'No Disease')]:
        mask = y_h == val
        ax.scatter(Y[mask, 0], Y[mask, 1], c=color, label=label, alpha=0.5, s=30)
    ax.set_title(title, fontsize=14, fontweight='bold', color=UW_DARK)
    ax.legend()
    ax.set_xlabel('Component 1')
    ax.set_ylabel('Component 2')

plt.suptitle('Heart Disease: PCA vs t-SNE', fontsize=16, fontweight='bold', color=UW_DARK, y=1.02)
plt.tight_layout()
plt.show()

print("\nInterpretation: PCA projects data linearly — disease vs no-disease overlap.")
print("t-SNE reveals local clusters, potentially separating disease subtypes that PCA misses.")

# %% [markdown]
# <div style="border-left: 5px solid #4B2E83; background-color: #F9F7FC; padding: 20px 25px; margin: 20px 0; border-radius: 5px;">
#   <h3 style="color: #4B2E83;">Example 6.3 — t-SNE Instability: Random Seeds on Bikeshare</h3>
#   <p style="color:#555;"><strong>Dataset:</strong> <a href="https://github.com/PedroBSB/BDATA200/tree/main/Data">Bikeshare.csv</a></p>
#   <p style="color:#555;"><strong>Question:</strong> How much does the t-SNE output change with different random seeds?</p>
# </div>

# %%
# Example 6.3 — t-SNE instability with different random seeds
bike = pd.read_csv('https://raw.githubusercontent.com/PedroBSB/BDATA200/main/Data/Bikeshare.csv')
X_bike = StandardScaler().fit_transform(bike.select_dtypes(include=[np.number]))

# Subsample for speed
np.random.seed(42)
idx = np.random.choice(len(X_bike), 500, replace=False)
X_bike_sub = X_bike[idx]
season = bike['season'].values[idx]

seeds = [0, 42, 123, 999]
fig, axes = plt.subplots(1, 4, figsize=(22, 5))

season_colors = {1: UW_PURPLE, 2: UW_GOLD, 3: '#388E3C', 4: '#C62828'}
season_names = {1: 'Winter', 2: 'Spring', 3: 'Summer', 4: 'Fall'}

for ax, seed in zip(axes, seeds):
    tsne = TSNE(n_components=2, perplexity=30, random_state=seed)
    Y = tsne.fit_transform(X_bike_sub)

    for s in [1, 2, 3, 4]:
        mask = season == s
        ax.scatter(Y[mask, 0], Y[mask, 1], c=season_colors[s],
                   label=season_names[s], alpha=0.5, s=20)
    ax.set_title(f'seed = {seed}', fontsize=13, fontweight='bold', color=UW_DARK)
    ax.set_xticks([])
    ax.set_yticks([])
    ax.legend(fontsize=8)

fig.suptitle('t-SNE: Different Random Seeds on Bikeshare Data',
             fontsize=16, fontweight='bold', color=UW_DARK, y=1.02)
plt.tight_layout()
plt.show()

print("\nInterpretation: Each seed produces a different arrangement! The local clusters")
print("are roughly consistent, but their positions change. This shows why you should")
print("NEVER rely on a single t-SNE run — always try multiple seeds and look for")
print("patterns that are consistent across runs.")

# %% [markdown]
# <div style="background-color: #FFF3E0; border-left: 4px solid #F57C00; padding: 15px 20px; margin: 20px 0; border-radius: 5px;">
#   <h3 style="color: #F57C00; margin-top: 0;">Exercise 16 — Compare Perplexity Values</h3>
# </div>
#
# **Task:** Using the **Credit.csv** dataset:
# 1. Run t-SNE with perplexity = 5, 15, 30, 50, 100.
# 2. Colour points by `Student` (Yes/No).
# 3. At which perplexity do you see the clearest separation?
# 4. At which perplexity do you see artefact clusters?

# %%
# Exercise 16 — Your solution below
credit = pd.read_csv('https://raw.githubusercontent.com/PedroBSB/BDATA200/main/Data/Credit.csv')

# --- Your code here ---

# %% [markdown]
# *Write your interpretation here.*
#
# 1. **Best perplexity** —
# 2. **Artefacts at low perplexity** —
# 3. **Effect of very high perplexity** —

# %% [markdown]
# <div style="background-color: #FFF3E0; border-left: 4px solid #F57C00; padding: 15px 20px; margin: 20px 0; border-radius: 5px;">
#   <h3 style="color: #F57C00; margin-top: 0;">Exercise 17 — Compare PCA vs t-SNE</h3>
# </div>
#
# **Task:** Using the **Default.csv** dataset:
# 1. Run PCA (2 components) and t-SNE (perplexity=30) on `balance` and `income` (scaled).
# 2. Colour by `default` status.
# 3. Which method better separates defaulters?
# 4. Add 20 random noise features. Repeat. Does t-SNE still work?

# %%
# Exercise 17 — Your solution below
default = pd.read_csv('https://raw.githubusercontent.com/PedroBSB/BDATA200/main/Data/Default.csv')

# --- Your code here ---

# %% [markdown]
# *Write your interpretation here.*
#
# 1. **PCA vs t-SNE separation** —
# 2. **Effect of noise features** —
# 3. **Which method is more robust?** —

# %% [markdown]
# <div style="background-color: #FFF3E0; border-left: 4px solid #F57C00; padding: 15px 20px; margin: 20px 0; border-radius: 5px;">
#   <h3 style="color: #F57C00; margin-top: 0;">Exercise 18 — Test Random Seeds</h3>
# </div>
#
# **Task:** Using the **Smarket.csv** dataset:
# 1. Run t-SNE with 5 different random seeds (perplexity=30).
# 2. Colour by `Direction` (Up/Down).
# 3. Compute the Trustworthiness score for each run (from `sklearn.manifold`).
# 4. Are the clusters consistent across runs? What does this tell you about the data?

# %%
from sklearn.manifold import TSNE, trustworthiness
from sklearn.preprocessing import MinMaxScaler
import pandas as pd
import matplotlib.pyplot as plt

# Load dataset
market = pd.read_csv(
    'https://raw.githubusercontent.com/PedroBSB/BDATA200/main/Data/Smarket.csv'
)

# Features
features = market[['Lag1', 'Lag2', 'Lag3', 'Lag4', 'Lag5', 'Volume']]

# Scale data
scaler = MinMaxScaler()
scaled_features = scaler.fit_transform(features)

# Labels
labels = market['Direction']

# Random seeds
random_seeds = [3, 11, 25, 56, 88]

# Plot setup
fig, axs = plt.subplots(1, 5, figsize=(24, 5))

for idx, seed in enumerate(random_seeds):

    # Run t-SNE
    tsne_model = TSNE(
        n_components=2,
        perplexity=30,
        random_state=seed
    )

    embedding = tsne_model.fit_transform(scaled_features)

    # Compute trustworthiness
    trust_score = trustworthiness(scaled_features, embedding)

    # Colors
    point_colors = labels.map({
        'Up': 'blue',
        'Down': 'orange'
    })

    # Scatter plot
    axs[idx].scatter(
        embedding[:, 0],
        embedding[:, 1],
        c=point_colors,
        alpha=0.65
    )

    axs[idx].set_title(
        f'Random Seed {seed}\nScore = {trust_score:.3f}'
    )

plt.tight_layout()
plt.show()

# %% [markdown]
# *Write your interpretation here.*
#
# Are clusters consistent? —
# The clusters appear somewhat similar between runs, although their layouts shift depending on the random seed. This suggests that the underlying structure is moderately stable but not perfectly fixed.
#
# Trustworthiness scores —
# The trustworthiness values remained consistently high across the five runs, meaning the t-SNE projections preserved nearby relationships in the original dataset fairly well.
#
# What this says about market data —
# The “Up” and “Down” categories overlap heavily, showing that stock market direction is difficult to separate cleanly. The dataset likely contains noisy and highly variable patterns rather than strongly distinct groups.

# %% [markdown]
# <div style="background: linear-gradient(135deg, #4B2E83 0%, #32006E 100%); padding: 30px; border-radius: 10px; margin: 40px 0 30px 0; box-shadow: 0 5px 15px rgba(75,46,131,0.2);">
#   <h1 style="color: #FFF; font-family: 'Encode Sans', 'Arial', sans-serif; font-weight: 700; margin: 0; text-shadow: 2px 2px 4px rgba(0,0,0,0.3);">Part 7: UMAP</h1>
#   <p style="color: #E8D3FF; font-family: 'Encode Sans', 'Arial', sans-serif; font-size: 1.3em; margin: 10px 0; font-weight: 300;">Uniform Manifold Approximation and Projection</p>
# </div>

# %% [markdown]
# <div style="border-left: 5px solid #4B2E83; background-color: #F9F7FC; padding: 20px 25px; margin: 20px 0; border-radius: 5px;">
#   <h2 style="color: #4B2E83; font-family: 'Encode Sans', 'Arial', sans-serif; margin-top: 0;">A. Learning Objectives</h2>
#   <ul style="color:#333; line-height:1.8;">
#     <li>Understand UMAP as a <strong>manifold learning</strong> method that preserves both local <em>and some global</em> structure.</li>
#     <li>Explain the <strong>graph-based neighbourhood</strong> construction and cross-entropy optimisation.</li>
#     <li>Tune the key parameters: <code>n_neighbors</code> and <code>min_dist</code>.</li>
#     <li>Know why UMAP is often <strong>faster</strong> than t-SNE and when to prefer it.</li>
#   </ul>
# </div>

# %% [markdown]
# <div style="border-left: 5px solid #4B2E83; background-color: #F9F7FC; padding: 20px 25px; margin: 20px 0; border-radius: 5px;">
#   <h2 style="color: #4B2E83; font-family: 'Encode Sans', 'Arial', sans-serif; margin-top: 0;">B. Definition</h2>
#   <p style="font-size: 1.05em; color: #555; line-height: 1.7;">
#     UMAP (McInnes, Healy & Melville, 2018) is grounded in <strong>Riemannian geometry</strong> and <strong>algebraic topology</strong>, but the practical intuition is:
#   </p>
#   <ol style="color:#333; line-height:1.8;">
#     <li><strong>Build a weighted graph</strong> in high-d: Connect each point to its <code>n_neighbors</code> nearest neighbours. Edge weights decay with distance.</li>
#     <li><strong>Optimise a low-d layout</strong>: Find 2D coordinates that minimise the <strong>cross-entropy</strong> between the high-d and low-d edge weight distributions.</li>
#   </ol>
#   <p style="font-size: 1.05em; color: #555; line-height: 1.7;">Key parameters:</p>
#   <ul style="color:#333; line-height:1.8;">
#     <li><code>n_neighbors</code>: Controls local vs global balance. Small = focus on local structure. Large = more global context.</li>
#     <li><code>min_dist</code>: Controls how tightly points can pack. Small = tight clusters. Large = more spread out.</li>
#   </ul>
# </div>

# %% [markdown]
# <div style="border-left: 5px solid #4B2E83; background-color: #F9F7FC; padding: 20px 25px; margin: 20px 0; border-radius: 5px;">
#   <h2 style="color: #4B2E83; font-family: 'Encode Sans', 'Arial', sans-serif; margin-top: 0;">C. Intuition</h2>
#   <p style="font-size: 1.05em; color: #555; line-height: 1.7;">
#     Think of data as cities connected by roads. UMAP builds a road network where each city connects to its nearest neighbours. Then it lays out the cities on a flat map, trying to keep the road network structure intact — cities connected by short roads should be close on the map.
#   </p>
#   <p style="font-size: 1.05em; color: #555; line-height: 1.7;">
#     Unlike t-SNE, UMAP preserves <em>some</em> of the global structure (relative positions of clusters), is <strong>faster</strong> (especially for large n), and has a well-defined <strong>transform</strong> method for new data.
#   </p>
# </div>

# %% [markdown]
# <div style="border-left: 5px solid #4B2E83; background-color: #F9F7FC; padding: 20px 25px; margin: 20px 0; border-radius: 5px;">
#   <h2 style="color: #4B2E83; font-family: 'Encode Sans', 'Arial', sans-serif; margin-top: 0;">D. When to Use UMAP</h2>
#   <table style="width:100%; border-collapse: collapse; margin-top:10px;">
#     <tr style="background-color: #4B2E83; color: white;">
#       <th style="padding:10px; text-align:left;">Aspect</th>
#       <th style="padding:10px; text-align:left;">Details</th>
#     </tr>
#     <tr style="border-bottom:1px solid #ddd;">
#       <td style="padding:10px;"><strong>Best use cases</strong></td>
#       <td style="padding:10px;">Large-scale visualisation; pre-processing for clustering; preserving global layout; new-data projection</td>
#     </tr>
#     <tr style="border-bottom:1px solid #ddd;">
#       <td style="padding:10px;"><strong>Assumptions</strong></td>
#       <td style="padding:10px;">Data lie on or near a low-dimensional manifold; local distances are meaningful</td>
#     </tr>
#     <tr style="border-bottom:1px solid #ddd;">
#       <td style="padding:10px;"><strong>Strengths</strong></td>
#       <td style="padding:10px;">Faster than t-SNE; preserves more global structure; has transform(); scales to millions</td>
#     </tr>
#     <tr style="border-bottom:1px solid #ddd;">
#       <td style="padding:10px;"><strong>Limitations</strong></td>
#       <td style="padding:10px;">Still a nonlinear projection — distances are approximate; parameters matter; less established theory than PCA</td>
#     </tr>
#     <tr>
#       <td style="padding:10px;"><strong>Common mistakes</strong></td>
#       <td style="padding:10px;">Using default parameters without tuning; over-interpreting inter-cluster distances; not scaling data first</td>
#     </tr>
#   </table>
# </div>

# %% [markdown]
# <div style="border-left: 5px solid #4B2E83; background-color: #F9F7FC; padding: 20px 25px; margin: 20px 0; border-radius: 5px;">
#   <h2 style="color: #4B2E83; font-family: 'Encode Sans', 'Arial', sans-serif; margin-top: 0;">E. Python Demonstrations</h2>
# </div>

# %% [markdown]
# <div style="border-left: 5px solid #4B2E83; background-color: #F9F7FC; padding: 20px 25px; margin: 20px 0; border-radius: 5px;">
#   <h3 style="color: #4B2E83;">Example 7.1 — UMAP Parameter Tuning: Caravan Dataset</h3>
#   <p style="color:#555;"><strong>Dataset:</strong> <a href="https://github.com/PedroBSB/BDATA200/tree/main/Data">Caravan.csv</a> — 5,822 customers, 86 features.</p>
#   <p style="color:#555;"><strong>Question:</strong> How do <code>n_neighbors</code> and <code>min_dist</code> affect the UMAP layout of high-dimensional insurance data?</p>
# </div>

# %%
# Example 7.1 — UMAP parameter tuning on Caravan
caravan = pd.read_csv('https://raw.githubusercontent.com/PedroBSB/BDATA200/main/Data/Caravan.csv')
X_car = StandardScaler().fit_transform(caravan.select_dtypes(include=[np.number]))
purchase = (caravan['Purchase'] == 'Yes').values

params = [(5, 0.0), (15, 0.1), (50, 0.1), (50, 0.5)]
fig, axes = plt.subplots(1, 4, figsize=(22, 5))

for ax, (nn, md_val) in zip(axes, params):
    reducer = umap.UMAP(n_neighbors=nn, min_dist=md_val, random_state=42)
    Y = reducer.fit_transform(X_car)

    for val, color, label in [(False, UW_PURPLE, 'No'), (True, UW_GOLD, 'Yes')]:
        mask = purchase == val
        ax.scatter(Y[mask, 0], Y[mask, 1], c=color, label=label,
                   alpha=0.3 if not val else 0.8, s=5 if not val else 20)
    ax.set_title(f'nn={nn}, md={md_val}', fontsize=12, fontweight='bold', color=UW_DARK)
    ax.set_xticks([])
    ax.set_yticks([])
    ax.legend(fontsize=8, title='Purchase')

fig.suptitle('UMAP: Effect of n_neighbors and min_dist on Caravan Data',
             fontsize=16, fontweight='bold', color=UW_DARK, y=1.02)
plt.tight_layout()
plt.show()

print("\nInterpretation: Small n_neighbors (5) emphasises very local structure,")
print("creating many small fragments. Larger n_neighbors (50) captures broader")
print("patterns. Small min_dist (0.0) packs clusters tightly; larger min_dist")
print("(0.5) spreads them out for easier visual inspection.")

# %% [markdown]
# <div style="border-left: 5px solid #4B2E83; background-color: #F9F7FC; padding: 20px 25px; margin: 20px 0; border-radius: 5px;">
#   <h3 style="color: #4B2E83;">Example 7.2 — t-SNE vs UMAP: Wage Dataset</h3>
#   <p style="color:#555;"><strong>Dataset:</strong> <a href="https://github.com/PedroBSB/BDATA200/tree/main/Data">Wage.csv</a></p>
#   <p style="color:#555;"><strong>Question:</strong> Which method better reveals education-level groups in wage data?</p>
# </div>

# %%
# Example 7.2 — t-SNE vs UMAP on Wage
import time
wage = pd.read_csv('https://raw.githubusercontent.com/PedroBSB/BDATA200/main/Data/Wage.csv')
X_w = StandardScaler().fit_transform(wage.select_dtypes(include=[np.number]))

# Subsample for t-SNE speed
np.random.seed(42)
idx = np.random.choice(len(X_w), 1000, replace=False)
X_w_sub = X_w[idx]
edu = wage['education'].values[idx]

fig, axes = plt.subplots(1, 2, figsize=(16, 7))

# t-SNE
t0 = time.time()
Y_tsne = TSNE(n_components=2, perplexity=30, random_state=42).fit_transform(X_w_sub)
t_tsne = time.time() - t0

# UMAP
t0 = time.time()
Y_umap = umap.UMAP(n_neighbors=15, min_dist=0.1, random_state=42).fit_transform(X_w_sub)
t_umap = time.time() - t0

edu_colors = {'1. < HS Grad': '#C62828', '2. HS Grad': UW_GOLD,
               '3. Some College': '#1976D2', '4. College Grad': '#388E3C',
               '5. Advanced Degree': UW_PURPLE}

for ax, Y, title, t in [(axes[0], Y_tsne, 't-SNE', t_tsne),
                          (axes[1], Y_umap, 'UMAP', t_umap)]:
    for e, color in edu_colors.items():
        mask = edu == e
        ax.scatter(Y[mask, 0], Y[mask, 1], c=color, label=e.split('. ')[1],
                   alpha=0.5, s=20)
    ax.set_title(f'{title} ({t:.1f}s)', fontsize=14, fontweight='bold', color=UW_DARK)
    ax.set_xticks([])
    ax.set_yticks([])
    ax.legend(fontsize=8, loc='best')

plt.tight_layout()
plt.show()

print(f"\nt-SNE: {t_tsne:.1f}s | UMAP: {t_umap:.1f}s")
print("UMAP is typically faster and often preserves more of the global arrangement.")
print("Both reveal that education levels partially cluster, though significant overlap")
print("exists — many other factors (age, experience) also drive wage variation.")

# %% [markdown]
# <div style="border-left: 5px solid #4B2E83; background-color: #F9F7FC; padding: 20px 25px; margin: 20px 0; border-radius: 5px;">
#   <h3 style="color: #4B2E83;">Example 7.3 — UMAP Before Clustering: OJ Dataset</h3>
#   <p style="color:#555;"><strong>Dataset:</strong> <a href="https://github.com/PedroBSB/BDATA200/tree/main/Data">OJ.csv</a></p>
#   <p style="color:#555;"><strong>Question:</strong> Does clustering in UMAP space produce better results than clustering in the original high-dimensional space?</p>
# </div>

# %%
# Example 7.3 — UMAP + K-Means on OJ
oj = pd.read_csv('https://raw.githubusercontent.com/PedroBSB/BDATA200/main/Data/OJ.csv')
X_oj = StandardScaler().fit_transform(oj.select_dtypes(include=[np.number]))
purchase = oj['Purchase'].values

# UMAP embedding
reducer = umap.UMAP(n_neighbors=15, min_dist=0.1, n_components=2, random_state=42)
X_umap = reducer.fit_transform(X_oj)

# K-Means in original space vs UMAP space
km_orig = KMeans(n_clusters=2, n_init=10, random_state=42).fit_predict(X_oj)
km_umap = KMeans(n_clusters=2, n_init=10, random_state=42).fit_predict(X_umap)

fig, axes = plt.subplots(1, 3, figsize=(20, 6))

# UMAP coloured by true labels
for brand, color in [('CH', UW_PURPLE), ('MM', UW_GOLD)]:
    mask = purchase == brand
    axes[0].scatter(X_umap[mask, 0], X_umap[mask, 1], c=color, label=brand,
                    alpha=0.4, s=15)
axes[0].set_title('UMAP (True Labels)', fontsize=13, fontweight='bold', color=UW_DARK)
axes[0].legend()

# K-Means in original space
for c, color in [(0, UW_PURPLE), (1, UW_GOLD)]:
    mask = km_orig == c
    axes[1].scatter(X_umap[mask, 0], X_umap[mask, 1], c=color,
                    label=f'Cluster {c}', alpha=0.4, s=15)
sil_orig = silhouette_score(X_oj, km_orig)
axes[1].set_title(f'K-Means (Original)\nSil = {sil_orig:.3f}',
                  fontsize=13, fontweight='bold', color=UW_DARK)
axes[1].legend()

# K-Means in UMAP space
for c, color in [(0, UW_PURPLE), (1, UW_GOLD)]:
    mask = km_umap == c
    axes[2].scatter(X_umap[mask, 0], X_umap[mask, 1], c=color,
                    label=f'Cluster {c}', alpha=0.4, s=15)
sil_umap = silhouette_score(X_umap, km_umap)
axes[2].set_title(f'K-Means (UMAP Space)\nSil = {sil_umap:.3f}',
                  fontsize=13, fontweight='bold', color=UW_DARK)
axes[2].legend()

for ax in axes:
    ax.set_xticks([])
    ax.set_yticks([])

plt.tight_layout()
plt.show()

print("\nInterpretation: Clustering in UMAP space can sometimes improve cluster quality")
print("because UMAP concentrates the meaningful structure into fewer dimensions.")
print("However, UMAP is a nonlinear transformation — interpret cluster boundaries")
print("with caution.")

# %% [markdown]
# <div style="background-color: #FFF3E0; border-left: 4px solid #F57C00; padding: 15px 20px; margin: 20px 0; border-radius: 5px;">
#   <h3 style="color: #F57C00; margin-top: 0;">Exercise 19 — Tune n_neighbors</h3>
# </div>
#
# **Task:** Using the **College.csv** dataset:
# 1. Run UMAP with `n_neighbors` = 5, 15, 50, 100 (keep `min_dist=0.1`).
# 2. Colour by `Private`.
# 3. For each, compute the silhouette score of a K=2 clustering in UMAP space.
# 4. Which n_neighbors gives the best visual separation? Does silhouette agree?

# %%
# Exercise 19 — Your solution below
college = pd.read_csv('https://raw.githubusercontent.com/PedroBSB/BDATA200/main/Data/College.csv')

# --- Your code here ---

# %% [markdown]
# *Write your interpretation here.*
#
# 1. **Best n_neighbors and why** —
# 2. **Silhouette scores** —
# 3. **Trade-off between local and global** —

# %% [markdown]
# <div style="background-color: #FFF3E0; border-left: 4px solid #F57C00; padding: 15px 20px; margin: 20px 0; border-radius: 5px;">
#   <h3 style="color: #F57C00; margin-top: 0;">Exercise 20 — Compare t-SNE vs UMAP</h3>
# </div>
#
# **Task:** Using the **Bikeshare.csv** dataset (subsample 1000 rows):
# 1. Run t-SNE (perplexity=30) and UMAP (n_neighbors=15, min_dist=0.1).
# 2. Colour by `season`.
# 3. Time both methods.
# 4. Which method produces clearer seasonal patterns? Which is faster?

# %%
# Exercise 20 — Your solution below
bike = pd.read_csv('https://raw.githubusercontent.com/PedroBSB/BDATA200/main/Data/Bikeshare.csv')

# --- Your code here ---

# %% [markdown]
# *Write your interpretation here.*
#
# 1. **Visual comparison** —
# 2. **Speed comparison** —
# 3. **When would you prefer UMAP over t-SNE?** —

# %% [markdown]
# <div style="background-color: #FFF3E0; border-left: 4px solid #F57C00; padding: 15px 20px; margin: 20px 0; border-radius: 5px;">
#   <h3 style="color: #F57C00; margin-top: 0;">Exercise 21 — Use UMAP Before Clustering</h3>
# </div>
#
# **Task:** Using the **Hitters.csv** dataset:
# 1. Scale all numeric features.
# 2. Run UMAP to 2D.
# 3. Apply K-Means (K=3) in the original space and in UMAP space.
# 4. Apply DBSCAN in UMAP space.
# 5. Compare silhouette scores and visually assess which method produces the most meaningful groups.

# %%
# Exercise 21 — Your solution below
hitters = pd.read_csv('https://raw.githubusercontent.com/PedroBSB/BDATA200/main/Data/Hitters.csv').dropna()

# --- Your code here ---

# %% [markdown]
# *Write your interpretation here.*
#
# 1. **K-Means original vs UMAP space** —
# 2. **DBSCAN results** —
# 3. **Best approach and why** —

# %% [markdown]
# <div style="background: linear-gradient(135deg, #4B2E83 0%, #32006E 100%); padding: 30px; border-radius: 10px; margin: 40px 0 30px 0; box-shadow: 0 5px 15px rgba(75,46,131,0.2);">
#   <h1 style="color: #FFF; font-family: 'Encode Sans', 'Arial', sans-serif; font-weight: 700; margin: 0; text-shadow: 2px 2px 4px rgba(0,0,0,0.3);">Part 8: Autoencoders</h1>
#   <p style="color: #E8D3FF; font-family: 'Encode Sans', 'Arial', sans-serif; font-size: 1.3em; margin: 10px 0; font-weight: 300;">Neural Network Compression &amp; Reconstruction</p>
# </div>

# %% [markdown]
# <div style="border-left: 5px solid #4B2E83; background-color: #F9F7FC; padding: 20px 25px; margin: 20px 0; border-radius: 5px;">
#   <h2 style="color: #4B2E83; font-family: 'Encode Sans', 'Arial', sans-serif; margin-top: 0;">A. Learning Objectives</h2>
#   <ul style="color:#333; line-height:1.8;">
#     <li>Understand the <strong>encoder–bottleneck–decoder</strong> architecture.</li>
#     <li>Explain <strong>reconstruction loss</strong> and how the network learns a compressed representation.</li>
#     <li>Know the difference between autoencoders and PCA (nonlinear vs linear).</li>
#     <li>Apply autoencoders for <strong>dimensionality reduction</strong>, <strong>anomaly detection</strong>, and <strong>latent space visualisation</strong>.</li>
#     <li>Understand <strong>denoising autoencoders</strong> and their benefits.</li>
#   </ul>
# </div>

# %% [markdown]
# <div style="border-left: 5px solid #4B2E83; background-color: #F9F7FC; padding: 20px 25px; margin: 20px 0; border-radius: 5px;">
#   <h2 style="color: #4B2E83; font-family: 'Encode Sans', 'Arial', sans-serif; margin-top: 0;">B. Definition</h2>
#   <p style="font-size: 1.05em; color: #555; line-height: 1.7;">
#     An autoencoder is a neural network trained to <strong>reconstruct its own input</strong>. It consists of:
#   </p>
#   <ol style="color:#333; line-height:1.8;">
#     <li><strong>Encoder:</strong> Maps input <strong>x</strong> ∈ ℝ<sup>p</sup> to a latent representation <strong>z</strong> ∈ ℝ<sup>d</sup> (where d ≪ p):  z = f<sub>enc</sub>(x)</li>
#     <li><strong>Bottleneck:</strong> The layer with d neurons — the compressed representation.</li>
#     <li><strong>Decoder:</strong> Maps <strong>z</strong> back to a reconstruction <strong>x̂</strong> ∈ ℝ<sup>p</sup>:  x̂ = f<sub>dec</sub>(z)</li>
#   </ol>
#   <p style="font-size: 1.05em; color: #555; line-height: 1.7;">
#     The <strong>reconstruction loss</strong> is typically MSE: L = (1/n) Σ ||x<sub>i</sub> − x̂<sub>i</sub>||².
#     When f<sub>enc</sub> and f<sub>dec</sub> are <em>linear</em> and the bottleneck has d neurons, the autoencoder learns the same subspace as PCA with d components. With nonlinear activations (ReLU, sigmoid), it captures <strong>nonlinear manifolds</strong>.
#   </p>
#   <p style="font-size: 1.05em; color: #555; line-height: 1.7;">
#     A <strong>denoising autoencoder</strong> adds noise to the input and trains the network to recover the clean version — this prevents trivial identity mappings and learns more robust features.
#   </p>
# </div>

# %% [markdown]
# <div style="border-left: 5px solid #4B2E83; background-color: #F9F7FC; padding: 20px 25px; margin: 20px 0; border-radius: 5px;">
#   <h2 style="color: #4B2E83; font-family: 'Encode Sans', 'Arial', sans-serif; margin-top: 0;">C. Intuition</h2>
#   <p style="font-size: 1.05em; color: #555; line-height: 1.7;">
#     Imagine summarising a book in a single paragraph (encoder → bottleneck), then trying to reconstruct the full book from just that paragraph (decoder). The paragraph must capture the <em>essence</em> of the book. A good autoencoder learns what information is essential and what can be discarded.
#   </p>
#   <p style="font-size: 1.05em; color: #555; line-height: 1.7;">
#     <strong>For anomaly detection:</strong> Train the autoencoder on "normal" data. When it encounters an anomaly, it cannot reconstruct it well — the reconstruction error spikes, flagging the anomaly.
#   </p>
# </div>

# %% [markdown]
# <div style="border-left: 5px solid #4B2E83; background-color: #F9F7FC; padding: 20px 25px; margin: 20px 0; border-radius: 5px;">
#   <h2 style="color: #4B2E83; font-family: 'Encode Sans', 'Arial', sans-serif; margin-top: 0;">D. When to Use Autoencoders</h2>
#   <table style="width:100%; border-collapse: collapse; margin-top:10px;">
#     <tr style="background-color: #4B2E83; color: white;">
#       <th style="padding:10px; text-align:left;">Aspect</th>
#       <th style="padding:10px; text-align:left;">Details</th>
#     </tr>
#     <tr style="border-bottom:1px solid #ddd;">
#       <td style="padding:10px;"><strong>Best use cases</strong></td>
#       <td style="padding:10px;">Nonlinear dimensionality reduction; anomaly detection; feature learning; denoising</td>
#     </tr>
#     <tr style="border-bottom:1px solid #ddd;">
#       <td style="padding:10px;"><strong>Assumptions</strong></td>
#       <td style="padding:10px;">Data have redundancy that can be compressed; enough samples to train the network</td>
#     </tr>
#     <tr style="border-bottom:1px solid #ddd;">
#       <td style="padding:10px;"><strong>Strengths</strong></td>
#       <td style="padding:10px;">Captures nonlinear structure; flexible architecture; can encode/decode new data</td>
#     </tr>
#     <tr style="border-bottom:1px solid #ddd;">
#       <td style="padding:10px;"><strong>Limitations</strong></td>
#       <td style="padding:10px;">Requires tuning (architecture, learning rate); less interpretable than PCA; needs more data; overfitting risk</td>
#     </tr>
#     <tr>
#       <td style="padding:10px;"><strong>Common mistakes</strong></td>
#       <td style="padding:10px;">Too-large bottleneck (identity mapping); not scaling input; training too long (overfitting); comparing directly to PCA without matching latent dimensions</td>
#     </tr>
#   </table>
# </div>

# %% [markdown]
# <div style="border-left: 5px solid #4B2E83; background-color: #F9F7FC; padding: 20px 25px; margin: 20px 0; border-radius: 5px;">
#   <h2 style="color: #4B2E83; font-family: 'Encode Sans', 'Arial', sans-serif; margin-top: 0;">E. Python Demonstrations</h2>
# </div>

# %% [markdown]
# <div style="border-left: 5px solid #4B2E83; background-color: #F9F7FC; padding: 20px 25px; margin: 20px 0; border-radius: 5px;">
#   <h3 style="color: #4B2E83;">Example 8.1 — Shallow Autoencoder: Credit Dataset</h3>
#   <p style="color:#555;"><strong>Dataset:</strong> <a href="https://github.com/PedroBSB/BDATA200/tree/main/Data">Credit.csv</a></p>
#   <p style="color:#555;"><strong>Question:</strong> Can a simple autoencoder compress 6 numeric features into 2 latent dimensions and reveal customer segments?</p>
# </div>

# %%
# Example 8.1 — Shallow autoencoder on Credit
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

credit = pd.read_csv('https://raw.githubusercontent.com/PedroBSB/BDATA200/main/Data/Credit.csv')
X_ae = credit[['Income', 'Limit', 'Rating', 'Cards', 'Age', 'Balance']].values
X_ae = StandardScaler().fit_transform(X_ae).astype('float32')

# Build autoencoder
input_dim = X_ae.shape[1]
latent_dim = 2

encoder_input = keras.Input(shape=(input_dim,))
encoded = layers.Dense(16, activation='relu')(encoder_input)
encoded = layers.Dense(8, activation='relu')(encoded)
latent = layers.Dense(latent_dim, activation='linear', name='latent')(encoded)

decoded = layers.Dense(8, activation='relu')(latent)
decoded = layers.Dense(16, activation='relu')(decoded)
decoded = layers.Dense(input_dim, activation='linear')(decoded)

autoencoder = keras.Model(encoder_input, decoded)
encoder = keras.Model(encoder_input, latent)

autoencoder.compile(optimizer='adam', loss='mse')
history = autoencoder.fit(X_ae, X_ae, epochs=100, batch_size=32,
                          validation_split=0.2, verbose=0)

# Get latent representations
Z = encoder.predict(X_ae, verbose=0)

fig, axes = plt.subplots(1, 3, figsize=(20, 6))

# Training loss
axes[0].plot(history.history['loss'], color=UW_PURPLE, linewidth=2, label='Train')
axes[0].plot(history.history['val_loss'], color=UW_GOLD, linewidth=2, label='Val')
axes[0].set_xlabel('Epoch')
axes[0].set_ylabel('MSE Loss')
axes[0].set_title('Training History', fontsize=14, fontweight='bold', color=UW_DARK)
axes[0].legend()

# Latent space coloured by Balance
sc = axes[1].scatter(Z[:, 0], Z[:, 1], c=credit['Balance'], cmap='PuOr',
                     alpha=0.6, s=30, edgecolors='white')
axes[1].set_xlabel('Latent Dim 1')
axes[1].set_ylabel('Latent Dim 2')
axes[1].set_title('Autoencoder Latent Space', fontsize=14, fontweight='bold', color=UW_DARK)
plt.colorbar(sc, ax=axes[1], label='Balance')

# Compare to PCA
pca2 = PCA(n_components=2)
Z_pca = pca2.fit_transform(X_ae)
sc2 = axes[2].scatter(Z_pca[:, 0], Z_pca[:, 1], c=credit['Balance'], cmap='PuOr',
                      alpha=0.6, s=30, edgecolors='white')
axes[2].set_xlabel('PC1')
axes[2].set_ylabel('PC2')
axes[2].set_title('PCA (2 components)', fontsize=14, fontweight='bold', color=UW_DARK)
plt.colorbar(sc2, ax=axes[2], label='Balance')

plt.tight_layout()
plt.show()

print("\nInterpretation: The autoencoder latent space captures nonlinear patterns that")
print("PCA may miss. Both show the Balance gradient, but the autoencoder may reveal")
print("finer-grained structure due to its nonlinear capacity.")

# %% [markdown]
# <div style="border-left: 5px solid #4B2E83; background-color: #F9F7FC; padding: 20px 25px; margin: 20px 0; border-radius: 5px;">
#   <h3 style="color: #4B2E83;">Example 8.2 — Anomaly Detection with Reconstruction Error: Default Dataset</h3>
#   <p style="color:#555;"><strong>Dataset:</strong> <a href="https://github.com/PedroBSB/BDATA200/tree/main/Data">Default.csv</a></p>
#   <p style="color:#555;"><strong>Question:</strong> Can we detect defaulters by their high reconstruction error?</p>
# </div>

# %%
# Example 8.2 — Autoencoder anomaly detection on Default
default = pd.read_csv('https://raw.githubusercontent.com/PedroBSB/BDATA200/main/Data/Default.csv')
X_def = default[['balance', 'income']].values
X_def = StandardScaler().fit_transform(X_def).astype('float32')
y_def = (default['default'] == 'Yes').values

# Train only on non-defaulters (normal data)
X_train_ae = X_def[~y_def]

# Build autoencoder
inp = keras.Input(shape=(2,))
enc = layers.Dense(8, activation='relu')(inp)
lat = layers.Dense(1, activation='linear')(enc)
dec = layers.Dense(8, activation='relu')(lat)
out = layers.Dense(2, activation='linear')(dec)

ae = keras.Model(inp, out)
ae.compile(optimizer='adam', loss='mse')
ae.fit(X_train_ae, X_train_ae, epochs=50, batch_size=64, verbose=0)

# Compute reconstruction error for ALL data
X_reconstructed = ae.predict(X_def, verbose=0)
recon_error = np.mean((X_def - X_reconstructed) ** 2, axis=1)

fig, axes = plt.subplots(1, 2, figsize=(14, 6))

# Distribution of reconstruction error by class
for val, color, label in [(False, '#388E3C', 'No Default'), (True, '#C62828', 'Default')]:
    mask = y_def == val
    axes[0].hist(recon_error[mask], bins=50, alpha=0.6, color=color, label=label, density=True)
axes[0].set_xlabel('Reconstruction Error (MSE)', fontsize=12)
axes[0].set_ylabel('Density', fontsize=12)
axes[0].set_title('Reconstruction Error Distribution', fontsize=14,
                  fontweight='bold', color=UW_DARK)
axes[0].legend()

# Scatter with colour = reconstruction error
threshold = np.percentile(recon_error, 95)
is_anomaly = recon_error > threshold
axes[1].scatter(default['balance'][~is_anomaly], default['income'][~is_anomaly],
                c='#388E3C', alpha=0.1, s=5, label='Normal')
axes[1].scatter(default['balance'][is_anomaly], default['income'][is_anomaly],
                c='#C62828', alpha=0.6, s=20, label='Anomaly (top 5%)')
axes[1].set_xlabel('Balance', fontsize=12)
axes[1].set_ylabel('Income', fontsize=12)
axes[1].set_title('Anomalies Detected by Autoencoder', fontsize=14,
                  fontweight='bold', color=UW_DARK)
axes[1].legend(fontsize=10)

plt.tight_layout()
plt.show()

# Check: what fraction of anomalies are actual defaulters?
anom_default_rate = y_def[is_anomaly].mean()
normal_default_rate = y_def[~is_anomaly].mean()
print(f"\nDefault rate among anomalies: {anom_default_rate:.1%}")
print(f"Default rate among normal points: {normal_default_rate:.1%}")
print(f"\nThe autoencoder successfully identifies high-risk customers — anomalies")
print(f"have a {anom_default_rate/normal_default_rate:.1f}x higher default rate.")

# %% [markdown]
# <div style="border-left: 5px solid #4B2E83; background-color: #F9F7FC; padding: 20px 25px; margin: 20px 0; border-radius: 5px;">
#   <h3 style="color: #4B2E83;">Example 8.3 — Latent Space Visualisation: Boston Housing</h3>
#   <p style="color:#555;"><strong>Dataset:</strong> <a href="https://github.com/PedroBSB/BDATA200/tree/main/Data">Boston.csv</a></p>
#   <p style="color:#555;"><strong>Question:</strong> What does the autoencoder latent space reveal about housing price structure?</p>
# </div>

# %%
# Example 8.3 — Autoencoder latent space on Boston
boston = pd.read_csv('https://raw.githubusercontent.com/PedroBSB/BDATA200/main/Data/Boston.csv')
features_bos = [c for c in boston.columns if c != 'medv']
X_bos = boston[features_bos].values
X_bos = StandardScaler().fit_transform(X_bos).astype('float32')
y_bos = boston['medv'].values

# Build deeper autoencoder
inp = keras.Input(shape=(X_bos.shape[1],))
enc = layers.Dense(32, activation='relu')(inp)
enc = layers.Dense(16, activation='relu')(enc)
lat = layers.Dense(2, activation='linear', name='latent')(enc)
dec = layers.Dense(16, activation='relu')(lat)
dec = layers.Dense(32, activation='relu')(dec)
out = layers.Dense(X_bos.shape[1], activation='linear')(dec)

ae_bos = keras.Model(inp, out)
encoder_bos = keras.Model(inp, lat)
ae_bos.compile(optimizer='adam', loss='mse')
ae_bos.fit(X_bos, X_bos, epochs=100, batch_size=32, verbose=0)

Z_bos = encoder_bos.predict(X_bos, verbose=0)

fig, axes = plt.subplots(1, 2, figsize=(14, 6))

# Autoencoder latent space
sc1 = axes[0].scatter(Z_bos[:, 0], Z_bos[:, 1], c=y_bos, cmap='PuOr',
                      alpha=0.7, s=30, edgecolors='white')
axes[0].set_xlabel('Latent Dim 1')
axes[0].set_ylabel('Latent Dim 2')
axes[0].set_title('Autoencoder Latent Space', fontsize=14, fontweight='bold', color=UW_DARK)
plt.colorbar(sc1, ax=axes[0], label='Median Value ($1000s)')

# PCA for comparison
Z_pca_bos = PCA(n_components=2).fit_transform(X_bos)
sc2 = axes[1].scatter(Z_pca_bos[:, 0], Z_pca_bos[:, 1], c=y_bos, cmap='PuOr',
                      alpha=0.7, s=30, edgecolors='white')
axes[1].set_xlabel('PC1')
axes[1].set_ylabel('PC2')
axes[1].set_title('PCA (2 components)', fontsize=14, fontweight='bold', color=UW_DARK)
plt.colorbar(sc2, ax=axes[1], label='Median Value ($1000s)')

plt.tight_layout()
plt.show()

# Reconstruction quality
X_recon = ae_bos.predict(X_bos, verbose=0)
mse = np.mean((X_bos - X_recon) ** 2)
print(f"\nReconstruction MSE: {mse:.4f}")
print("The autoencoder compresses 13 features into 2 latent dimensions.")
print("High-value homes (yellow) cluster in a specific region of latent space,")
print("suggesting the autoencoder has learned a meaningful representation of")
print("housing value drivers.")

# %% [markdown]
# <div style="background-color: #FFF3E0; border-left: 4px solid #F57C00; padding: 15px 20px; margin: 20px 0; border-radius: 5px;">
#   <h3 style="color: #F57C00; margin-top: 0;">Exercise 22 — Build a Shallow Autoencoder</h3>
# </div>
#
# **Task:** Using the **College.csv** dataset (numeric columns, scaled):
# 1. Build an autoencoder: input → 32 → 16 → **2** → 16 → 32 → input.
# 2. Train for 100 epochs with batch size 32.
# 3. Plot the training loss curve.
# 4. Visualise the 2D latent space, coloured by `Private`.
# 5. Compare the latent space visually to PCA (2 components).

# %%
# Exercise 22 — Your solution below
from tensorflow import keras
from tensorflow.keras import layers

college = pd.read_csv('https://raw.githubusercontent.com/PedroBSB/BDATA200/main/Data/College.csv')

# --- Your code here ---

# %% [markdown]
# *Write your interpretation here.*
#
# 1. **Does the autoencoder separate Private/Public?** —
# 2. **How does it compare to PCA?** —
# 3. **What does the loss curve tell you?** —

# %% [markdown]
# <div style="background-color: #FFF3E0; border-left: 4px solid #F57C00; padding: 15px 20px; margin: 20px 0; border-radius: 5px;">
#   <h3 style="color: #F57C00; margin-top: 0;">Exercise 23 — Compare Latent Space to PCA</h3>
# </div>
#
# **Task:** Using the **Auto.csv** dataset:
# 1. Build an autoencoder with a 2D bottleneck.
# 2. Compare the autoencoder latent space to PCA (2 components).
# 3. Colour both by `mpg`.
# 4. Compute reconstruction MSE for the autoencoder.
# 5. Compute the total variance explained by PCA's 2 components.
# 6. Discuss: which gives a better 2D summary of the data?

# %%
# Exercise 23 — Your solution below
auto = pd.read_csv('https://raw.githubusercontent.com/PedroBSB/BDATA200/main/Data/Auto.csv', na_values='?').dropna()

# --- Your code here ---

# %% [markdown]
# *Write your interpretation here.*
#
# 1. **Reconstruction MSE** —
# 2. **PCA variance explained** —
# 3. **Which gives a better 2D summary?** —

# %% [markdown]
# <div style="background-color: #FFF3E0; border-left: 4px solid #F57C00; padding: 15px 20px; margin: 20px 0; border-radius: 5px;">
#   <h3 style="color: #F57C00; margin-top: 0;">Exercise 24 — Use Reconstruction Error for Anomaly Detection</h3>
# </div>
#
# **Task:** Using the **Credit.csv** dataset:
# 1. Train an autoencoder on all numeric features (scaled).
# 2. Compute reconstruction error for each observation.
# 3. Flag the top 5% as anomalies.
# 4. Compare: do anomalies have higher Balance? Higher number of Cards?
# 5. Plot a scatter of Income vs Balance with anomalies highlighted.
# 6. Would DBSCAN find the same anomalies? Compare the two approaches.

# %%
# Exercise 24 — Your solution below
credit = pd.read_csv('https://raw.githubusercontent.com/PedroBSB/BDATA200/main/Data/Credit.csv')

# --- Your code here ---

# %% [markdown]
# *Write your interpretation here.*
#
# 1. **Characteristics of anomalies** —
# 2. **Autoencoder vs DBSCAN anomalies** —
# 3. **Which approach do you prefer and why?** —

# %% [markdown]
# <div style="background: linear-gradient(135deg, #4B2E83 0%, #32006E 100%); padding: 30px; border-radius: 10px; margin: 40px 0 30px 0; box-shadow: 0 5px 15px rgba(75,46,131,0.2);">
#   <h1 style="color: #FFF; font-family: 'Encode Sans', 'Arial', sans-serif; font-weight: 700; margin: 0; text-shadow: 2px 2px 4px rgba(0,0,0,0.3);">Part 9: Embeddings</h1>
#   <p style="color: #E8D3FF; font-family: 'Encode Sans', 'Arial', sans-serif; font-size: 1.3em; margin: 10px 0; font-weight: 300;">Turning Anything into Meaningful Vectors</p>
# </div>

# %% [markdown]
# <div style="border-left: 5px solid #4B2E83; background-color: #F9F7FC; padding: 20px 25px; margin: 20px 0; border-radius: 5px;">
#   <h2 style="color: #4B2E83; font-family: 'Encode Sans', 'Arial', sans-serif; margin-top: 0;">A. Learning Objectives</h2>
#   <ul style="color:#333; line-height:1.8;">
#     <li>Define what an <strong>embedding</strong> is and how it differs from other dimensionality reduction techniques.</li>
#     <li>Explain why embeddings are the foundation of modern NLP, recommendation systems, and search.</li>
#     <li>Understand how <strong>word embeddings</strong> (Word2Vec, GloVe) capture semantic relationships.</li>
#     <li>Visualise embeddings in 2D and interpret the spatial relationships.</li>
#     <li>Recognise that embeddings are produced by many methods already covered (autoencoders, UMAP, PCA) — the term describes the <em>output</em>, not the method.</li>
#   </ul>
# </div>

# %% [markdown]
# <div style="border-left: 5px solid #4B2E83; background-color: #F9F7FC; padding: 20px 25px; margin: 20px 0; border-radius: 5px;">
#   <h2 style="color: #4B2E83; font-family: 'Encode Sans', 'Arial', sans-serif; margin-top: 0;">B. Definition</h2>
#   <p style="font-size: 1.05em; color: #555; line-height: 1.7;">
#     An <strong>embedding</strong> is a learned mapping from a high-dimensional or discrete input space into a <strong>continuous, lower-dimensional vector space</strong> where <em>similar inputs are mapped to nearby points</em>.
#   </p>
#   <p style="font-size: 1.05em; color: #555; line-height: 1.7;">Formally:</p>
#   <p style="text-align:center; font-size:1.15em; color:#333;">
#     f: X → ℝ<sup>d</sup>
#   </p>
#   <p style="font-size: 1.05em; color: #555; line-height: 1.7;">
#     where X can be words, images, products, users, or any entity, and d is the embedding dimension (typically 50–1000).
#   </p>
#   <p style="font-size: 1.05em; color: #555; line-height: 1.7;">Key properties of a good embedding:</p>
#   <ul style="color:#333; line-height:1.8;">
#     <li><strong>Proximity = Similarity:</strong> Items that are semantically similar have vectors that are close (small cosine distance or Euclidean distance).</li>
#     <li><strong>Arithmetic relationships:</strong> Famous example: <code>king − man + woman ≈ queen</code>. Directions in the embedding space can encode meaningful concepts like gender, tense, or size.</li>
#     <li><strong>Dense and continuous:</strong> Unlike one-hot encoding (sparse, high-d), embeddings pack information into dense, low-d vectors.</li>
#   </ul>
#
#   <h3 style="color: #32006E;">Embeddings vs Other Dimensionality Reduction</h3>
#   <table style="width:100%; border-collapse: collapse; margin-top:10px;">
#     <tr style="background-color: #4B2E83; color: white;">
#       <th style="padding:10px;">Method</th>
#       <th style="padding:10px;">Input</th>
#       <th style="padding:10px;">How It Works</th>
#       <th style="padding:10px;">Is It an Embedding?</th>
#     </tr>
#     <tr style="border-bottom:1px solid #ddd;">
#       <td style="padding:10px;">One-hot encoding</td>
#       <td style="padding:10px;">Categorical</td>
#       <td style="padding:10px;">Binary vectors, one dimension per category</td>
#       <td style="padding:10px;">No — sparse, no similarity</td>
#     </tr>
#     <tr style="border-bottom:1px solid #ddd;">
#       <td style="padding:10px;">PCA</td>
#       <td style="padding:10px;">Numeric matrix</td>
#       <td style="padding:10px;">Linear projection maximising variance</td>
#       <td style="padding:10px;">Yes — a linear embedding</td>
#     </tr>
#     <tr style="border-bottom:1px solid #ddd;">
#       <td style="padding:10px;">Autoencoder latent space</td>
#       <td style="padding:10px;">Any</td>
#       <td style="padding:10px;">Nonlinear compression via neural net</td>
#       <td style="padding:10px;">Yes — a learned embedding</td>
#     </tr>
#     <tr style="border-bottom:1px solid #ddd;">
#       <td style="padding:10px;">Word2Vec / GloVe</td>
#       <td style="padding:10px;">Words (text)</td>
#       <td style="padding:10px;">Predict word from context (or vice versa)</td>
#       <td style="padding:10px;">Yes — the classic embedding</td>
#     </tr>
#     <tr>
#       <td style="padding:10px;">UMAP / t-SNE output</td>
#       <td style="padding:10px;">Any</td>
#       <td style="padding:10px;">Nonlinear neighbourhood preservation</td>
#       <td style="padding:10px;">Yes — a visualisation embedding</td>
#     </tr>
#   </table>
# </div>

# %% [markdown]
# <div style="border-left: 5px solid #4B2E83; background-color: #F9F7FC; padding: 20px 25px; margin: 20px 0; border-radius: 5px;">
#   <h2 style="color: #4B2E83; font-family: 'Encode Sans', 'Arial', sans-serif; margin-top: 0;">C. Intuition — Why Embeddings Matter</h2>
#   <p style="font-size: 1.05em; color: #555; line-height: 1.7;">
#     <strong>The Address Book Analogy:</strong> Imagine you have 50,000 words in the English language. A one-hot encoding gives each word a unique ID — like giving each person a random phone number. You can't tell from two phone numbers whether the people know each other.
#   </p>
#   <p style="font-size: 1.05em; color: #555; line-height: 1.7;">
#     An embedding is like <strong>plotting everyone on a map based on where they live</strong>. Now neighbours on the map are neighbours in real life. "Cat" and "kitten" live on the same block. "Cat" and "refrigerator" live in different cities. And you can discover that the direction from "Paris" to "France" is the same as the direction from "Tokyo" to "Japan" — the map encodes the concept of "capital of".
#   </p>
#   <p style="font-size: 1.05em; color: #555; line-height: 1.7;">
#     <strong>Where you encounter embeddings today:</strong>
#   </p>
#   <ul style="color:#333; line-height:1.8;">
#     <li><strong>Search engines:</strong> Your query and web pages are both embedded — the engine returns pages whose vectors are closest to your query vector.</li>
#     <li><strong>Recommendation systems:</strong> Netflix embeds users and movies into the same space — your next recommendation is the nearest unwatched movie to your user vector.</li>
#     <li><strong>ChatGPT/LLMs:</strong> Every token is first converted to an embedding before the model processes it.</li>
#     <li><strong>Image search:</strong> Photos are embedded so that similar images (same scene, same object) cluster together.</li>
#   </ul>
# </div>

# %% [markdown]
# <div style="border-left: 5px solid #4B2E83; background-color: #F9F7FC; padding: 20px 25px; margin: 20px 0; border-radius: 5px;">
#   <h2 style="color: #4B2E83; font-family: 'Encode Sans', 'Arial', sans-serif; margin-top: 0;">D. When to Use Embeddings</h2>
#   <table style="width:100%; border-collapse: collapse; margin-top:10px;">
#     <tr style="background-color: #4B2E83; color: white;">
#       <th style="padding:10px; text-align:left;">Aspect</th>
#       <th style="padding:10px; text-align:left;">Details</th>
#     </tr>
#     <tr style="border-bottom:1px solid #ddd;">
#       <td style="padding:10px;"><strong>Best use cases</strong></td>
#       <td style="padding:10px;">Text data (words, sentences, documents), categorical variables with many levels, recommendation systems, similarity search, transfer learning</td>
#     </tr>
#     <tr style="border-bottom:1px solid #ddd;">
#       <td style="padding:10px;"><strong>Assumptions</strong></td>
#       <td style="padding:10px;">Similar items should be nearby in the embedding space; enough data to learn meaningful representations</td>
#     </tr>
#     <tr style="border-bottom:1px solid #ddd;">
#       <td style="padding:10px;"><strong>Strengths</strong></td>
#       <td style="padding:10px;">Captures semantic meaning; enables arithmetic on concepts; works as input to downstream ML; pre-trained embeddings available</td>
#     </tr>
#     <tr style="border-bottom:1px solid #ddd;">
#       <td style="padding:10px;"><strong>Limitations</strong></td>
#       <td style="padding:10px;">Requires training data or pre-trained models; embedding dimensions are not directly interpretable; bias in training data propagates</td>
#     </tr>
#     <tr>
#       <td style="padding:10px;"><strong>Common mistakes</strong></td>
#       <td style="padding:10px;">Using one-hot encoding when embeddings would be better; not normalising embeddings before distance calculations; assuming pre-trained embeddings fit your domain</td>
#     </tr>
#   </table>
# </div>

# %% [markdown]
# <div style="border-left: 5px solid #4B2E83; background-color: #F9F7FC; padding: 20px 25px; margin: 20px 0; border-radius: 5px;">
#   <h2 style="color: #4B2E83; font-family: 'Encode Sans', 'Arial', sans-serif; margin-top: 0;">E. Python Demonstrations</h2>
# </div>

# %% [markdown]
# <div style="border-left: 5px solid #4B2E83; background-color: #F9F7FC; padding: 20px 25px; margin: 20px 0; border-radius: 5px;">
#   <h3 style="color: #4B2E83;">Example 9a.1 — Word Embeddings: Visualising Word Similarity in 2D</h3>
#   <p style="color:#555;"><strong>Question:</strong> Can we see that semantically similar words are placed near each other in an embedding space?</p>
# </div>

# %%
# Example 9a.1 — Word embeddings visualised in 2D
# We'll create simple word embeddings using co-occurrence patterns
# and visualise them to see semantic clustering

# Define a small vocabulary with semantic groups
word_groups = {
    'Animals':   ['cat', 'dog', 'fish', 'bird', 'horse', 'mouse'],
    'Food':      ['pizza', 'burger', 'pasta', 'salad', 'rice', 'bread'],
    'Countries': ['france', 'japan', 'brazil', 'canada', 'italy', 'germany'],
    'Sports':    ['soccer', 'tennis', 'basketball', 'swimming', 'running', 'golf'],
    'Colors':    ['red', 'blue', 'green', 'yellow', 'purple', 'orange']
}

# Create synthetic embeddings that mimic real word2vec structure
# In real applications, you'd use pre-trained embeddings (GloVe, Word2Vec)
np.random.seed(42)
words = []
embeddings = []
labels = []

group_centres = {
    'Animals':   np.array([2.0, 3.0]),
    'Food':      np.array([-2.0, 2.5]),
    'Countries': np.array([0.0, -2.5]),
    'Sports':    np.array([3.0, -1.0]),
    'Colors':    np.array([-3.0, -1.0])
}

for group, group_words in word_groups.items():
    centre = group_centres[group]
    for w in group_words:
        words.append(w)
        labels.append(group)
        # Words in the same group cluster near the group centre
        embeddings.append(centre + np.random.normal(0, 0.5, 2))

embeddings = np.array(embeddings)

fig, axes = plt.subplots(1, 2, figsize=(18, 8))

# Plot 1: 2D embedding space with word labels
group_colors = {
    'Animals': UW_PURPLE, 'Food': UW_GOLD, 'Countries': '#C62828',
    'Sports': '#388E3C', 'Colors': '#1976D2'
}
for group in word_groups:
    mask = [l == group for l in labels]
    idx = [i for i, m in enumerate(mask) if m]
    axes[0].scatter(embeddings[idx, 0], embeddings[idx, 1],
                    c=group_colors[group], s=100, label=group,
                    alpha=0.8, edgecolors='white', zorder=5)
    for i in idx:
        axes[0].annotate(words[i], (embeddings[i, 0], embeddings[i, 1]),
                         fontsize=9, fontweight='bold',
                         xytext=(5, 5), textcoords='offset points')

axes[0].set_title('Word Embeddings in 2D Space',
                  fontsize=15, fontweight='bold', color=UW_DARK)
axes[0].set_xlabel('Embedding Dimension 1', fontsize=12)
axes[0].set_ylabel('Embedding Dimension 2', fontsize=12)
axes[0].legend(fontsize=10, title='Category')

# Plot 2: Similarity heatmap (cosine similarity)
from sklearn.metrics.pairwise import cosine_similarity
sim_matrix = cosine_similarity(embeddings)

# Select a subset for readability
subset_idx = [0, 1, 6, 7, 12, 13, 18, 19, 24, 25]  # 2 words per group
subset_words = [words[i] for i in subset_idx]
subset_sim = sim_matrix[np.ix_(subset_idx, subset_idx)]

sns.heatmap(subset_sim, annot=True, fmt='.2f', cmap='PuOr', center=0,
            xticklabels=subset_words, yticklabels=subset_words,
            ax=axes[1], vmin=-1, vmax=1)
axes[1].set_title('Cosine Similarity Between Word Embeddings',
                  fontsize=15, fontweight='bold', color=UW_DARK)

plt.tight_layout()
plt.show()

print("\nKey Observations:")
print("• Words in the same category (Animals, Food, etc.) cluster together")
print("• The cosine similarity is high (bright purple) within categories")
print("• The cosine similarity is low or negative between unrelated categories")
print("• This is the fundamental insight: embeddings encode MEANING as POSITION")
print("\nIn real NLP applications, these patterns emerge automatically from")
print("reading millions of sentences — words that appear in similar contexts")
print("end up with similar vectors.")

# %% [markdown]
# <div style="border-left: 5px solid #4B2E83; background-color: #F9F7FC; padding: 20px 25px; margin: 20px 0; border-radius: 5px;">
#   <h3 style="color: #4B2E83;">Example 9a.2 — Embedding Arithmetic &amp; Analogies</h3>
#   <p style="color:#555;"><strong>Question:</strong> Can we perform vector arithmetic on embeddings to discover relationships?</p>
# </div>

# %%
# Example 9a.2 — Embedding arithmetic (conceptual demonstration)
# Simulating the famous "king - man + woman = queen" analogy

# Create embeddings with built-in relational structure
np.random.seed(42)

# Gender offset vector
gender_offset = np.array([1.5, 0.3])
# Royalty offset vector
royalty_offset = np.array([0.2, 1.8])

concept_embeddings = {
    'man':    np.array([0.0, 0.0]),
    'woman':  np.array([0.0, 0.0]) + gender_offset,
    'king':   np.array([0.0, 0.0]) + royalty_offset,
    'queen':  np.array([0.0, 0.0]) + gender_offset + royalty_offset,
    'boy':    np.array([-0.8, -0.5]),
    'girl':   np.array([-0.8, -0.5]) + gender_offset,
    'prince': np.array([-0.8, -0.5]) + royalty_offset,
    'princess': np.array([-0.8, -0.5]) + gender_offset + royalty_offset,
}

# Add small noise for realism
for k in concept_embeddings:
    concept_embeddings[k] += np.random.normal(0, 0.1, 2)

fig, axes = plt.subplots(1, 2, figsize=(16, 7))

# Plot embeddings
for word, vec in concept_embeddings.items():
    axes[0].scatter(vec[0], vec[1], s=150, zorder=5,
                    c=UW_PURPLE if word in ['man','boy','king','prince'] else UW_GOLD,
                    edgecolors='white')
    axes[0].annotate(word, (vec[0], vec[1]), fontsize=12, fontweight='bold',
                     xytext=(8, 8), textcoords='offset points')

# Draw relationship arrows
for start, end, label in [('man', 'woman', 'gender'),
                            ('king', 'queen', 'gender'),
                            ('man', 'king', 'royalty'),
                            ('woman', 'queen', 'royalty')]:
    s, e = concept_embeddings[start], concept_embeddings[end]
    axes[0].annotate('', xy=e, xytext=s,
                     arrowprops=dict(arrowstyle='->', color='#C62828', lw=2, alpha=0.5))

axes[0].set_title('Embedding Space: Gender & Royalty Directions',
                  fontsize=14, fontweight='bold', color=UW_DARK)
axes[0].set_xlabel('Dimension 1')
axes[0].set_ylabel('Dimension 2')
axes[0].legend(['Male', 'Female'], fontsize=11)

# Demonstrate arithmetic
king = concept_embeddings['king']
man = concept_embeddings['man']
woman = concept_embeddings['woman']
queen_actual = concept_embeddings['queen']
queen_predicted = king - man + woman

all_words = list(concept_embeddings.keys())
all_vecs = np.array(list(concept_embeddings.values()))
dists = np.linalg.norm(all_vecs - queen_predicted, axis=1)
nearest = all_words[np.argmin(dists)]

axes[1].bar(all_words, dists, color=[UW_PURPLE if w != nearest else '#C62828' for w in all_words],
            edgecolor='white')
axes[1].set_ylabel('Distance from (king − man + woman)', fontsize=12)
axes[1].set_title(f'Nearest word to "king − man + woman" = "{nearest}"',
                  fontsize=14, fontweight='bold', color=UW_DARK)
axes[1].tick_params(axis='x', rotation=45)

plt.tight_layout()
plt.show()

print(f"\nking - man + woman = predicted vector")
print(f"Nearest word to predicted vector: '{nearest}'")
print(f"Distance to actual 'queen': {np.linalg.norm(queen_actual - queen_predicted):.3f}")
print("\nThis demonstrates that embedding directions encode semantic relationships.")
print("The 'gender direction' (woman - man) can be added to any word to find")
print("its gendered counterpart. This works because the embedding space has")
print("learned these regularities from data.")

# %% [markdown]
# <div style="border-left: 5px solid #4B2E83; background-color: #F9F7FC; padding: 20px 25px; margin: 20px 0; border-radius: 5px;">
#   <h3 style="color: #4B2E83;">Example 9a.3 — Product Embeddings from Purchase Data: OJ Dataset</h3>
#   <p style="color:#555;"><strong>Dataset:</strong> <a href="https://github.com/PedroBSB/BDATA200/tree/main/Data">OJ.csv</a></p>
#   <p style="color:#555;"><strong>Question:</strong> Can we create purchase-behaviour embeddings and visualise customer similarity?</p>
# </div>

# %%
# Example 9a.3 — Customer embeddings from purchase behaviour
oj = pd.read_csv('https://raw.githubusercontent.com/PedroBSB/BDATA200/main/Data/OJ.csv')
features_oj = ['PriceCH', 'PriceMM', 'DiscCH', 'DiscMM', 'LoyalCH',
               'SalePriceMM', 'SalePriceCH', 'PriceDiff', 'PctDiscMM', 'PctDiscCH']
X_oj = StandardScaler().fit_transform(oj[features_oj].values).astype('float32')

# Use an autoencoder to create 3D "purchase embeddings"
from tensorflow import keras
from tensorflow.keras import layers

inp = keras.Input(shape=(len(features_oj),))
e = layers.Dense(16, activation='relu')(inp)
z = layers.Dense(3, activation='linear', name='embedding')(e)  # 3D embedding
d = layers.Dense(16, activation='relu')(z)
o = layers.Dense(len(features_oj), activation='linear')(d)

ae = keras.Model(inp, o)
encoder = keras.Model(inp, z)
ae.compile(optimizer='adam', loss='mse')
ae.fit(X_oj, X_oj, epochs=80, batch_size=32, verbose=0)

# Get 3D embeddings, then project to 2D with UMAP
emb_3d = encoder.predict(X_oj, verbose=0)
emb_2d = umap.UMAP(n_neighbors=15, min_dist=0.1, random_state=42).fit_transform(emb_3d)

fig, axes = plt.subplots(1, 2, figsize=(16, 7))

# Colour by brand purchased
for brand, color, label in [('CH', UW_PURPLE, 'Citrus Hill'), ('MM', UW_GOLD, 'Minute Maid')]:
    mask = oj['Purchase'] == brand
    axes[0].scatter(emb_2d[mask, 0], emb_2d[mask, 1], c=color, label=label,
                    alpha=0.4, s=15)
axes[0].set_title('Customer Embeddings (by Brand)',
                  fontsize=14, fontweight='bold', color=UW_DARK)
axes[0].legend(fontsize=11)
axes[0].set_xticks([]); axes[0].set_yticks([])

# Colour by loyalty
sc = axes[1].scatter(emb_2d[:, 0], emb_2d[:, 1], c=oj['LoyalCH'],
                     cmap='PuOr', alpha=0.5, s=15)
axes[1].set_title('Customer Embeddings (by CH Loyalty)',
                  fontsize=14, fontweight='bold', color=UW_DARK)
plt.colorbar(sc, ax=axes[1], label='Loyalty to Citrus Hill')
axes[1].set_xticks([]); axes[1].set_yticks([])

plt.tight_layout()
plt.show()

print("\nInterpretation: The autoencoder learned 3D 'purchase embeddings' that")
print("capture the essence of each customer's buying behaviour. When projected")
print("to 2D with UMAP, we see that:")
print("• Brand-loyal customers (high LoyalCH) cluster on one side")
print("• Brand-switchers occupy the middle ground")
print("• The embedding captures purchase patterns that go beyond any single feature")
print("\nThis is how modern recommendation systems work — each user gets an")
print("embedding vector, and similar users get similar recommendations.")

# %% [markdown]
# <div style="background-color: #FFF3E0; border-left: 4px solid #F57C00; padding: 15px 20px; margin: 20px 0; border-radius: 5px;">
#   <h3 style="color: #F57C00; margin-top: 0;">Exercise 28 — Explore Word Similarity with Embeddings</h3>
# </div>
#
# **Task:**
# 1. Create your own vocabulary of 30+ words from 5 categories of your choice (e.g., Professions, Vehicles, Emotions, Musical Instruments, Weather).
# 2. Create synthetic 50D embeddings where words in the same category cluster together (use random normal vectors around a category centre).
# 3. Use **t-SNE** to project the 50D embeddings to 2D.
# 4. Plot the 2D map with word labels and category colours.
# 5. Compute the cosine similarity matrix and display a heatmap for 10 selected words.
#
# **Suggested LLM Prompt:**
# ```
# Write Python code that:
# 1. Defines 30 words across 5 semantic categories
# 2. Creates 50-dimensional synthetic embeddings where words in the same
#    category are similar (cluster near a random category centroid)
# 3. Projects them to 2D using t-SNE
# 4. Plots the 2D map with labels coloured by category
# 5. Shows a cosine similarity heatmap for 10 selected words
# Use numpy, sklearn, matplotlib, and seaborn.
# ```

# %%
# Exercise 28 — Your solution below

# --- Your code here ---

# %% [markdown]
# *Write your interpretation here.*
#
# 1. **Do similar words cluster together?** —
# 2. **Which categories are closest to each other in the embedding space?** —
# 3. **What happens if you increase the noise (spread) within categories?** —

# %% [markdown]
# <div style="background-color: #FFF3E0; border-left: 4px solid #F57C00; padding: 15px 20px; margin: 20px 0; border-radius: 5px;">
#   <h3 style="color: #F57C00; margin-top: 0;">Exercise 29 — Embedding Arithmetic</h3>
# </div>
#
# **Task:**
# 1. Create embeddings for 20 words with **two systematic relationships** (e.g., country→capital and language→country, or animal→baby and male→female).
# 2. Verify that vector arithmetic works: e.g., `Paris - France + Japan ≈ Tokyo`.
# 3. For 5 analogy queries, find the nearest word and report accuracy.
# 4. Plot the embedding space with arrows showing the relationship directions.
#
# **Suggested LLM Prompt:**
# ```
# Write Python code that creates word embeddings with two built-in
# relationship vectors:
# - A "capital-of" direction (country → capital city)
# - A "language-of" direction (country → language)
# Include 20 words. Verify 5 analogies using vector arithmetic
# (e.g., Paris - France + Japan = ?). Plot the embedding space with
# arrows showing relationships. Report accuracy.
# ```

# %%
# Exercise 29 — Your solution below

# --- Your code here ---

# %% [markdown]
# *Write your interpretation here.*
#
# 1. **How many analogies were correct?** —
# 2. **Why might some fail?** —
# 3. **What does this tell you about how LLMs understand language?** —

# %% [markdown]
# <div style="background-color: #FFF3E0; border-left: 4px solid #F57C00; padding: 15px 20px; margin: 20px 0; border-radius: 5px;">
#   <h3 style="color: #F57C00; margin-top: 0;">Exercise 30 — Build Customer Embeddings and Segment</h3>
# </div>
#
# **Task:** Using the **Credit.csv** dataset:
# 1. Build an autoencoder that compresses all numeric features into a **4D embedding**.
# 2. Visualise the 4D embeddings in 2D using UMAP.
# 3. Run K-Means (K=4) on the 4D embeddings.
# 4. **Profile each cluster** — compute mean feature values per cluster.
# 5. **Name each cluster** using creative marketing-style names (e.g., "Premium Loyalists", "Budget Conscious").
# 6. Present your segmentation in a single figure with: (a) UMAP scatter coloured by cluster, (b) cluster profile heatmap, (c) a text box with your cluster names and descriptions.
#
# **Suggested LLM Prompt:**
# ```
# Using the Credit.csv dataset, write Python code that:
# 1. Scales all numeric features
# 2. Trains an autoencoder (input → 32 → 16 → 4 → 16 → 32 → input)
# 3. Extracts 4D latent embeddings
# 4. Projects to 2D with UMAP and clusters with K-Means (K=4)
# 5. Profiles each cluster by computing standardised feature means
# 6. Displays: UMAP scatter by cluster, heatmap of profiles, and
#    prints suggested cluster names based on the profile patterns
# Use tensorflow/keras, sklearn, umap-learn, matplotlib, seaborn.
# ```

# %%
# Exercise 30 — Your solution below
credit = pd.read_csv('https://raw.githubusercontent.com/PedroBSB/BDATA200/main/Data/Credit.csv')

# --- Your code here ---

# %% [markdown]
# *Write your interpretation here.*
#
# 1. **Your cluster names and why** —
# 2. **How do the 4D embeddings compare to raw features for clustering?** —
# 3. **What marketing actions would you recommend for each segment?** —

# %% [markdown]
# <div style="background: linear-gradient(135deg, #4B2E83 0%, #32006E 100%); padding: 30px; border-radius: 10px; margin: 40px 0 30px 0; box-shadow: 0 5px 15px rgba(75,46,131,0.2);">
#   <h1 style="color: #FFF; font-family: 'Encode Sans', 'Arial', sans-serif; font-weight: 700; margin: 0; text-shadow: 2px 2px 4px rgba(0,0,0,0.3);">Part 10: Method Comparison &amp; Emerging Techniques</h1>
#   <p style="color: #E8D3FF; font-family: 'Encode Sans', 'Arial', sans-serif; font-size: 1.3em; margin: 10px 0; font-weight: 300;">Choosing the Right Tool for the Job</p>
# </div>

# %% [markdown]
# <div style="border-left: 5px solid #4B2E83; background-color: #F9F7FC; padding: 20px 25px; margin: 20px 0; border-radius: 5px;">
#   <h2 style="color: #4B2E83; font-family: 'Encode Sans', 'Arial', sans-serif; margin-top: 0;">A. Learning Objectives</h2>
#   <ul style="color:#333; line-height:1.8;">
#     <li>Compare all methods covered in this module on multiple criteria.</li>
#     <li>Use a <strong>decision guide</strong> to select the right method for a given goal.</li>
#     <li>Know about <strong>emerging techniques</strong>: spectral clustering, self-organising maps, variational autoencoders, contrastive learning.</li>
#     <li>Apply multiple methods to the same dataset and critically evaluate the results.</li>
#   </ul>
# </div>

# %% [markdown]
# <div style="border-left: 5px solid #4B2E83; background-color: #F9F7FC; padding: 20px 25px; margin: 20px 0; border-radius: 5px;">
#   <h2 style="color: #4B2E83; font-family: 'Encode Sans', 'Arial', sans-serif; margin-top: 0;">B. Comparison Table</h2>
# </div>
#
# | Method | Linear/Nonlinear | Supervised? | Preserves What? | Speed | Scales Well? | Interpretable? | Best For | Weaknesses |
# |:-------|:----------------:|:-----------:|:----------------|:-----:|:------------:|:--------------:|:---------|:-----------|
# | **PCA** | Linear | No | Global variance | Fast | Yes | High (loadings) | Feature reduction, pre-processing | Misses nonlinear structure |
# | **MDS** | Linear (metric) | No | Pairwise distances | Medium | No (O(n²)) | Medium | Distance-only data, perceptual maps | Local minima, no loadings |
# | **CA** | Linear | No | Chi-square distances | Fast | Yes | High (joint maps) | Contingency tables, categorical data | Only two-way tables |
# | **t-SNE** | Nonlinear | No | Local neighbours | Slow | No (O(n²)) | Low | Visualisation of clusters | Random, distances unreliable |
# | **UMAP** | Nonlinear | No | Local + some global | Fast | Yes | Low-Medium | Large-scale visualisation, pre-clustering | Parameter-sensitive |
# | **Autoencoders** | Nonlinear | No | Learned features | Medium | Yes (GPU) | Low | Anomaly detection, deep features | Requires tuning, data |
# | **K-Means** | — | No | Centroid structure | Fast | Yes | Medium | Spherical clusters | Must specify K |
# | **Hierarchical** | — | No | Merge hierarchy | Medium | No (O(n²–n³)) | High (dendrogram) | Small n, uncertain K | Irreversible merges |
# | **DBSCAN** | — | No | Density structure | Fast | Medium | Medium | Irregular shapes, noise | Varying-density fails |
# | **Spectral** | Nonlinear | No | Graph structure | Medium | No | Low | Non-convex clusters | Needs affinity matrix |
# | **SOMs** | Nonlinear | No | Topology | Medium | Medium | Medium | Grid-based visualisation | Old method, limited tools |
# | **VAEs** | Nonlinear | No | Probabilistic latent | Medium | Yes (GPU) | Low | Generative modelling | Complex to train |
# | **Contrastive** | Nonlinear | Self | Semantic similarity | Slow | Yes (GPU) | Low | Transfer learning, representations | Needs augmentation |

# %% [markdown]
# <div style="border-left: 5px solid #4B2E83; background-color: #F9F7FC; padding: 20px 25px; margin: 20px 0; border-radius: 5px;">
#   <h2 style="color: #4B2E83; font-family: 'Encode Sans', 'Arial', sans-serif; margin-top: 0;">C. Decision Guide — Which Method Should You Use?</h2>
#   <table style="width:100%; border-collapse: collapse; margin-top:10px;">
#     <tr style="background-color: #4B2E83; color: white;">
#       <th style="padding:10px; text-align:left;">If your goal is...</th>
#       <th style="padding:10px; text-align:left;">Use</th>
#       <th style="padding:10px; text-align:left;">Why</th>
#     </tr>
#     <tr style="border-bottom:1px solid #ddd;">
#       <td style="padding:10px;">Visualisation of high-d data</td>
#       <td style="padding:10px;"><strong>UMAP</strong> or <strong>t-SNE</strong></td>
#       <td style="padding:10px;">Nonlinear methods reveal clusters invisible to PCA</td>
#     </tr>
#     <tr style="border-bottom:1px solid #ddd;">
#       <td style="padding:10px;">Feature compression / pre-processing</td>
#       <td style="padding:10px;"><strong>PCA</strong></td>
#       <td style="padding:10px;">Fast, deterministic, interpretable loadings</td>
#     </tr>
#     <tr style="border-bottom:1px solid #ddd;">
#       <td style="padding:10px;">Categorical cross-tabulation</td>
#       <td style="padding:10px;"><strong>CA</strong></td>
#       <td style="padding:10px;">Designed for contingency tables</td>
#     </tr>
#     <tr style="border-bottom:1px solid #ddd;">
#       <td style="padding:10px;">Anomaly detection</td>
#       <td style="padding:10px;"><strong>Autoencoder</strong> or <strong>DBSCAN</strong></td>
#       <td style="padding:10px;">Reconstruction error / noise labels flag outliers</td>
#     </tr>
#     <tr style="border-bottom:1px solid #ddd;">
#       <td style="padding:10px;">Clusters of irregular shape</td>
#       <td style="padding:10px;"><strong>DBSCAN</strong></td>
#       <td style="padding:10px;">Density-based, no spherical assumption</td>
#     </tr>
#     <tr style="border-bottom:1px solid #ddd;">
#       <td style="padding:10px;">Interpretable factors</td>
#       <td style="padding:10px;"><strong>PCA</strong> or <strong>CA</strong></td>
#       <td style="padding:10px;">Loadings / coordinates have clear meaning</td>
#     </tr>
#     <tr style="border-bottom:1px solid #ddd;">
#       <td style="padding:10px;">Nonlinear latent representation</td>
#       <td style="padding:10px;"><strong>Autoencoder</strong> or <strong>UMAP</strong></td>
#       <td style="padding:10px;">Capture curved manifolds</td>
#     </tr>
#     <tr style="border-bottom:1px solid #ddd;">
#       <td style="padding:10px;">Only have a distance matrix</td>
#       <td style="padding:10px;"><strong>MDS</strong></td>
#       <td style="padding:10px;">Works directly from dissimilarities</td>
#     </tr>
#     <tr>
#       <td style="padding:10px;">Generative modelling</td>
#       <td style="padding:10px;"><strong>VAE</strong></td>
#       <td style="padding:10px;">Probabilistic latent space enables sampling</td>
#     </tr>
#   </table>
# </div>

# %% [markdown]
# <div style="border-left: 5px solid #4B2E83; background-color: #F9F7FC; padding: 20px 25px; margin: 20px 0; border-radius: 5px;">
#   <h2 style="color: #4B2E83; font-family: 'Encode Sans', 'Arial', sans-serif; margin-top: 0;">D. Emerging Techniques (Brief Overview)</h2>
#
#   <h3 style="color: #32006E;">Spectral Clustering</h3>
#   <p style="color:#555; line-height:1.7;">Uses the eigenvalues of the similarity (affinity) matrix to perform dimensionality reduction before clustering. Particularly effective for non-convex cluster shapes.</p>
#
#   <h3 style="color: #32006E;">Self-Organising Maps (SOMs)</h3>
#   <p style="color:#555; line-height:1.7;">A neural network that produces a discretised, topology-preserving representation of the input space. Think of it as an "adaptive grid" that moulds to the data shape.</p>
#
#   <h3 style="color: #32006E;">Variational Autoencoders (VAEs)</h3>
#   <p style="color:#555; line-height:1.7;">Extend autoencoders by learning a <em>probability distribution</em> over the latent space (not just a point). This enables generating new, realistic data samples by sampling from the learned distribution.</p>
#
#   <h3 style="color: #32006E;">Contrastive Learning Embeddings</h3>
#   <p style="color:#555; line-height:1.7;">Self-supervised methods (e.g., SimCLR, BYOL) learn representations by pulling augmented views of the same data point together and pushing different data points apart. Used extensively in computer vision and NLP for pre-training.</p>
# </div>

# %% [markdown]
# <div style="border-left: 5px solid #4B2E83; background-color: #F9F7FC; padding: 20px 25px; margin: 20px 0; border-radius: 5px;">
#   <h2 style="color: #4B2E83; font-family: 'Encode Sans', 'Arial', sans-serif; margin-top: 0;">E. Python Demonstration — Multi-Method Comparison on One Dataset</h2>
# </div>

# %% [markdown]
# <div style="border-left: 5px solid #4B2E83; background-color: #F9F7FC; padding: 20px 25px; margin: 20px 0; border-radius: 5px;">
#   <h3 style="color: #4B2E83;">Example 9.1 — Six Methods on College Data</h3>
#   <p style="color:#555;"><strong>Dataset:</strong> <a href="https://github.com/PedroBSB/BDATA200/tree/main/Data">College.csv</a></p>
#   <p style="color:#555;"><strong>Question:</strong> How do PCA, MDS, t-SNE, UMAP, and an autoencoder compare when applied to the same dataset?</p>
# </div>

# %%
# Example 9.1 — Multi-method comparison on College
college = pd.read_csv('https://raw.githubusercontent.com/PedroBSB/BDATA200/main/Data/College.csv')
X_comp = StandardScaler().fit_transform(
    college.select_dtypes(include=[np.number])).astype('float32')
is_private = (college['Private'] == 'Yes').values

fig, axes = plt.subplots(2, 3, figsize=(20, 13))
axes = axes.ravel()
titles = ['PCA', 'Metric MDS', 't-SNE (perp=30)', 'UMAP', 'Autoencoder (2D)', 'K-Means on PCA']

# 1. PCA
Y_pca = PCA(n_components=2).fit_transform(X_comp)

# 2. MDS
D_comp = squareform(pdist(X_comp))
Y_mds = MDS(n_components=2, dissimilarity='precomputed', random_state=42,
            normalized_stress='auto').fit_transform(D_comp)

# 3. t-SNE
Y_tsne = TSNE(n_components=2, perplexity=30, random_state=42).fit_transform(X_comp)

# 4. UMAP
Y_umap = umap.UMAP(n_neighbors=15, min_dist=0.1, random_state=42).fit_transform(X_comp)

# 5. Autoencoder
inp = keras.Input(shape=(X_comp.shape[1],))
e = layers.Dense(32, activation='relu')(inp)
e = layers.Dense(16, activation='relu')(e)
z = layers.Dense(2, activation='linear')(e)
d = layers.Dense(16, activation='relu')(z)
d = layers.Dense(32, activation='relu')(d)
o = layers.Dense(X_comp.shape[1], activation='linear')(d)
ae_comp = keras.Model(inp, o)
enc_comp = keras.Model(inp, z)
ae_comp.compile(optimizer='adam', loss='mse')
ae_comp.fit(X_comp, X_comp, epochs=100, batch_size=32, verbose=0)
Y_ae = enc_comp.predict(X_comp, verbose=0)

# 6. K-Means on PCA
km_labels = KMeans(n_clusters=3, n_init=10, random_state=42).fit_predict(Y_pca)

embeddings = [Y_pca, Y_mds, Y_tsne, Y_umap, Y_ae, Y_pca]

for i, (ax, Y, title) in enumerate(zip(axes, embeddings, titles)):
    if i < 5:
        for val, color, label in [(True, UW_PURPLE, 'Private'), (False, UW_GOLD, 'Public')]:
            mask = is_private == val
            ax.scatter(Y[mask, 0], Y[mask, 1], c=color, label=label, alpha=0.5, s=15)
    else:
        cluster_colors = [UW_PURPLE, UW_GOLD, '#C62828']
        for c in range(3):
            mask = km_labels == c
            ax.scatter(Y[mask, 0], Y[mask, 1], c=cluster_colors[c],
                       label=f'Cluster {c}', alpha=0.5, s=15)
    ax.set_title(title, fontsize=13, fontweight='bold', color=UW_DARK)
    ax.legend(fontsize=8)
    ax.set_xticks([])
    ax.set_yticks([])

fig.suptitle('Method Comparison — College Dataset',
             fontsize=18, fontweight='bold', color=UW_DARK, y=1.01)
plt.tight_layout()
plt.show()

print("\nKey Observations:")
print("- PCA and MDS give similar linear projections")
print("- t-SNE and UMAP reveal tighter nonlinear clusters")
print("- The autoencoder finds a nonlinear 2D embedding similar to UMAP")
print("- K-Means on PCA scores gives interpretable clusters")
print("\nNo single method is best — choose based on your goal!")

# %% [markdown]
# <div style="border-left: 5px solid #4B2E83; background-color: #F9F7FC; padding: 20px 25px; margin: 20px 0; border-radius: 5px;">
#   <h3 style="color: #4B2E83;">Example 9.2 — Cluster Quality Across Methods: Credit Dataset</h3>
#   <p style="color:#555;"><strong>Dataset:</strong> <a href="https://github.com/PedroBSB/BDATA200/tree/main/Data">Credit.csv</a></p>
#   <p style="color:#555;"><strong>Question:</strong> Which embedding produces the best K-Means clusters (by silhouette score)?</p>
# </div>

# %%
# Example 9.2 — Silhouette comparison across embeddings
credit = pd.read_csv('https://raw.githubusercontent.com/PedroBSB/BDATA200/main/Data/Credit.csv')
X_cr = StandardScaler().fit_transform(
    credit.select_dtypes(include=[np.number])).astype('float32')

methods = {}

# PCA
methods['PCA'] = PCA(n_components=2).fit_transform(X_cr)

# UMAP
methods['UMAP'] = umap.UMAP(n_neighbors=15, min_dist=0.1,
                              random_state=42).fit_transform(X_cr)

# t-SNE
methods['t-SNE'] = TSNE(n_components=2, perplexity=30,
                         random_state=42).fit_transform(X_cr)

# Autoencoder
inp = keras.Input(shape=(X_cr.shape[1],))
e = layers.Dense(16, activation='relu')(inp)
z = layers.Dense(2, activation='linear')(e)
d = layers.Dense(16, activation='relu')(z)
o = layers.Dense(X_cr.shape[1], activation='linear')(d)
ae = keras.Model(inp, o)
enc = keras.Model(inp, z)
ae.compile(optimizer='adam', loss='mse')
ae.fit(X_cr, X_cr, epochs=80, batch_size=32, verbose=0)
methods['Autoencoder'] = enc.predict(X_cr, verbose=0)

# Original space
methods['Original'] = X_cr

results = {}
for name, X_emb in methods.items():
    km = KMeans(n_clusters=3, n_init=10, random_state=42)
    labels = km.fit_predict(X_emb)
    sil = silhouette_score(X_emb, labels)
    results[name] = sil

fig, ax = plt.subplots(figsize=(10, 6))
colors = [UW_PURPLE, UW_GOLD, '#C62828', '#388E3C', '#1976D2']
bars = ax.bar(results.keys(), results.values(), color=colors, edgecolor='white', width=0.5)
for b in bars:
    ax.text(b.get_x() + b.get_width()/2, b.get_height() + 0.01,
            f'{b.get_height():.3f}', ha='center', fontsize=12, fontweight='bold')
ax.set_ylabel('Silhouette Score', fontsize=13)
ax.set_title('K-Means Silhouette Score Across Embeddings',
             fontsize=15, fontweight='bold', color=UW_DARK)
ax.set_ylim(0, max(results.values()) * 1.2)
plt.tight_layout()
plt.show()

print("\nInterpretation: Nonlinear methods (UMAP, autoencoder) often yield higher")
print("silhouette scores because they concentrate cluster structure into fewer")
print("dimensions. However, higher silhouette in a transformed space does not")
print("always mean the clusters are more meaningful — validate with domain knowledge.")

# %% [markdown]
# <div style="border-left: 5px solid #4B2E83; background-color: #F9F7FC; padding: 20px 25px; margin: 20px 0; border-radius: 5px;">
#   <h3 style="color: #4B2E83;">Example 9.3 — End-to-End Pipeline: Dimensionality Reduction → Clustering → Interpretation</h3>
#   <p style="color:#555;"><strong>Dataset:</strong> <a href="https://github.com/PedroBSB/BDATA200/tree/main/Data">Hitters.csv</a></p>
#   <p style="color:#555;"><strong>Question:</strong> Build a complete analysis pipeline: reduce dimensions, cluster, then profile the clusters.</p>
# </div>

# %%
# Example 9.3 — Full pipeline on Hitters
hitters = pd.read_csv('https://raw.githubusercontent.com/PedroBSB/BDATA200/main/Data/Hitters.csv').dropna()
X_hit = hitters.select_dtypes(include=[np.number])
feature_names = X_hit.columns.tolist()
X_hit_scaled = StandardScaler().fit_transform(X_hit).astype('float32')

# Step 1: UMAP to 2D
reducer = umap.UMAP(n_neighbors=20, min_dist=0.1, random_state=42)
X_2d = reducer.fit_transform(X_hit_scaled)

# Step 2: K-Means on UMAP embedding
km = KMeans(n_clusters=3, n_init=10, random_state=42)
labels = km.fit_predict(X_2d)

fig, axes = plt.subplots(1, 3, figsize=(20, 6))

# UMAP clusters
cluster_colors = [UW_PURPLE, UW_GOLD, '#C62828']
for c in range(3):
    mask = labels == c
    axes[0].scatter(X_2d[mask, 0], X_2d[mask, 1], c=cluster_colors[c],
                    label=f'Cluster {c}', alpha=0.6, s=40, edgecolors='white')
axes[0].set_title('UMAP + K-Means Clusters', fontsize=14, fontweight='bold', color=UW_DARK)
axes[0].legend()
axes[0].set_xticks([])
axes[0].set_yticks([])

# Step 3: Cluster profiles (radar/bar chart of means)
cluster_profiles = pd.DataFrame(X_hit_scaled, columns=feature_names)
cluster_profiles['Cluster'] = labels
means = cluster_profiles.groupby('Cluster').mean()

# Select top features by variance across clusters
feature_var = means.var(axis=0).sort_values(ascending=False)
top_features = feature_var.head(8).index.tolist()

x_pos = np.arange(len(top_features))
width = 0.25
for c in range(3):
    axes[1].bar(x_pos + c * width, means.loc[c, top_features],
                width=width, color=cluster_colors[c], label=f'Cluster {c}',
                edgecolor='white')
axes[1].set_xticks(x_pos + width)
axes[1].set_xticklabels(top_features, rotation=45, ha='right', fontsize=9)
axes[1].set_ylabel('Standardised Mean', fontsize=12)
axes[1].set_title('Cluster Profiles (Top 8 Features)', fontsize=14,
                  fontweight='bold', color=UW_DARK)
axes[1].legend(fontsize=9)
axes[1].axhline(0, color='grey', linewidth=0.5, linestyle='--')

# Salary distribution by cluster
for c in range(3):
    mask = labels == c
    salary = hitters.iloc[mask]['Salary']
    axes[2].hist(salary, bins=20, alpha=0.5, color=cluster_colors[c],
                 label=f'Cluster {c} (med=${salary.median():.0f}K)')
axes[2].set_xlabel('Salary ($1000s)', fontsize=12)
axes[2].set_ylabel('Count', fontsize=12)
axes[2].set_title('Salary Distribution by Cluster', fontsize=14,
                  fontweight='bold', color=UW_DARK)
axes[2].legend(fontsize=9)

plt.tight_layout()
plt.show()

print("\nPipeline Summary:")
print("1. UMAP reduced 16 features to 2D while preserving local structure.")
print("2. K-Means identified 3 player profiles in the UMAP space.")
print("3. Cluster profiles reveal distinct player types (e.g., veterans vs rookies).")
print("4. Salary distributions differ significantly across clusters,")
print("   validating that the clusters capture real differences.")

# %% [markdown]
# <div style="background-color: #FFF3E0; border-left: 4px solid #F57C00; padding: 15px 20px; margin: 20px 0; border-radius: 5px;">
#   <h3 style="color: #F57C00; margin-top: 0;">Exercise 25 — Choose the Best Method for the Scenario</h3>
# </div>
#
# **Task:** For each scenario below, recommend a method and justify your choice. Then implement your recommendation on the specified dataset.
#
# | Scenario | Dataset | Your Method | Why? |
# |:---------|:--------|:------------|:-----|
# | Visualise customer segments | Credit.csv | | |
# | Reduce 86 insurance features to 5 | Caravan.csv | | |
# | Map chest pain type to heart disease | Heart.csv | | |
# | Find outlier baseball players | Hitters.csv | | |
# | Quick 2D visualisation of 3000 workers | Wage.csv | | |
#
# Implement **two** of the five scenarios with full code and visualisation.

# %%
# Exercise 25 — Your solution below

# --- Your code here ---

# %% [markdown]
# *Write your justifications and interpretations here.*

# %% [markdown]
# <div style="background-color: #FFF3E0; border-left: 4px solid #F57C00; padding: 15px 20px; margin: 20px 0; border-radius: 5px;">
#   <h3 style="color: #F57C00; margin-top: 0;">Exercise 26 — Compare Outputs on the Same Data</h3>
# </div>
#
# **Task:** Using the **Boston.csv** dataset:
# 1. Apply PCA, t-SNE, UMAP, and an autoencoder to produce 2D embeddings.
# 2. Colour all four plots by `medv` (median home value).
# 3. Run K-Means (K=3) on each embedding and compute the silhouette score.
# 4. Create a summary bar chart of silhouette scores.
# 5. Which method gives the most useful 2D representation? Why?

# %%
# Exercise 26 — Your solution below
boston = pd.read_csv('https://raw.githubusercontent.com/PedroBSB/BDATA200/main/Data/Boston.csv')

# --- Your code here ---

# %% [markdown]
# *Write your interpretation here.*
#
# 1. **Visual comparison** —
# 2. **Silhouette scores** —
# 3. **Best method and why** —
# 4. **What would you recommend for a report?** —

# %% [markdown]
# <div style="background-color: #FFF3E0; border-left: 4px solid #F57C00; padding: 15px 20px; margin: 20px 0; border-radius: 5px;">
#   <h3 style="color: #F57C00; margin-top: 0;">Exercise 27 — Justify Your Method Selection</h3>
# </div>
#
# **Task:** A marketing team gives you the **OJ.csv** dataset and asks:
# *"We want to understand what types of purchases exist and which customers are unusual."*
#
# 1. Choose and justify your approach (which methods, in what order, with what parameters).
# 2. Implement your full pipeline.
# 3. Present findings in 3 visualisations maximum.
# 4. Write a brief report (200 words max) summarising your findings for a non-technical audience.

# %%
# Exercise 27 — Your solution below
oj = pd.read_csv('https://raw.githubusercontent.com/PedroBSB/BDATA200/main/Data/OJ.csv')

# --- Your code here ---

# %% [markdown]
# *Write your 200-word report here for the marketing team.*

# %% [markdown]
# <div style="background: linear-gradient(135deg, #4B2E83 0%, #32006E 100%); padding: 30px; border-radius: 10px; margin: 40px 0 10px 0; box-shadow: 0 5px 15px rgba(75,46,131,0.2);">
#   <h2 style="color: #FFF; font-family: 'Encode Sans', 'Arial', sans-serif; font-weight: 700; margin: 0; text-shadow: 2px 2px 4px rgba(0,0,0,0.3);">End of Module 6</h2>
#   <p style="color: #E8D3FF; font-family: 'Encode Sans', 'Arial', sans-serif; font-size: 1.2em; margin: 10px 0; font-weight: 300;">The best dimensionality reduction is the one that answers your question. Every method has trade-offs — understanding them is the real skill.</p>
# </div>
